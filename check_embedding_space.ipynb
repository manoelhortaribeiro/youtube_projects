# %% [markdown]
# This notebook checks the behaviour of the embedding space

# %%
import numpy as np
import pandas as pd
import zstandard as zstd

import pickle
import random

from annoy import AnnoyIndex
from scipy.spatial import distance

# %%
'''
Retrieve the array obtained by apllying the dimentinality reductin algorithm
graph_matrix: SHAPE: (channels, n_comp)
'''
n_comp = 500
graph_matrix = np.load('../../../dlabdata1/youtube_large/jouven/graph_matrix_reduced_'+str(n_comp)+'.npz')
graph_matrix = graph_matrix['arr_0']
df = pd.DataFrame(graph_matrix)
df = df.rename(lambda x: 'dr'+str(x), axis='columns')
df.head()
# Out:
#           dr0        dr1        dr2        dr3         dr4         dr5  \
# 0    3.018157   2.509277  -1.370723  -1.205678   -2.077085   -0.748989
# 1    8.037677   4.613102   1.003205   0.260758    2.158020   -4.919136
# 2   21.643678   4.486470  17.017157   4.962999    5.291304   -7.874998
# 3  367.470984 -22.194127 -71.681107 -28.139755 -121.998349 -263.544879
# 4   27.062345   3.521666   8.440126   2.053278   10.615795  -12.821902
#
#          dr6        dr7        dr8        dr9  ...     dr490      dr491  \
# 0   0.437611   2.537465  -1.731717  -0.114103  ...  0.055535   0.139898
# 1   1.621984   0.779602   2.237350   2.801618  ... -0.542192  -0.185954
# 2  -0.042691   5.202206   5.295214   3.251302  ...  2.204272  -0.736775
# 3  40.496879 -23.376365  14.612321  31.488560  ... -5.095282 -12.182553
# 4  -3.522644  -7.847089 -14.845779  20.498252  ...  2.095842  -2.157510
#
#       dr492     dr493     dr494     dr495     dr496     dr497     dr498  \
# 0 -0.440606  0.131203  0.164528  0.020788 -0.678321 -0.291248 -0.392943
# 1  0.173667  0.040427  0.472720  0.092969 -0.323724 -0.429245 -0.025467
# 2  1.406568 -0.932924  1.431729 -0.790614 -1.471813 -0.479949  1.046505
# 3  2.291161  5.818858 -0.325965 -1.839918  1.649609  0.640047 -5.059650
# 4 -0.829279 -0.495257  0.104933 -1.049125  0.119824  1.179280  0.452845
#
#       dr499
# 0  0.481696
# 1 -0.864688
# 2  0.862118
# 3 -6.026595
# 4 -2.336437
#
# [5 rows x 500 columns]

# %%
'''
Now we have to map the index values into the channels_id thanks to the mapping dictionarray already created
'''
# Channels that are in set_crawler dataset and also in which the language is in english
with open('../../../dlabdata1/youtube_large/olam/channels_id.pickle', 'rb') as f:
    channels_id = pickle.load(f)
f.close()

# Dictionnary to map an integer corresponding to the column/row of the sparse matrix to the channel id.
channel_index_dict = {}
for ind, channel_id in enumerate(channels_id):
    channel_index_dict[ind] = channel_id
    
# Dictionnary to map the channel id to an integer corresponding to the column/row of the sparse matrix.
channel_id_dict = {}
for ind, channel_id in enumerate(channels_id):
    channel_id_dict[channel_id] = ind

# %% [markdown]
# ### Find k closest channel using annoy library

# %% [markdown]
# First to check how good is the embedding space, we are going to choose a channel and it's k closest channels in the embedding space. By looking at these channels in the YouTube website, we should get similar channels if the embedding space is good.

# %%
np.array(df.iloc[0])
# Out:
# array([ 3.01815744e+00,  2.50927734e+00, -1.37072257e+00, -1.20567830e+00,
#        -3.90236719e-01,  5.97832104e-02,  2.95489873e-01, -2.02736198e-01,
#        -6.52600192e-01,  3.03922997e-01,  1.32931559e-01, -1.71104955e-01,
#        -1.74939831e-01,  2.37327198e-01,  6.53431948e-01, -5.13207013e-02,
#        -6.39869279e-02, -4.60619317e-02, -1.89467663e-01, -2.77413787e-02,
#        -2.54000859e-01, -1.13989874e-01,  3.39734702e-01,  1.00893779e-01,
#        -1.69787934e-01, -2.95126829e-01, -8.47297766e-02,  4.34989524e-01,
#         1.34272733e-01, -8.70004385e-02,  4.47596349e-01,  2.00334559e-01,
#        -2.37323161e-01, -1.26900291e-01, -5.60858974e-01, -1.62534255e-01,
#        -2.82490988e-02, -1.29335700e-01, -1.42430658e-01,  2.38909111e-01,
#         2.53429176e-01, -3.90237008e-01,  8.13277274e-02, -3.17213434e-01,
#         5.57805285e-02, -1.73810471e-01,  4.51995433e-02,  8.74411359e-02,
#        -1.61178156e-01, -4.79970152e-01,  8.07282333e-02, -1.04900230e-01,
#        -5.10295817e-01,  2.28615007e-02,  7.99192995e-02,  3.98213931e-01,
#         1.87562335e-01,  3.21263677e-02, -3.27801331e-02, -7.88518790e-02,
#        -3.14191354e-01,  1.19599715e-01,  5.55354899e-02,  1.39898301e-01,
#        -4.40605552e-01,  1.31203343e-01,  1.64527830e-01,  2.07879818e-02,
#        -6.78321483e-01, -2.91247803e-01, -3.92942963e-01,  4.81696489e-01])

# %%
index = AnnoyIndex(n_comp, "euclidean")  # Length of item vector that will be indexed
df.apply(lambda row: index.add_item(row.name, np.array(row)), axis = 1)
index.build(100) # 10 trees
#index.save('../../../dlabdata1/youtube_large/jouven/annoy_index_10_trees.ann')
# Out:
# True

# %%
#random.seed(1)
item = random.randint(0, len(df))
print('item: ', item)
nearest_neighbors_index = index.get_nns_by_item(item, 20, search_k = len(df))
print(nearest_neighbors_index) # will find the 1000 nearest neighbors
# Out:
# item:  16543
# [16543, 115042, 77163, 78164, 47750, 33212, 62731, 147383, 89464, 53533, 24819, 43031, 5458, 49837, 58287, 5848, 143352, 98347, 64534, 37307]

# %%
nearest_neighbors_id = [channel_index_dict[val] for val in nearest_neighbors_index]
nearest_neighbors_id
# Out:
# ['UCPuuuhmMW7jh6roOrIV9yRw',
#  'UCjpgDLE5LGOpzX2igCKAdSQ',
#  'UC4NALVCmcmL5ntpV0thoH6w',
#  'UCs9DW1cr_cf4Mpi6QFjam_w',
#  'UCvbQvWnQWEVNciTqgQPc7Hg',
#  'UCuM2xSE9ix0ncMxjx4Ggolw',
#  'UC2kz8okargLDXEH5RZMIRvw',
#  'UCs8EL6BMdxYx9K-wO7T2mIg',
#  'UCl69ToPHGlOHUCegE2HJM1g',
#  'UCjAij4NWCod80d70enm3tRw',
#  'UCvTueU0tFCj3Ym_aPi6UmUw',
#  'UCO5ujNeWRIwP4DbCZqZWcLw',
#  'UCSQ4EcsdtS3YxG2oHLF6heg',
#  'UCN_ebY0N506fwZIwud36mUg',
#  'UCzOIlU2dIXOTiTlFDuA3PJg',
#  'UC2q1qbHBqQJl-TL15LPT0dw',
#  'UCN9xkhyjdN8QN5d1m2FIU8A',
#  'UCK5X3f0fxO4YnVKVZP8p6hg',
#  'UC34n5OYv8Z7PRP-mtkxkPwQ',
#  'UCvnCXuh_zhm75EJ89qJ95Kw']

# %%
channelcrawler = pd.read_csv("/dlabdata1/youtube_large/channelcrawler.csv")
channelcrawler['channel_id'] = channelcrawler['link'].str.split('/').str[-1]
channelcrawler.head()
# Out:
#              category   join_date  \
# 0  Film and Animation  2017-05-21
# 1       Entertainment  2011-12-13
# 2               Music  2013-09-13
# 3               Music  2008-03-17
# 4       Entertainment  2014-10-19
#
#                                                 link                     name  \
# 0  http://www.youtube.com/channel/UCBJuEqXfXTdcPS...             MagnusNation
# 1  http://www.youtube.com/channel/UCkNW9Q1VR_aeZ6...  Mago Dario Animazion...
# 2  http://www.youtube.com/channel/UC1xcnrpcF59FWW...       Mägo de Oz - Topic
# 3  http://www.youtube.com/channel/UCXhkGgooXHDNwg...             Mago Merlino
# 4  http://www.youtube.com/channel/UCvZGsuvKlYOGiZ...               MAGO TOMÁS
#
#    subscribers  videos                channel_id
# 0        65100      28  UCBJuEqXfXTdcPSbGO9qqn1g
# 1        60200      48  UCkNW9Q1VR_aeZ6uht83jJVQ
# 2        40200     395  UC1xcnrpcF59FWWELtZvJTdg
# 3        14800     838  UCXhkGgooXHDNwgJXmoTSN7g
# 4        26200      31  UCvZGsuvKlYOGiZTsxwJNS5Q

# %%
channelcrawler['category'].unique()
# Out:
# array(['Film and Animation', 'Entertainment', 'Music', 'Comedy', 'Gaming',
#        'Science & Technology', 'Sports', 'Education', 'People & Blogs',
#        'Nonprofits & Activism', 'Howto & Style', 'News & Politics',
#        'Travel & Events', 'Autos & Vehicles', 'Pets & Animals', nan],
#       dtype=object)

# %%
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
#                   channel_id               category   join_date  \
# 0   UCPuuuhmMW7jh6roOrIV9yRw                  Music  2006-03-01
# 1   UCjpgDLE5LGOpzX2igCKAdSQ         People & Blogs  2013-03-17
# 2   UC4NALVCmcmL5ntpV0thoH6w                  Music  2014-08-05
# 3   UCs9DW1cr_cf4Mpi6QFjam_w                  Music  2013-02-19
# 4   UCvbQvWnQWEVNciTqgQPc7Hg                  Music  2013-03-23
# 5   UCuM2xSE9ix0ncMxjx4Ggolw   Science & Technology  2011-06-22
# 6   UC2kz8okargLDXEH5RZMIRvw          Entertainment  2015-02-08
# 7   UCs8EL6BMdxYx9K-wO7T2mIg                  Music  2015-05-04
# 8   UCl69ToPHGlOHUCegE2HJM1g                  Music  2010-03-20
# 9   UCjAij4NWCod80d70enm3tRw                 Gaming  2017-03-21
# 10  UCvTueU0tFCj3Ym_aPi6UmUw         People & Blogs  2013-05-21
# 11  UCO5ujNeWRIwP4DbCZqZWcLw       Autos & Vehicles  2018-04-17
# 12  UCSQ4EcsdtS3YxG2oHLF6heg  Nonprofits & Activism  2014-01-01
# 13  UCN_ebY0N506fwZIwud36mUg         Pets & Animals  2015-01-12
# 14  UCzOIlU2dIXOTiTlFDuA3PJg        Travel & Events  2017-04-20
# 15  UC2q1qbHBqQJl-TL15LPT0dw         People & Blogs  2012-07-23
# 16  UCN9xkhyjdN8QN5d1m2FIU8A                  Music  2016-11-22
# 17  UCK5X3f0fxO4YnVKVZP8p6hg         People & Blogs  2006-01-02
# 18  UC34n5OYv8Z7PRP-mtkxkPwQ                 Gaming  2012-10-13
# 19  UCvnCXuh_zhm75EJ89qJ95Kw                  Music  2009-11-26
#
#                                                  link  \
# 0   http://www.youtube.com/channel/UCPuuuhmMW7jh6r...
# 1   http://www.youtube.com/channel/UCjpgDLE5LGOpzX...
# 2   http://www.youtube.com/channel/UC4NALVCmcmL5nt...
# 3   http://www.youtube.com/channel/UCs9DW1cr_cf4Mp...
# 4   http://www.youtube.com/channel/UCvbQvWnQWEVNci...
# 5   http://www.youtube.com/channel/UCuM2xSE9ix0ncM...
# 6   http://www.youtube.com/channel/UC2kz8okargLDXE...
# 7   http://www.youtube.com/channel/UCs8EL6BMdxYx9K...
# 8   http://www.youtube.com/channel/UCl69ToPHGlOHUC...
# 9   http://www.youtube.com/channel/UCjAij4NWCod80d...
# 10  http://www.youtube.com/channel/UCvTueU0tFCj3Ym...
# 11  http://www.youtube.com/channel/UCO5ujNeWRIwP4D...
# 12  http://www.youtube.com/channel/UCSQ4EcsdtS3YxG...
# 13  http://www.youtube.com/channel/UCN_ebY0N506fwZ...
# 14  http://www.youtube.com/channel/UCzOIlU2dIXOTiT...
# 15  http://www.youtube.com/channel/UC2q1qbHBqQJl-T...
# 16  http://www.youtube.com/channel/UCN9xkhyjdN8QN5...
# 17  http://www.youtube.com/channel/UCK5X3f0fxO4YnV...
# 18  http://www.youtube.com/channel/UC34n5OYv8Z7PRP...
# 19  http://www.youtube.com/channel/UCvnCXuh_zhm75E...
#
#                        name  subscribers  videos
# 0             Grateful Dead       112434     157
# 1                 Bethany G       161000     740
# 2   LooLoo Kids - Nurser...     18500000     415
# 3                  Yo Trane        61700      24
# 4               DjPurpleI5h        30700    1502
# 5               Kevin Riazi        14700      63
# 6         Creative Newborns        11100     833
# 7         Careless Whispers        14500      48
# 8                  CHHEWANG       348000      48
# 9              Atomic Heart        30600      15
# 10               Hail Storm        20200      22
# 11                     Audi        10300     211
# 12             Manav Dharam        34400     170
# 13         Primitive Monkey       144000    8304
# 14  You Should Know This...        36800     129
# 15  TV Capital Sinop & G...        14600    2294
# 16            Lekker Sounds        14207     335
# 17              Alicia Keys      3572479     113
# 18            BaronVonGamez       420941    2207
# 19                 385idéal      1151676     602

# %% [markdown]
# ### Comparative study between users walk and random walk

# %% [markdown]
# In this section we want to measure the euclidian distance of a user walk compared to a random walk.
# user walk: All the channels visited by a user taken at random. We then compute the euclidian distance in the embedding space between the first and the last channel.
# random walk: Channels taken at random and we measures their distances.
#
# The result we are looking for is that the user walk should be smaller than the random walk.

# %%
len_random_set = 1000

# %% [markdown]
# #### Users walk

# %%
# Dictionnary mapping the video_id to the channel_id
vid_to_channels = pd.read_pickle("/dlabdata1/youtube_large/id_to_channel_mapping.pickle")

# %%
class Zreader:

    def __init__(self, file, chunk_size=16384):
        '''Init method'''
        self.fh = open(file,'rb')
        self.chunk_size = chunk_size
        self.dctx = zstd.ZstdDecompressor()
        self.reader = self.dctx.stream_reader(self.fh)
        self.buffer = ''

    def readlines(self):
        '''Generator method that creates an iterator for each line of JSON'''
        while True:
            chunk = self.reader.read(self.chunk_size).decode("utf-8", errors="ignore")
            if not chunk:
                break
            lines = (self.buffer + chunk).split("\n")

            for line in lines[:-1]:
                yield line

            self.buffer = lines[-1]

# %%
'''
Function to add new edge
    PARAMETERS:
        - graph_dict: dictionnary mapping the edge (tuple of channel indices) with the weight of that edge
        - user_edge_channel_id: new edge to be added in graph_dict
'''
def add_user(channels, first_channel, last_channel, idx):
    channels.append((channel_id_dict[first_channel], channel_id_dict[last_channel]))
    #print('user at index ' + str(idx) + ' has been added')
        
# Adjust chunk_size as necessary -- defaults to 16,384 if not specific
reader = Zreader("/dlabdata1/youtube_large/youtube_comments.ndjson.zst", chunk_size=16384)

# parameters
channels = []
random_values = set(random.sample(range(3, 100000), k = len_random_set))
#print('index of users taken at random: ', random_values)
idx = 1
nb_elem_added = 0
user = 'author_id'
first_channel = ''
last_channel = ''
average_distance = 0


# Read each line from the reader
for line in reader.readlines():
    line_split = line.replace('"', '').split(',')
    if len(line_split) == 9:
        if idx == 1:
            print(line_split)
            idx += 1

        else:
            if vid_to_channels.get(line_split[2]) in channels_id:
                corr_channel = vid_to_channels[line_split[2]]
                if line_split[0] == user:
                    last_channel = corr_channel
                    user_last = line_split[0]
                else:
                    if (idx in random_values) and (last_channel != ''):
                        add_user(channels, first_channel, last_channel, idx)
                        nb_elem_added += 1
                    elif idx in random_values:
                        idx -= 1
                    user_first = line_split[0]
                    first_channel = corr_channel
                    last_channel = ''
                    user = line_split[0]
                    idx += 1
                
    if nb_elem_added == len_random_set:
        for val in channels:
            average_distance += distance.euclidean(df.iloc[val[0]], df.iloc[1])
        average_distance /= len_random_set
        print('Average distance of the users walk is ', average_distance)
        break
# Out:
# ['author_id', 'id', 'video_id', 'parent_id', 'crawled_at', 'likes', 'replies', 'author', 'content']
# Average distance of the users walk is  578.2853395127695

# %% [markdown]
# #### Random walk

# %%
len_random_values = len(df)
random_values_1 = random.sample(range(len_random_values), k = len_random_set)
random_values_2 = random.sample(range(len_random_values), k = len_random_set)
random_walk_channels = list(zip(random_values_1, random_values_2))
#print('random channels chosen: ', list(random_values))

# %%
average_random_walk_distance = 0
for val in random_walk_channels:
    average_random_walk_distance += distance.euclidean(df.iloc[val[0]], df.iloc[1])
average_random_walk_distance /= len_random_set
print('Average distance of the random walk is ', average_random_walk_distance)
# Out:
# Average distance of the random walk is  498.32158976881726
