# %% [markdown]
# ## NOTEBOOK DESCRIPTION:
#
# This notebook checks the behaviour of the embedding space:
# - It first checks manually the nearest neighbors of some selected channels
# - It also compute the user jumper score which is a first barrier on the evaluation of the embedding

# %%
import pickle
import os
import sys
import random

import numpy as np
import pandas as pd


scriptpath = "/home/jouven/youtube_projects/"
sys.path.append(os.path.abspath(scriptpath))

from helpers.helpers_channels_more_10k import *
from helpers.helpers_channel_embedding import *

scriptpath = "/home/jouven/youtube_projects"
sys.path.append(os.path.abspath(scriptpath))
from helpers.config_threshold_value import *

# %% [markdown]
# ### Useful functions

# %%
# Selected channels and id-index mapping
dict_channel_ind, dict_ind_channel, channels_id = filtered_channels_index_id_mapping()

# %%
PATH = '/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channels_more_10k/channel_embedding_30M_diff_channels_7.npy'

# %%
channelcrawler = pd.read_csv("/dlabdata1/youtube_large/df_channels_en.tsv.gz", sep='\t')
# Select the rows being in the select channels
channelcrawler = channelcrawler[channelcrawler['channel'].apply(lambda row: row in channels_id)]

# %%
channelcrawler.head()
# Out:
#      category_cc   join_date                   channel  \
# 0         Gaming  2010-04-29  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 1      Education  2006-09-01  UCbCmjCuTUZos6Inko4u57UQ
# 2  Entertainment  2006-09-20  UCpEhnqL0y41EpW2TvWAHD7Q
# 3  Howto & Style  2016-11-15  UC295-Dw_tDNtZXFeAPAW6Aw
# 4         Sports  2007-05-11  UCJ5v_MCY6GNUBTO8-D3XoAg
#
#                    name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                PewDiePie       101000000       3956                 3.0
# 1  Cocomelon - Nursery ...        60100000        458                 7.0
# 2                SET India        56018869      32661                 8.0
# 3          5-Minute Crafts        60600000       3591                 9.0
# 4                      WWE        48400000      43421                11.0
#
#    weights
# 0    2.087
# 1    2.087
# 2    2.087
# 3    2.087
# 4    2.087

# %%
channelcrawler['category_cc'].unique()
# Out:
# array(['Gaming', 'Education', 'Entertainment', 'Howto & Style', 'Sports',
#        'Music', 'Film and Animation', 'Comedy', 'Nonprofits & Activism',
#        'People & Blogs', 'News & Politics', 'Science & Technology',
#        'Pets & Animals', 'Autos & Vehicles', 'Travel & Events', nan],
#       dtype=object)

# %% [markdown]
# ### Manually check the neirest neighbors of some selected channels

# %% [markdown]
# First to check how good is the embedding space, we are going to choose a channel and it's k closest channels in the embedding space. By looking at these channels in the YouTube website, we have a sense of how good/bad is the embedding.

# %%
# Looking at the neirest neigbors of `Shaaanxo` being a girl fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCMpOz2KEfkSdd5JeIJh_fxw'], dict_ind_channel, k= 20, embedding_type = 'word2vecf')
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel     category_cc   join_date  \
# 0   UCMpOz2KEfkSdd5JeIJh_fxw   Howto & Style  2009-01-18
# 1   UCUt0ZA6l_EidUnBFMR9BZig   Howto & Style  2009-11-28
# 2   UCeZn7qRN3JKVcEYK_dDg7JQ   Howto & Style  2010-11-19
# 3   UCXbQzhqSvgVZTUyi1T4AU3w   Howto & Style  2011-08-31
# 4   UCydYMBWbpGgt0RIfNVXGxCA   Howto & Style  2011-04-03
# 5   UCPRlGA2w7C_DVw-1ynolJYw  People & Blogs  2011-07-19
# 6   UCvxXnjcMUY46qEJ6I-1dThw   Howto & Style  2008-12-31
# 7   UC3JxYPRHnB5TvaCFuKfcdJQ   Howto & Style  2012-03-02
# 8   UC1BB4CsKykhht_25SQUNLjA  People & Blogs  2013-06-07
# 9   UC5CLbqqdnKUzYNyS_kMbnIg   Howto & Style  2012-08-17
# 10  UCeGe5mF6zkOA17X6X1VIjkA   Howto & Style  2013-05-14
# 11  UCEZtkE45zjun9zROKtcqOcQ   Howto & Style  2012-02-11
# 12  UCWWyv3cV6dH1Q8rdGFu10hQ  People & Blogs  2015-04-16
# 13  UCJRFJl5UDs4Citzs-uRcrxQ   Howto & Style  2011-01-12
# 14  UCAakD8jDdAya5f59XRfiIuQ   Howto & Style  2012-03-22
# 15  UC8C7sbw7tHN2gD6fE9Cj9rw   Howto & Style  2013-04-07
# 16  UC85jN0RMP-uJTIzhAcMFitA  People & Blogs  2010-10-06
# 17  UCqTR5f7YkGro3cPv23SqcqQ   Howto & Style  2012-12-29
# 18  UCSrf41V5oQnwZgFO2QK2Q8g   Howto & Style  2010-09-30
# 19  UCFghPtzFcmyDiID1ASMA4Dg   Howto & Style  2008-07-03
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                  Shaaanxo         3215340       1422              3566.0
# 1                     SMLx0         1000000        645             16293.0
# 2              leighannsays          816000        756             19205.0
# 3             Lauren Curtis         3530000        379              3067.0
# 4          Andréa Matillano          304000       1074             58530.0
# 5            Shaaanxo Vlogs          555112        742             29412.0
# 6            ThatGirlShaeXo          397000        667             41405.0
# 7                  Chrisspy         1660000        258              8889.0
# 8        CaseyHolmesVlogs91          640000        183             27439.0
# 9   Young Wild and Polis...          158000        630            110411.0
# 10               Amy Macedo          995000        696             16577.0
# 11            Amanda Ensing         1440000        488             10711.0
# 12             Cosmobyhaley          508000        349             34593.0
# 13        Danielle Mansutti         1610000        412              9194.0
# 14            ItsMyRayeRaye         1980000        242              7044.0
# 15  Jessica Braun | JAMb...          560000       1009             31776.0
# 16            Karissa Pukas          737127        503             24009.0
# 17                 juicyjas          625000        682             25375.0
# 18              Alexisjayda          413000        793             44389.0
# 19            Lisa Eldridge         1930000        320              6687.0
#
#     weights
# 0    2.2780
# 1    2.8620
# 2    2.8650
# 3    2.2335
# 4    3.5900
# 5    3.0150
# 6    3.3705
# 7    2.5650
# 8    2.9760
# 9    5.0615
# 10   2.8185
# 11   2.5920
# 12   3.1995
# 13   2.5580
# 14   2.5200
# 15   3.1005
# 16   2.9405
# 17   2.9760
# 18   3.3455
# 19   2.4920

# %%
# Looking at the neirest neigbors of `Alex Costa` being a men fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCZyCposXwcyopaACep44maQ'], dict_ind_channel, k= 20, embedding_type = 'word2vecf')
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel           category_cc   join_date  \
# 0   UCZyCposXwcyopaACep44maQ         Howto & Style  2011-09-29
# 1   UCbq8_4_mFAx_rzDF5VT7MJw         Howto & Style  2013-11-11
# 2   UCcGYJndqreqXMUZoOhn3E7A  Science & Technology  2012-04-10
# 3   UCK-H1e0S8jg-8qoqQ5N8jvw  Science & Technology  2012-07-26
# 4   UCk1SpWNzOs4MYmr0uICEntg  Science & Technology  2009-12-25
# 5   UCdp6GUwjKscp5ST4M4WgIpw  Science & Technology  2011-09-11
# 6   UCBKH2wfmHxht7YyA2dVaWew  Science & Technology  2011-11-09
# 7   UCzLaQ6eeTVuAltzTrN7fzyg  Science & Technology  2012-02-16
# 8   UCejH9OVMqJmzerevPFqPd2w       Entertainment  2016-12-27
# 9   UCVcQH8A634mauPrGbWs7QlQ           Education  2010-07-14
# 10  UCEUvltkHJLAbazgxsmpJdOA              Gaming  2016-02-07
# 11  UCwVybImr_rQGsaO4bvjIWcw  Film and Animation  2013-01-15
# 12  UCfPyVJEBD7Di1YYjTdS2v8g           Education  2015-03-24
# 13  UCZpRbIs4y844kjNpCQu6emA              Gaming  2012-01-06
# 14  UCDqgSnRMGVx3dP4sn3ATZMA  Film and Animation  2015-01-29
# 15  UCHSi5wUHw5PhPUdcKqIWS_g       Entertainment  2014-07-26
# 16  UCVv1vQYLgJ6STMJkK2aWMyQ       Entertainment  2015-07-07
# 17  UCQxdWI84BtazOv6Y8OW7BUA       Entertainment  2013-11-10
# 18  UCfoOUk3V7-Jln-h0FUjbkSw  Film and Animation  2013-03-22
# 19  UCwAIv1MTna8lHAkNjJxZm9w      People & Blogs  2006-06-03
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                Magpiepony          736000        304             21120.0
# 1          FluttershyPlay's           80300         68            199547.0
# 2             MusicGirl Pro          194000        204             84619.0
# 3   Little Kelly & Frien...          183624        496             98458.0
# 4                    Juliya          170000         25             99830.0
# 5          Misty Brick Toys          295000        376             61289.0
# 6       The Beginners Bible          160917        243             99787.0
# 7              eric wartick          168734        103            102730.0
# 8           Big WOU Channel          306000        179             51566.0
# 9   Jack Hartmann Kids M...          665000        878             20512.0
# 10  Kefe Animations - Mi...          797000        130             20250.0
# 11           World Of Games          299000         43             55758.0
# 12           Homeschool Pop          172000        365             83934.0
# 13          Blackbelt Films          210000        597             80266.0
# 14  Daniel Tiger's Neigh...          381465        408             43576.0
# 15  Glitter Rainbow Toys...          252113        148             71878.0
# 16                Tridashie          252744         48             67004.0
# 17               LenTotally          138000         39            116818.0
# 18           Giga Gargantua          359000        132             48007.0
# 19                konas2002          764000       1060             21656.0
#
#     weights
# 0    2.9225
# 1    5.3380
# 2    4.3660
# 3    3.6775
# 4    3.7310
# 5    3.7875
# 6    3.7170
# 7    3.9895
# 8    3.4685
# 9    2.9200
# 10   2.8810
# 11   3.5140
# 12   4.3100
# 13   4.0845
# 14   3.3770
# 15   3.8020
# 16   4.0465
# 17   4.5690
# 18   3.4325
# 19   2.9455

# %%
# Looking at neirest neigbors of `Beyond the trailer` a channel for analysis of films
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCAXR2zenCwvRIyQd9ydtfaA'], dict_ind_channel, k= 20, embedding_type = 'word2vecf')
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel         category_cc   join_date  \
# 0   UCAXR2zenCwvRIyQd9ydtfaA       Entertainment  2008-11-03
# 1   UCtoMyXF4VFY3cB8fUcn7N4A       Entertainment  2006-09-19
# 2   UCPOrN8u0yH-gIEb7SkMwkTw       Entertainment  2012-04-06
# 3   UCinjnmQEwCddOudyCC1v7qA     News & Politics  2006-06-13
# 4   UCkqg9F6VUHWDZB4rR--NM7w              Gaming  2006-04-10
# 5   UC7sDT8jZ76VLV1u__krUutA  Film and Animation  2016-07-29
# 6   UC_Oa7Ph3v94om5OyxY1nPKg       Howto & Style  2009-06-03
# 7   UCl_Ydej82Zq4NEZnwxeaUwg               Music  2006-04-28
# 8   UC1nw_szfrEsDWcwD32wHE_w       Entertainment  2006-03-05
# 9   UCveZqqGewoyPiacooywP5Ig           Education  2012-05-08
# 10  UCFJCZVPGAHi6uCdcxy5KVvA              Gaming  2007-02-23
# 11  UCL8h3ri2WN_-IbviBlWtUcQ  Film and Animation  2015-10-24
# 12  UCPrFAYA0GkRWnTPqGunt3hg              Comedy  2007-02-05
# 13  UCbxjDfYwfF8RjYBp5htJ38Q  Film and Animation  2008-06-06
# 14  UCC_lO6DJt16KzCGbRrT17Eg              Comedy  2006-05-02
# 15  UCXJL3ST-O0J3nqzQyPJtpNg              Gaming  2010-05-22
# 16  UCXGecfdP4LZs8BMSytOJJqA       Entertainment  2009-01-18
# 17  UC_E54fzF2BPsy7Ig4aDygWA               Music  2006-05-16
# 18  UCNttVtX1_K2kSwKcCgK_Acw              Gaming  2006-11-28
# 19  UCfDoPEgiYTMmraXj8HS7s4g       Entertainment  2006-04-04
#
#                name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  weights
# 0   Beyond The Trailer          853000       5064             19744.0   2.8635
# 1         AMC Theatres          396000       9046             44969.0   3.3400
# 2   Comic Book Girl 19          525000        404             35166.0   3.2045
# 3               KTLA 5          106000       4650            117556.0   4.5950
# 4            DBZanto Z          695000       1852             25053.0   2.9630
# 5                 DUST         1290000        480              9119.0   2.5585
# 6          Paul Davids         1319463        269              9978.0   2.6355
# 7            Stompdown          189000        616             92383.0   3.9140
# 8             q on cbc          164000       2596             96946.0   3.4260
# 9          Alt Shift X         1130000        113             13313.0   2.7875
# 10            wowhobbs          243000       1889             75506.0   3.6245
# 11          CinemaWins         1340000        179             10466.0   2.6410
# 12          Emily Hart          355000        567             51848.0   3.4705
# 13     Warner Bros. UK          748000       2015             21843.0   2.9450
# 14           FND Films          174000        295             99966.0   3.7275
# 15       Preach Gaming          367000       2130             45574.0   3.3410
# 16          Opie Radio          118000       1814            141833.0   5.3095
# 17      RelapseRecords          328000       1472             53650.0   3.5600
# 18                Nyhm          126281         58            133706.0   5.5165
# 19         Kevin Smith          494000        452             34487.0   3.1650

# %% [markdown]
# ### User jumper implementation

# %%
# We randomly choose 3 000 users and for each user we select a random pair of channel
# channels_tuple = [(channel_1, channel_2), (...)]
with open(os.path.join(COMMON_PATH, "channels_tuple_user_walk.pkl"),'rb') as f:
     channels_tuple = pickle.load(f)
f.close()

# %%
files = [PATH]
users_walk_tab, users_walk_tab_new, ranking_position_tab = get_user_walk_and_position_ratio(files, channels_tuple)

# %%
print('User walk = ' + str(users_walk_tab))
print('Ranking position ratio = ' + str(ranking_position_tab))
# Out:
# [0.4285789192126741]
