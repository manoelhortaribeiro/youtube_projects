# %% [markdown]
# ## NOTEBOOK DESCRIPTION:
#
# This notebook checks the behaviour of the embedding space:
# - It first checks manually the nearest neighbors of some selected channels
# - It also compute the user jumper score which is a first barrier on the evaluation of the embedding

# %%
import pickle
import os
import sys
import random

import numpy as np
import pandas as pd


scriptpath = "/home/jouven/youtube_projects/"
sys.path.append(os.path.abspath(scriptpath))

from helpers.helpers_channels_more_300 import *
from helpers.helpers_channel_embedding import *

# %% [markdown]
# ### Useful functions

# %%
# Selected channels and id-index mapping
dict_channel_ind, dict_ind_channel, channels_id = filtered_channels_index_id_mapping()

# %%
PATH = '/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channels_more_300/size_200_sub_0043_neg_35_threshold_20/channel_embedding.npy'

# %%
channelcrawler = pd.read_csv("/dlabdata1/youtube_large/df_channels_en.tsv.gz", sep='\t')
# Select the rows being in the select channels
channelcrawler = channelcrawler[channelcrawler['channel'].apply(lambda row: row in channels_id)]

# %%
channelcrawler.head()
# Out:
#      category_cc   join_date                   channel  \
# 0         Gaming  2010-04-29  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 1      Education  2006-09-01  UCbCmjCuTUZos6Inko4u57UQ
# 2  Entertainment  2006-09-20  UCpEhnqL0y41EpW2TvWAHD7Q
# 3  Howto & Style  2016-11-15  UC295-Dw_tDNtZXFeAPAW6Aw
# 4         Sports  2007-05-11  UCJ5v_MCY6GNUBTO8-D3XoAg
#
#                    name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                PewDiePie       101000000       3956                 3.0
# 1  Cocomelon - Nursery ...        60100000        458                 7.0
# 2                SET India        56018869      32661                 8.0
# 3          5-Minute Crafts        60600000       3591                 9.0
# 4                      WWE        48400000      43421                11.0
#
#    weights
# 0    2.087
# 1    2.087
# 2    2.087
# 3    2.087
# 4    2.087

# %%
channelcrawler['category_cc'].unique()
# Out:
# array(['Gaming', 'Education', 'Entertainment', 'Howto & Style', 'Sports',
#        'Music', 'Film and Animation', 'Comedy', 'Nonprofits & Activism',
#        'People & Blogs', 'News & Politics', 'Science & Technology',
#        'Pets & Animals', 'Autos & Vehicles', 'Travel & Events', nan],
#       dtype=object)

# %% [markdown]
# ### Manually check the neirest neighbors of some selected channels

# %% [markdown]
# First to check how good is the embedding space, we are going to choose a channel and it's k closest channels in the embedding space. By looking at these channels in the YouTube website, we have a sense of how good/bad is the embedding.

# %%
# Looking at the neirest neigbors of `Shaaanxo` being a girl fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCMpOz2KEfkSdd5JeIJh_fxw'], dict_ind_channel, k= 20, embedding_type = 'word2vecf')
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel     category_cc   join_date           name_cc  \
# 0   UCMpOz2KEfkSdd5JeIJh_fxw   Howto & Style  2009-01-18          Shaaanxo
# 1   UC21yq4sq8uxTcfgIxxyE9VQ   Howto & Style  2011-06-27       Carli Bybel
# 2   UCK2ACorzpH-igxuHZ2ObCEA  People & Blogs  2010-03-10      itsJudysLife
# 3   UCz0Qnv6KczUe3NH1wnpmqhA   Howto & Style  2006-11-27  Nicole Guerriero
# 4   UCxj0QizmFhx7kVKSArHBCTA   Howto & Style  2011-03-09      Casey Holmes
# 5   UCZ90tZPn-ue2BmRAcDD88tA   Howto & Style  2010-01-04     Amanda Steele
# 6   UC9TreTE-iXwfwQl72DzDurA   Howto & Style  2009-01-04    Kandee Johnson
# 7   UCTKDB3h5zMdf_2siDHsd_yw           Music  2008-09-26         Cimorelli
# 8   UCJttQwY6KBhwov_2wKywtqA   Howto & Style  2010-06-27    NikkiPhillippi
# 9   UC7u7O4kGomeLwRxh0lhkDaQ   Entertainment  2010-01-04    Lindsey Hughes
# 10  UCERTKUMXl6x8G79BmG6KtpQ   Howto & Style  2010-06-17     Meghan Rienks
# 11  UCDHQbU57NZilrhbuZNbQcRA   Howto & Style  2013-02-27     PatrickStarrr
# 12  UCzco9CewPf0F-SP1p6LhWrw   Howto & Style  2008-07-07     Gigi Gorgeous
# 13  UCIJwWYOfsCfz6PjxbONYXSg   Howto & Style  2009-06-13        blogilates
# 14  UCGiSY-wqHv35wFvivMKlJTA  People & Blogs  2014-06-12     Trisha Paytas
# 15  UCCgDVqiPU10shxzmwkMwJ6A   Howto & Style  2009-09-22     PiinkSparkles
# 16  UC6jgzx2g3nlbaYkd8EMweKA   Howto & Style  2010-09-07       Jaclyn Hill
# 17  UCf5Z8I0Yy0_-a-xAu2_0Yiw   Entertainment  2014-08-04       Sarah Baska
# 18  UCsopuR4Uw3TSA1VPY0MyAfQ   Howto & Style  2009-11-02  Claudia Sulewski
# 19  UCJLCmVUYSbyMGtB2pHOi_QQ   Entertainment  2008-07-27    Andrea Russett
#
#     subscribers_cc  videos_cc  subscriber_rank_sb  weights
# 0          3215340       1422              3566.0   2.2780
# 1          6190000        546              1234.0   2.0870
# 2          1660000       2893              8765.0   2.5830
# 3          2870000        664              4160.0   2.3400
# 4          1770000        730              8208.0   2.5370
# 5          2700000        437              4606.0   2.3870
# 6          3900000        630              2276.0   2.1660
# 7          4980000        631              1593.0   2.0870
# 8          1360000        959             11569.0   2.6770
# 9           928000        705             18726.0   2.8985
# 10         2190000        761              6298.0   2.4700
# 11         4430000        358              2108.0   2.1275
# 12         2910000        513              4079.0   2.3260
# 13         4720000        679              1731.0   2.0870
# 14         1360000        928             11453.0   2.6410
# 15         1170000       1557             13926.0   2.8105
# 16         5890000        344              1348.0   2.0870
# 17         1580000        198              9385.0   2.5940
# 18         2010000        482              6495.0   2.4870
# 19         3020000        406              3829.0   2.2775

# %%
# Looking at the neirest neigbors of `Alex Costa` being a men fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCZyCposXwcyopaACep44maQ'], dict_ind_channel, k= 20, embedding_type = 'word2vecf')
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel           category_cc   join_date  \
# 0   UCZyCposXwcyopaACep44maQ         Howto & Style  2011-09-29
# 1   UCbvIIQc5Jo9-jIXnkPe03oA        People & Blogs  2015-09-19
# 2   UCvcm_wQUH4jvM33JgwVJ5Ew      Autos & Vehicles  2014-09-02
# 3   UCjo7oMbNu181jPBs3_lZIJA                 Music  2014-06-13
# 4   UCbjw-VrJCUb8PTGoiDI2UMw      Autos & Vehicles  2016-01-03
# 5   UCUpC8yomtIEfrTXLjk-wAmw      Autos & Vehicles  2006-08-07
# 6   UCCxawQ5mHZEPP9SvMFar1RA      Autos & Vehicles  2015-05-06
# 7   UCaxW6r282iWvzJmr3BwGc-A      Autos & Vehicles  2015-10-08
# 8   UCvhnYODy6WQ0mw_zi3V1h0g  Science & Technology  2011-10-11
# 9   UCQIyqMWCdx1GBvbw_Yi6lEA                Sports  2006-03-16
# 10  UCCN3j77kPMeQu41gfMNd13A         Entertainment  2009-04-24
# 11  UCKwGZZMrhNYKzucCtTPY2Nw                Sports  2006-08-01
# 12  UCiXH5CLtTt-aZF_BLPGWvcg  Science & Technology  2011-05-25
# 13  UCfcyjCP9MOfYlV6gjR9odKA                Sports  2010-11-18
# 14  UC18WQbNSfrqxlIjKeIW3bGQ  Science & Technology  2014-12-02
# 15  UC6C3PX8hLzueaPWW9nmT85w                 Music  2012-05-15
# 16  UCPy4EQ9HhP-g9xc4yDahhnQ                Gaming  2007-10-08
# 17  UCYwrS5QvBY_JbSdbINLey6Q      Autos & Vehicles  2006-01-14
# 18  UCuSPD9UnPI47_N9lI1jjCGw                Gaming  2012-06-22
# 19  UCF47He8GtRaSHeTvvsyAOrw  Science & Technology  2014-07-30
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                Alex Costa         2120000        543              5370.0
# 1             Matti Haapoja          749000        346             20693.0
# 2          Roads Untraveled          224000        408             79028.0
# 3               Buffet Boys          680000        156             24769.0
# 4                   iamjake          153000        510            104404.0
# 5                   DoctaM3          128000       1145            130835.0
# 6                More Skids          146000        365            116776.0
# 7            Auto Addiction          305592        331             53839.0
# 8               JuanBagnell           94189       1139            161753.0
# 9   Aston Martin Red Bul...          547456        604             29225.0
# 10                Ken Heron           96100        843            156336.0
# 11                 PGA TOUR          477000      16584             36010.0
# 12              Jared Busch          203000        959             81981.0
# 13  Transworld Skateboar...          346000       2920             51395.0
# 14                    ASBYT          628000        584             26360.0
# 15          Bill McClintock           78600         67            164095.0
# 16                  CORSAIR          394000        440             46498.0
# 17                      BMW          955170        901             16819.0
# 18           AreYouFriendly           11100        625            919097.0
# 19              GadgetMatch          461000        380             36670.0
#
#     weights
# 0    2.4170
# 1    2.9325
# 2    3.6720
# 3    2.9495
# 4    4.3545
# 5    4.2310
# 6    4.5795
# 7    3.5170
# 8    5.4665
# 9    2.9935
# 10   5.4695
# 11   3.3125
# 12   4.0130
# 13   3.4685
# 14   2.9960
# 15   5.3510
# 16   3.2980
# 17   2.8130
# 18  18.3450
# 19   3.2250

# %%
# Looking at the neirest neigbors of `Magpiepony` which is a kids film
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCISF5OGuAtSLNF24TKTnXag'], dict_ind_channel, k= 20, embedding_type = 'word2vecf')
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors

# %%
# Looking at neirest neigbors of `Beyond the trailer` a channel for analysis of films
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCAXR2zenCwvRIyQd9ydtfaA'], dict_ind_channel, k= 20, embedding_type = 'word2vecf')
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors

# %% [markdown]
# ### User jumper implementation

# %%
# We randomly choose 3 000 users and for each user we select a random pair of channel
# channels_tuple = [(channel_1, channel_2), (...)]
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_user_walk.pkl",'rb') as f:
     channels_tuple = pickle.load(f)
f.close()

# %%
files = [PATH]
users_walk_tab, users_walk_tab_new, ranking_position_tab = get_user_walk_and_position_ratio(files, channels_tuple)

# %%
print('User walk = ' + str(users_walk_tab))
print("User walk (new way) = " + str(users_walk_tab_new))
print('Ranking position ratio = ' + str(ranking_position_tab))
# Out:
# [0.4285789192126741]
