# %% [markdown]
# ### Statistics on the number of comments per channel

# %%
import time
import pickle
import operator
import sys
import os

import zstandard as zstd
import pandas as pd
import numpy as np

from annoy import AnnoyIndex
from scipy.spatial import distance
from sklearn.metrics.pairwise import cosine_similarity

scriptpath = "../../"
sys.path.append(os.path.abspath(scriptpath))
from helpers.helpers_channels_more_300 import *

# %% [markdown]
# ### Finding cultural axis in our channel embedding

# %%
# Selected channels and id-index mapping
dict_channel_ind, dict_ind_channel, channels_id = filtered_channels_index_id_mapping()

# %%
channelcrawler = pd.read_csv("/dlabdata1/youtube_large/channelcrawler.csv")
channelcrawler['channel_id'] = channelcrawler['link'].str.split('/').str[-1]
channelcrawler = channelcrawler[channelcrawler['channel_id'].apply(lambda row: row in channels_id)]
channelcrawler.head()
# Out:
#              category   join_date  \
# 0  Film and Animation  2017-05-21
# 3               Music  2008-03-17
# 5              Comedy  2017-01-15
# 6              Gaming  2017-05-06
# 7  Film and Animation  2013-12-17
#
#                                                 link              name  \
# 0  http://www.youtube.com/channel/UCBJuEqXfXTdcPS...      MagnusNation
# 3  http://www.youtube.com/channel/UCXhkGgooXHDNwg...      Mago Merlino
# 5  http://www.youtube.com/channel/UCxJWPpPED-J24z...  Magog of Morskar
# 6  http://www.youtube.com/channel/UCNNLaOkE-rcthx...  magoogala gaming
# 7  http://www.youtube.com/channel/UCISF5OGuAtSLNF...        Magpiepony
#
#    subscribers  videos                channel_id
# 0        65100      28  UCBJuEqXfXTdcPSbGO9qqn1g
# 3        14800     838  UCXhkGgooXHDNwgJXmoTSN7g
# 5        29400     158  UCxJWPpPED-J24znoKyKZYjg
# 6       113000     106  UCNNLaOkE-rcthxNssSHET2A
# 7       736000     304  UCISF5OGuAtSLNF24TKTnXag

# %%
'''
Retrieve the array obtained by apllying the dimentionality reduction algorithm
graph_matrix: SHAPE: (channels, n_comp)

PARAMETER:
    - file_path: the path where the embedding graph is stored

RETURN: 
    - df: DataFrame representing the graph in the embedding space
'''
def get_dataframe_in_embedding_space(file_path):
    graph_matrix = np.load(file_path)
    df = pd.DataFrame(graph_matrix)
    df = df.rename(lambda x: 'dr'+str(x), axis='columns')
    df['index'] = np.load('/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channels_more_300/size_200_sub_0043_neg_35_threshold_20/channel_embeddingindex_ordering.npy')
    df = df.sort_values(by=['index'])
    return df.set_index('index')

# %%
'''
    Retrieve the array obtained by apllying the dimentinality reductin algorithm
    graph_matrix: SHAPE: (channels, n_comp)
    
    PARAMETERS:
        - df_embedding: DataFrame representing the channel embedding
        - n_comp: number of components to use after the dimentionalit reduction
        
    RETURN: The annoy index
    '''

def get_annoy_index(df_embedding, n_comp):
    
    index = AnnoyIndex(n_comp, "euclidean")  # Length of item vector that will be indexed
    df_embedding.apply(lambda row: index.add_item(int(row.name), np.array(row)), axis = 1)
    index.build(100) # 100 trees
    return index

# %%
'''
For the given ref_channel, compute it's k neirest neighbor and create pairs of channels between the found channel and ref_channel
PARAMETERS:
    - channels_pairs: table representing the pair of channel already computed
    - ref_channel: the channel on which we compute the neirest neighbor search
    - index: the annoy index to do the k nearest neighbor search
    - k: the number of neighbors 

'''
def create_pairs(channels_pairs, ref_channel, index, k):
    nearest_neighbors = index.get_nns_by_item(ref_channel, k)
    for neighbor_channel in nearest_neighbors:
        channels_pairs.append((ref_channel, neighbor_channel))

# %%
'''
Generate the set of all pairs of channels with their k neirest neighbors
PARAMETERS:
    - df_embedding: DataFrame representing the channel embedding
    - k: the parameter of the nearest neighbor search
    - n_comp: the number of components after applying the dimensionality reduction
RETURN:
    - list of channels tuple 
'''
def channels_with_neighbors_pairs(df_embedding, k, n_comp, seed):
    channels_pairs = []
    index = get_annoy_index(df_embedding, n_comp)
    
    for channel in range(len(df_embedding)):
        if not channel == seed[0] and not channel == seed[1]:
            create_pairs(channels_pairs, channel, index, k)
    return channels_pairs

# %%
'''
Creates the axis vector representing the desired cultural concept which is based on the seed pair.
PARAMETERS:
    - path: the path where the reducted matrix is saved
    - k: the number of neirest neighbor
    - seed: the seed pair representing the base of the axis
    - nb_selected_pairs: number of selected pairs to create the axis
RETURN:
    - All the channels pairs ranked by the cosine similarity metric (from higher to lower)
'''

def compute_axis_vector_based_on_seed(path, k, seed, nb_selected_pairs):
    
    # DataFrame representing the embedding
    df_embedding = get_dataframe_in_embedding_space(path)
    
    n_comp = df_embedding.shape[1]

    channels_pairs = channels_with_neighbors_pairs(df_embedding, k, n_comp, seed)

    vector_diff_channels_pairs = np.array([np.array(df_embedding.iloc[first_vector]) - np.array(df_embedding.iloc[second_vector]) for first_vector, second_vector in channels_pairs])
    vector_diff_seed = (np.array(df_embedding.iloc[seed[0]]) - np.array(df_embedding.iloc[seed[1]]))
    
    # compute cosine similarity score
    similarity_ranked = cosine_similarity(vector_diff_channels_pairs, vector_diff_seed.reshape(1, -1))
    dict_channel_similarity = {}
    for ind in range(len(channels_pairs)):
        dict_channel_similarity[channels_pairs[ind]] = similarity_ranked[ind]
    sorted_similarity_score = sorted(dict_channel_similarity.keys(), key=dict_channel_similarity.get, reverse = True)
    
    return cultural_concept_vector(df_embedding, sorted_similarity_score, vector_diff_seed, nb_selected_pairs)

# %%
'''
The nb_selected_pairs-1 pairs are selected based on the cosine similarity score to end up with nb_pairs_selected 
pairs to create the axis (with the original seed pair).
To create the axis, the vector difference of all nb_pairs_selected are averaged together to obtain a single vector 
for the axis that robustly represents the desired cultural concept.
PARAMETERS:
    - df_embedding: DataFrame representing the channel embedding
    - sorted_similarity_score: list of channel pairs ordered by their cosine similarity score
    - vector_diff_seed: vector difference between the seed pair
    - nb_selected_pairs: number of selected pairs to create the axis
RETURN:
    - Vector for the axis that represents the desired cultural concept
'''

def cultural_concept_vector(df_embedding, sorted_similarity_score, vector_diff_seed, nb_selected_pairs):
    cultural_concept_vectors = []
    
    cultural_concept_vectors.append(vector_diff_seed)
    
    selected_channels_pairs = np.array(sorted_similarity_score[:nb_selected_pairs-1])
    # Print the corresponding channels id
    for pair in selected_channels_pairs:
        print(channelcrawler[channelcrawler['channel_id'].apply(lambda channel_id: channel_id in [dict_ind_channel[pair[0]], dict_ind_channel[pair[1]]])])
   
    for channel_pair in selected_channels_pairs:
        cultural_concept_vectors.append(np.array(df_embedding.iloc[channel_pair[0]]) - np.array(df_embedding.iloc[channel_pair[1]]))
    cultural_concept_vectors = np.array(cultural_concept_vectors)
    return cultural_concept_vectors.mean(axis = 0)

# %% [markdown]
# #### Partisans axis: Democrats vs republican

# %%
#channelcrawler[channelcrawler['name'] == 'The Democrats']
# global movement of one united voice to stand against Trump and his administration.
channelcrawler[channelcrawler['name'] == 'The Democrats']
# Out:
#              category   join_date  \
# 5362  News & Politics  2006-07-27
#
#                                                    link           name  \
# 5362  http://www.youtube.com/channel/UClkO4MArT2WKWj...  The Democrats
#
#       subscribers  videos                channel_id
# 5362        12600     510  UClkO4MArT2WKWj32YDD_-Ew

# %%
channelcrawler[channelcrawler['channel_id'] == 'UCLRYsOHrkk5qcIhtq033bLQ']
# Out:
# Empty DataFrame
# Columns: [category, join_date, link, name, subscribers, videos, channel_id]
# Index: []

# %%
channelcrawler[channelcrawler['name'] == 'Donald J Trump']
#channelcrawler[channelcrawler['name'] == 'Liberal Democrats']
# Out:
#                category   join_date  \
# 151623  News & Politics  2015-03-17
#
#                                                      link            name  \
# 151623  http://www.youtube.com/channel/UCAql2DyGU2un1E...  Donald J Trump
#
#         subscribers  videos                channel_id
# 151623       189000     222  UCAql2DyGU2un1Ei2nMYsqOA

# %%
k = 30
path = '/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channels_more_300/size_200_sub_0043_neg_35_threshold_20/channel_embedding.npy'
partisan_seed = (dict_channel_ind['UClkO4MArT2WKWj32YDD_-Ew'], dict_channel_ind['UCAql2DyGU2un1Ei2nMYsqOA'])
nb_selected_pairs = 10

partisan_axis = compute_axis_vector_based_on_seed(path, k, partisan_seed, nb_selected_pairs)
# Out:
#              category   join_date  \
# 131685  Howto & Style  2013-04-22
# 149830  Entertainment  2015-03-30
#
#                                                      link           name  \
# 131685  http://www.youtube.com/channel/UCMYpyd5l-qep26...  Aneeqa Beauty
# 149830  http://www.youtube.com/channel/UCB9V55-U4cZWcS...   Wilbert Ross
#
#         subscribers  videos                channel_id
# 131685        15700     103  UCMYpyd5l-qep26Q1zRgE-yQ
# 149830       210989      40  UCB9V55-U4cZWcSky65cuhCw
#        category   join_date  \
# 31468     Music  2016-01-21
# 134771    Music  2012-08-13
#
#                                                      link          name  \
# 31468   http://www.youtube.com/channel/UCmNSoJCouaKT_c...    Skrt Video
# 134771  http://www.youtube.com/channel/UCQFicwEyxv3P9Z...  SniizahMusic
#
#         subscribers  videos                channel_id
# 31468         25200      17  UCmNSoJCouaKT_cgxipipzGw
# 134771        55433     322  UCQFicwEyxv3P9ZkpglSZd0g
#              category   join_date  \
# 64420       Education  2009-05-10
# 147340  Entertainment  2011-08-04
#
#                                                      link  \
# 64420   http://www.youtube.com/channel/UChqTAS8GVF1TM3...
# 147340  http://www.youtube.com/channel/UCg7HSihKy8HoWs...
#
#                            name  subscribers  videos                channel_id
# 64420   Tradesman's Shop Tal...        19139     759  UChqTAS8GVF1TM3pFyxvnPxg
# 147340          The Horror Guru        18500     250  UCg7HSihKy8HoWsc0BOpiIXw
#         category   join_date  \
# 89895  Education  2006-04-02
# 93961      Music  2014-09-13
#
#                                                     link  \
# 89895  http://www.youtube.com/channel/UCqvaXJ1K3HheTP...
# 93961  http://www.youtube.com/channel/UCeZPWFxEwKf0gD...
#
#                           name  subscribers  videos                channel_id
# 89895  Principles by Ray Da...       305770      34  UCqvaXJ1K3HheTPNjH-KpwXQ
# 93961           Metal Vault II        45200    2010  UCeZPWFxEwKf0gD2uNV_3I6A
#                   category   join_date  \
# 38909   Film and Animation  2015-01-31
# 151377       Entertainment  2007-09-10
#
#                                                      link         name  \
# 38909   http://www.youtube.com/channel/UCS64RGiiU36DtF...  Flaire Xrei
# 151377  http://www.youtube.com/channel/UCv4EV3JvST7BDJ...      TLITD31
#
#         subscribers  videos                channel_id
# 38909         46300      12  UCS64RGiiU36DtFzyqTJhSSw
# 151377        16300     236  UCv4EV3JvST7BDJt_VRGhYsg
#               category   join_date  \
# 97513            Music  2011-04-19
# 116504  People & Blogs  2012-05-20
#
#                                                      link  \
# 97513   http://www.youtube.com/channel/UCh4yuJ6aBug9gm...
# 116504  http://www.youtube.com/channel/UC-yhMfYO1KU_lY...
#
#                            name  subscribers  videos                channel_id
# 97513   Inner Wound Recordin...        41700      80  UCh4yuJ6aBug9gmW3rNAZqQQ
# 116504                    Gamer        21200      23  UC-yhMfYO1KU_lYzGAXRlNEQ
#             category   join_date  \
# 4574          Sports  2006-09-01
# 50058  Howto & Style  2006-09-17
#
#                                                     link               name  \
# 4574   http://www.youtube.com/channel/UCxJ_Liuzh6kPdo...  Evike.com Airsoft
# 50058  http://www.youtube.com/channel/UCGtGTAa-xarr2H...        Peter Draws
#
#        subscribers  videos                channel_id
# 4574        411000    1435  UCxJ_Liuzh6kPdok1bIk4zEA
# 50058       772000     793  UCGtGTAa-xarr2HrEKRgRUHQ
#                   category   join_date  \
# 38161   Film and Animation  2014-10-05
# 133924               Music  2017-04-10
#
#                                                      link            name  \
# 38161   http://www.youtube.com/channel/UCLE5w7fCKZegO4...         Amichie
# 133924  http://www.youtube.com/channel/UCt-2I5mGu0jhj6...  NicoSantosVEVO
#
#         subscribers  videos                channel_id
# 38161         11700      55  UCLE5w7fCKZegO4TMyZBOP1g
# 133924        67800      15  UCt-2I5mGu0jhj6coClrgvkw
#              category   join_date  \
# 115376  Entertainment  2017-03-31
# 126753          Music  2015-12-01
#
#                                                      link  \
# 115376  http://www.youtube.com/channel/UC2i8njKuW6P3On...
# 126753  http://www.youtube.com/channel/UCRapJI2zQJer5B...
#
#                            name  subscribers  videos                channel_id
# 115376  Tayo Toys & Titipo T...       125000     480  UC2i8njKuW6P3OnBMfgFt68g
# 126753               Jonny Vice        23200      60  UCRapJI2zQJer5Bho2GDJh-Q

# %% [markdown]
# #### Gender axis: men vs women

# %%
# Here you will find everything about: Men's Fashion, Hairstyle, Fitness & Health, Personal Vlogs and Tech.
channelcrawler[channelcrawler['name'] == 'Alex Costa']
# Out:
#             category   join_date  \
# 70695  Howto & Style  2011-09-29
#
#                                                     link        name  \
# 70695  http://www.youtube.com/channel/UCZyCposXwcyopa...  Alex Costa
#
#        subscribers  videos                channel_id
# 70695      2120000     543  UCZyCposXwcyopaACep44maQ

# %%
# vlog channel about make up, hair transformation, rings selections, ...
channelcrawler[channelcrawler['name'] == 'Shaaanxo']
# Out:
#             category   join_date  \
# 38863  Howto & Style  2009-01-18
#
#                                                     link      name  \
# 38863  http://www.youtube.com/channel/UCMpOz2KEfkSdd5...  Shaaanxo
#
#        subscribers  videos                channel_id
# 38863      3215340    1422  UCMpOz2KEfkSdd5JeIJh_fxw

# %%
k = 30
#path = '/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channel_embedding.npy'
gender_seed = (dict_channel_ind['UCZyCposXwcyopaACep44maQ'], dict_channel_ind['UCMpOz2KEfkSdd5JeIJh_fxw'])
nb_selected_pairs = 10

gender_axis = compute_axis_vector_based_on_seed(path, k, gender_seed, nb_selected_pairs)
# Out:
#               category   join_date  \
# 110842           Music  2014-04-14
# 153979  People & Blogs  2014-12-26
#
#                                                      link           name  \
# 110842  http://www.youtube.com/channel/UCa_pp2zu1q971V...  Gaëtan Piolot
# 153979  http://www.youtube.com/channel/UCchN_MaC3-cBvj...      It'sMisty
#
#         subscribers  videos                channel_id
# 110842        24600      12  UCa_pp2zu1q971VM2yPzHEhg
# 153979        19300      87  UCchN_MaC3-cBvjvejCiMtmw
#               category   join_date  \
# 90080   People & Blogs  2018-05-07
# 157811   Howto & Style  2006-04-04
#
#                                                      link         name  \
# 90080   http://www.youtube.com/channel/UCaKE-yVmrJkmsO...         JEPH
# 157811  http://www.youtube.com/channel/UCnDqSqP8Lbn0_K...  metaspencer
#
#         subscribers  videos                channel_id
# 90080         14600      24  UCaKE-yVmrJkmsOXkvFTbHZg
# 157811        25200     242  UCnDqSqP8Lbn0_KU5iqFeA0A
#               category   join_date  \
# 98398            Music  2014-09-04
# 154778  People & Blogs  2006-07-15
#
#                                                      link          name  \
# 98398   http://www.youtube.com/channel/UCglKgxZZschp8n...  Channel Five
# 154778  http://www.youtube.com/channel/UCmIjyvIsv06SBa...       Photour
#
#         subscribers  videos                channel_id
# 98398         41500     126  UCglKgxZZschp8nsBRhMS5Zg
# 154778        10500      59  UCmIjyvIsv06SBakHlEc8gaA
#       category   join_date                                               link  \
# 32622    Music  2008-10-16  http://www.youtube.com/channel/UC-ZaFVre7Koir_...
# 62255    Music  2015-08-09  http://www.youtube.com/channel/UCFkkWd8IRCKkMU...
#
#                     name  subscribers  videos                channel_id
# 32622  Mihran Kirakosian      1720000     425  UC-ZaFVre7Koir_VcaM2LpNA
# 62255     StardustLegend        10700     156  UCFkkWd8IRCKkMUztMBtKtVQ
#                     category   join_date  \
# 28459   Science & Technology  2013-08-05
# 153256      Autos & Vehicles  2008-10-28
#
#                                                      link                name  \
# 28459   http://www.youtube.com/channel/UCD5rA0EFcxjr7L...  Goodnature Limited
# 153256  http://www.youtube.com/channel/UCYXvCcDgRi5RNb...        RC CAR HOBBY
#
#         subscribers  videos                channel_id
# 28459         10700      41  UCD5rA0EFcxjr7La2CNTMSSg
# 153256       241924     847  UCYXvCcDgRi5RNb1Zi4Yz-aA
#                  category   join_date  \
# 5400               Gaming  2007-08-22
# 74738  Film and Animation  2017-01-04
#
#                                                     link            name  \
# 5400   http://www.youtube.com/channel/UCJm8Zrooq9qsge...  DistantKingdom
# 74738  http://www.youtube.com/channel/UCchUOUW-eNmDfD...         AniNews
#
#        subscribers  videos                channel_id
# 5400         29500      89  UCJm8Zrooq9qsgefMlVRtzRg
# 74738       216000     204  UCchUOUW-eNmDfDqMS_AiZew
#              category   join_date  \
# 16499          Gaming  2010-08-27
# 148508  Entertainment  2016-09-27
#
#                                                      link  \
# 16499   http://www.youtube.com/channel/UCnwZZHboukKCsM...
# 148508  http://www.youtube.com/channel/UCP9FOft3cfPhI_...
#
#                            name  subscribers  videos                channel_id
# 16499             TheBlueDragon        13900    6445  UCnwZZHboukKCsMSXYUVRCwA
# 148508  The Voice Masterpiec...       182000      95  UCP9FOft3cfPhI_fLTgT1hjQ
#               category   join_date  \
# 150457  People & Blogs  2010-04-18
# 150466   Howto & Style  2010-08-26
#
#                                                      link              name  \
# 150457  http://www.youtube.com/channel/UCxKZqdMKI3zJuV...  MissBudgetBeauty
# 150466  http://www.youtube.com/channel/UCOZW0cTQOlOeHK...        MissDarcei
#
#         subscribers  videos                channel_id
# 150457        98000    1283  UCxKZqdMKI3zJuVL6mLQTg0w
# 150466       291228     416  UCOZW0cTQOlOeHKk_8kvGguQ
#              category   join_date  \
# 20051   Entertainment  2013-06-19
# 110367         Gaming  2011-12-15
#
#                                                      link             name  \
# 20051   http://www.youtube.com/channel/UCkDwvl7tdpht_I...  Broken Rainbows
# 110367  http://www.youtube.com/channel/UCgv1lXQsIDC8vw...      GhenryPerez
#
#         subscribers  videos                channel_id
# 20051         64300      55  UCkDwvl7tdpht_IGiPPIsUAg
# 110367        26000      72  UCgv1lXQsIDC8vwo47ov_Svg

# %% [markdown]
# #### Age axis: kids vs adult

# %%
#channelcrawler[channelcrawler['name'] == "TED-Ed"]
channelcrawler[channelcrawler['name'] == "Magpiepony"]
# Out:
#              category   join_date  \
# 7  Film and Animation  2013-12-17
#
#                                                 link        name  subscribers  \
# 7  http://www.youtube.com/channel/UCISF5OGuAtSLNF...  Magpiepony       736000
#
#    videos                channel_id
# 7     304  UCISF5OGuAtSLNF24TKTnXag

# %%
# Conferences/talk channel
channelcrawler[channelcrawler['name'] == 'James Bond 007']
# Out:
#                 category   join_date  \
# 5561  Film and Animation  2005-11-27
#
#                                                    link            name  \
# 5561  http://www.youtube.com/channel/UCwTkM6CvIsYFaF...  James Bond 007
#
#       subscribers  videos                channel_id
# 5561       115000     407  UCwTkM6CvIsYFaFiMKIKCqHw

# %%
k = 30
age_seed = (dict_channel_ind['UCISF5OGuAtSLNF24TKTnXag'], dict_channel_ind['UCwTkM6CvIsYFaFiMKIKCqHw'])
nb_selected_pairs = 10

age_axis = compute_axis_vector_based_on_seed(path, k, age_seed, nb_selected_pairs)
# Out:
#       category   join_date                                               link  \
# 46771   Sports  2009-12-05  http://www.youtube.com/channel/UCM4GEVa1Qi1CTd...
# 54898    Music  2007-06-14  http://www.youtube.com/channel/UCsq3H3cTxvDU1M...
#
#                    name  subscribers  videos                channel_id
# 46771  overtimeathletes       221000     716  UCM4GEVa1Qi1CTdJg0ljdoow
# 54898       Dr. Peacock       319585     307  UCsq3H3cTxvDU1Mktk1DQVkA
#              category   join_date  \
# 7110    Entertainment  2018-04-07
# 163921          Music  2016-09-12
#
#                                                      link            name  \
# 7110    http://www.youtube.com/channel/UC_QhMn47x9IS3v...  العاب سيمب�...
# 163921  http://www.youtube.com/channel/UC3CQLAsPXQ04pN...     MikeReyesTv
#
#         subscribers  videos                channel_id
# 7110         321000     242  UC_QhMn47x9IS3vpwQ27OhMA
# 163921        13200      22  UC3CQLAsPXQ04pNJ8uxJY2Hw
#                category   join_date  \
# 39137   News & Politics  2012-09-10
# 148919    Entertainment  2010-09-09
#
#                                                      link              name  \
# 39137   http://www.youtube.com/channel/UCiDa1Pvau5HpDl...  DarkSkyWatcher74
# 148919  http://www.youtube.com/channel/UCGA3SEYffk1E7_...        GZ Battles
#
#         subscribers  videos                channel_id
# 39137        102000     751  UCiDa1Pvau5HpDlGhb9hjuKA
# 148919        26961     871  UCGA3SEYffk1E7_ZS25wU1oA
#               category   join_date  \
# 132063  People & Blogs  2011-07-10
# 159896   Howto & Style  2011-02-05
#
#                                                      link  \
# 132063  http://www.youtube.com/channel/UCy_gglX3z2eHby...
# 159896  http://www.youtube.com/channel/UCqTUW5RJ0ifQZG...
#
#                            name  subscribers  videos                channel_id
# 132063               Team Dolan        37600      11  UCy_gglX3z2eHbyz3Cf-77Hw
# 159896  OfficialMonroeBrooKe...       169000      33  UCqTUW5RJ0ifQZG0jMcggxaA
#        category   join_date  \
# 69804    Gaming  2014-10-01
# 111555   Gaming  2013-09-25
#
#                                                      link          name  \
# 69804   http://www.youtube.com/channel/UCWd2KKUE6fNwZM...   DaintierFox
# 111555  http://www.youtube.com/channel/UCAIiXY14xY_TbW...  VictionaryHD
#
#         subscribers  videos                channel_id
# 69804        173000     563  UCWd2KKUE6fNwZM4BK9Ia1HQ
# 111555       222000     912  UCAIiXY14xY_TbWCBNG5mdGw
#                      category   join_date  \
# 4977                   Gaming  2016-07-05
# 151293  Nonprofits & Activism  2018-02-11
#
#                                                      link          name  \
# 4977    http://www.youtube.com/channel/UCmpVVlSr3344gq...    David Jake
# 151293  http://www.youtube.com/channel/UCOvsddMQ8Jx_-n...  Gospel Hymns
#
#         subscribers  videos                channel_id
# 4977          22100      67  UCmpVVlSr3344gqCyZMhHj1w
# 151293        47800      38  UCOvsddMQ8Jx_-nOOf858WIA
#               category   join_date  \
# 120178  People & Blogs  2018-01-13
# 128975  People & Blogs  2015-03-03
#
#                                                      link                name  \
# 120178  http://www.youtube.com/channel/UCUIW7pRqcIv6JP...  The Radford Family
# 128975  http://www.youtube.com/channel/UCgXJ-z1YU2M7Rc...       DIYeasycrafts
#
#         subscribers  videos                channel_id
# 120178        81000      93  UCUIW7pRqcIv6JPgEL4-SyUQ
# 128975        45400     295  UCgXJ-z1YU2M7RcWcFp-hXhA
#               category   join_date  \
# 1143     Entertainment  2010-12-13
# 120737  People & Blogs  2016-08-16
#
#                                                      link  \
# 1143    http://www.youtube.com/channel/UCtd7A9Qci1vIIK...
# 120737  http://www.youtube.com/channel/UCOMXUnDnd669B_...
#
#                            name  subscribers  videos                channel_id
# 1143                  iAndrawiz       227000      27  UCtd7A9Qci1vIIK7_tgybIFg
# 120737  Glenn Rottmann Your ...        14300      24  UCOMXUnDnd669B_9yAIvejrw
#        category   join_date  \
# 110196   Gaming  2018-06-27
# 118122    Music  2016-08-13
#
#                                                      link      name  \
# 110196  http://www.youtube.com/channel/UCsXC5pbulJpPGx...     Ehmak
# 118122  http://www.youtube.com/channel/UCL61u-DSWrWSgO...  Carlitos
#
#         subscribers  videos                channel_id
# 110196        26400      26  UCsXC5pbulJpPGxUNCUDsYYg
# 118122        16700      49  UCL61u-DSWrWSgO5Q5EPtl_A
