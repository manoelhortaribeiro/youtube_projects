# %% [markdown]
# This notebook checks the behaviour of the embedding space

# %%
import re
import os
import sys
import pickle
import random
import glob
import scipy.sparse

import numpy as np
import pandas as pd

from annoy import AnnoyIndex
from scipy.spatial import distance

scriptpath = "../../"
sys.path.append(os.path.abspath(scriptpath))
from helpers.helpers_channels_more_300 import *

# %%
haha = pd.DataFrame([(1, 2), (4, 5), (6, 7), (8, 9)])

# %%
sel = set([1, 2, 4])

# %%
(haha[0].isin(sel)) & (haha[1].isin(sel))
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
haha.loc[(haha[0].isin(sel)) & (haha[1].isin(sel))]
# Out:
#    0  1
# 0  1  2

# %%
'''
Retrieve the array obtained by apllying the dimentionality reduction algorithm
graph_matrix: SHAPE: (channels, n_comp)

PARAMETER:
    - file_path: the path where the embedding graph is stored

RETURN: 
    - df: DataFrame representing the graph in the embedding space
'''
def get_dataframe_in_embedding_space(file_path):
    graph_matrix = np.load(file_path)
    df = pd.DataFrame(graph_matrix)
    df = df.rename(lambda x: 'dr'+str(x), axis='columns')
    df['index'] = np.load('/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channels_more_300/size_200_sub_0043_neg_35_threshold_10/channel_embeddingindex_ordering.npy').astype(int)
    df = df.sort_values(by=['index'])
    return df.set_index('index')

# %%
# Selected channels and id-index mapping
dict_channel_ind, dict_ind_channel, channels_id = filtered_channels_index_id_mapping()

# %% [markdown]
# ### Find k closest channels using annoy library

# %% [markdown]
# First to check how good is the embedding space, we are going to choose a channel and it's k closest channels in the embedding space. By looking at these channels in the YouTube website, we should get similar channels if the embedding space is good.

# %%
channelcrawler = pd.read_csv("/dlabdata1/youtube_large/channelcrawler.csv")
channelcrawler['channel_id'] = channelcrawler['link'].str.split('/').str[-1]
channelcrawler.head()
# Out:
#              category   join_date  \
# 0  Film and Animation  2017-05-21
# 1       Entertainment  2011-12-13
# 2               Music  2013-09-13
# 3               Music  2008-03-17
# 4       Entertainment  2014-10-19
#
#                                                 link                     name  \
# 0  http://www.youtube.com/channel/UCBJuEqXfXTdcPS...             MagnusNation
# 1  http://www.youtube.com/channel/UCkNW9Q1VR_aeZ6...  Mago Dario Animazion...
# 2  http://www.youtube.com/channel/UC1xcnrpcF59FWW...       Mägo de Oz - Topic
# 3  http://www.youtube.com/channel/UCXhkGgooXHDNwg...             Mago Merlino
# 4  http://www.youtube.com/channel/UCvZGsuvKlYOGiZ...               MAGO TOMÁS
#
#    subscribers  videos                channel_id
# 0        65100      28  UCBJuEqXfXTdcPSbGO9qqn1g
# 1        60200      48  UCkNW9Q1VR_aeZ6uht83jJVQ
# 2        40200     395  UC1xcnrpcF59FWWELtZvJTdg
# 3        14800     838  UCXhkGgooXHDNwgJXmoTSN7g
# 4        26200      31  UCvZGsuvKlYOGiZTsxwJNS5Q

# %%
channelcrawler = channelcrawler[channelcrawler['channel_id'].apply(lambda row: row in channels_id)]

# %%
channelcrawler['category'].unique()
# Out:
# array(['Film and Animation', 'Music', 'Comedy', 'Gaming',
#        'Science & Technology', 'Sports', 'Entertainment', 'Education',
#        'Nonprofits & Activism', 'People & Blogs', 'Howto & Style',
#        'News & Politics', 'Travel & Events', 'Autos & Vehicles',
# 2765            CircleToonsHD      1000000     149  UCV6g95OBbVtFmN9uiJzkFqQ
# 2790       Mad Desires Studio       184000     158  UC-uaP4yRyHDoVZOX25y-KFA
# 2810                   rokamo        59400      80  UCWO5oyxM_J18-Fs11RFKmow
# 2828  FavoriteFandom Edits...        14555      35  UCEDnn2rjuGwim9Tv1KwMpJw
# 2832  POCOYO in ENGLISH fu...       385000     479  UC34mvxbzl-tk5AXpFaQksWg
# 2833  POCOYO in ENGLISH fu...      1880000     762  UCdknlZNiH-2VWrvjXkx9dJA

# %%
'''
    Retrieve the array obtained by apllying the dimentinality reductin algorithm
    graph_matrix: SHAPE: (channels, n_comp)
    
    PARAMETERS:
        - df_embedding: DataFrame representing the graph in the embedding space
        
    RETURN: The annoy index
    '''
def get_annoy_index(df):
    index = AnnoyIndex(df.shape[1], "euclidean")  # Length of item vector that will be indexed
    df.apply(lambda row: index.add_item(row.name, np.array(row)), axis = 1)
    index.build(100) # 100 trees
    return index

# %%
def get_k_nearest_neighbors(path, ref_index_channel, k = 20):
    df = get_dataframe_in_embedding_space(path)
    index = get_annoy_index(df)
    nearest_neighbors_index = index.get_nns_by_item(ref_index_channel, k, search_k = 100000000)
    nearest_neighbors_id = [dict_ind_channel[val] for val in nearest_neighbors_index]
    return nearest_neighbors_id

# %%
dict_channel_ind['UCLFW3EKD2My9swWH4eTLaYw']
# Out:
# 45013

# %%
path = '/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channels_more_300/size_200_sub_0043_neg_35_threshold_10/channel_embedding.npy'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCMpOz2KEfkSdd5JeIJh_fxw'], k= 40)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-04b51ab48a88> in <module>
#       1 path = '/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channels_more_300/size_200_sub_0043_neg_35_threshold_10/channel_embedding.npy'
# ----> 2 nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCMpOz2KEfkSdd5JeIJh_fxw'], k= 40)
#       3 nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
#       4 nearest_neighbors
#
# <ipython-input-9-7d237c4c0101> in get_k_nearest_neighbors(path, ref_index_channel, k)
#       1 def get_k_nearest_neighbors(path, ref_index_channel, k = 20):
# ----> 2     df = get_dataframe_in_embedding_space(path)
#       3     index = get_annoy_index(df)
#       4     nearest_neighbors_index = index.get_nns_by_item(ref_index_channel, k, search_k = 100000000)
#       5     nearest_neighbors_id = [dict_ind_channel[val] for val in nearest_neighbors_index]
#
# <ipython-input-2-7940bb858780> in get_dataframe_in_embedding_space(file_path)
#      10 '''
#      11 def get_dataframe_in_embedding_space(file_path):
# ---> 12     graph_matrix = np.load(file_path)
#      13     df = pd.DataFrame(graph_matrix)
#      14     df = df.rename(lambda x: 'dr'+str(x), axis='columns')
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: '/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channels_more_300/size_200_sub_0043_neg_35_threshold_10/channel_embedding.npy'

# %%
path = '/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channel_embedding.npy'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCZyCposXwcyopaACep44maQ'], k= len(channels_id)-1)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
# Out:
# Chloe Morello  52419
# Lauren Curtis  52969
# Shanxo  55894

# %%
nearest_neighbors[55894:55894+50]
# Out:
#                      channel_id            category   join_date  \
# 55894  UCMpOz2KEfkSdd5JeIJh_fxw       Howto & Style  2009-01-18
# 55895  UCf8w5m0YsRa8MHQ5bwSGmbw     News & Politics  2008-09-25
# 55896  UCv3rFzn-GHGtqzXiaq3sWNg     News & Politics  2012-06-01
# 55897  UCX9hgl0cGni5PLcNKzs0TSg      People & Blogs  2015-12-09
# 55898  UC-x0MrgC8evQZ5CKC4RjGKg       Entertainment  2017-08-04
# 28  http://www.youtube.com/channel/UCxZMOY2RdtK6LQ...
# 29  http://www.youtube.com/channel/UC3o7kbpTUQ5-0W...
# 30  http://www.youtube.com/channel/UCbBm6SZ235HFxw...
# 31  http://www.youtube.com/channel/UC1dVGItBqV4w-4...
# 32  http://www.youtube.com/channel/UCUUWDzrkuEztzd...
# 33  http://www.youtube.com/channel/UCIdKjWk5gp0N0M...
# 34  http://www.youtube.com/channel/UCKgAB8lqTbqbwX...
# 35  http://www.youtube.com/channel/UCq7-f1dGAoUNUS...
# 36  http://www.youtube.com/channel/UC4-AGCUwX7C-D4...
# 37  http://www.youtube.com/channel/UClmFQfVyDvdtCr...
# 38  http://www.youtube.com/channel/UCXN7rPhZK6Rp8l...
# 39  http://www.youtube.com/channel/UCqxzXCQqNQ9wSw...
# 40  http://www.youtube.com/channel/UCWuFgIcy1Q9TYd...
# 41  http://www.youtube.com/channel/UCWCtoOXSwTcbVj...
# 42  http://www.youtube.com/channel/UCTln5ss6h6L_xN...
# 43  http://www.youtube.com/channel/UCVlD5RMKD1bv-J...
# 44  http://www.youtube.com/channel/UCwJB9Z1L0aPIum...
# 45  http://www.youtube.com/channel/UCLmEFIwfG3HSru...
# 46  http://www.youtube.com/channel/UClqXcJew_A3s8q...
# 47  http://www.youtube.com/channel/UCsWnDtLWKEMJHK...
# 48  http://www.youtube.com/channel/UCgV3JnAlwJmkz0...
# 49  http://www.youtube.com/channel/UCp7zzDMR-77qQx...
#
#                        name  subscribers  videos
# 0            Donald J Trump       189000     222
# 1        seattletimesdotcom        29100    3588
# 2       The Western Journal        82400    1154
# 3          MAGAtruthChannel        43300      39
# 4              GOP War Room        42500    6496
# 5   Conservative Tribune...        31100    1707
# 6                CBS Boston        63500   31634
# 7              Daily Caller       135000    1050
# 8          POTUS Trump MAGA        27000    1705
# 9          LIVE ON-AIR NEWS        78100     354
# 10                     kxan        65900   62800
# 11            Savage Nation        61300      80
# 12             syracuse.com        27700    6137
# 13          Maureen Dowling        14000    4698
# 14       We the Internet TV       118000     354
# 15      The American Mirror        10500     329
# 16        Turning Point USA       156000     884
# 17                Daily Kos        10800     878
# 18  KPIX CBS SF Bay Area...       124000   24570
# 19               Bud Meyers        10422    1509
# 20         The Daily Signal        36500    1097
# 21       Red Eagle Politics        10500      97
# 22               Newsmax TV       138000   26820
# 23           Breitbart News       137000    2210
# 24                  KARE 11        22700   15792
# 25             PennLive.com        20000   15588
# 26            ABC15 Arizona       175000   71190
# 27         Bloomberg TicToc        65085    2873
# 28           CBS Sacramento        29300   17260
# 29                      GOP        68700     969
# 30               News2Share        31100    1117
# 31                   CBS 17        37400   27875
# 32                   NJ.com       169000   22974
# 33          John Donne Show        25400    1437
# 34                 KGW News        22119   17172
# 35                   Mark F        33200    1015
# 36                    YAFTV       191000    1263
# 37                    MLive       171000   32544
# 38                   KOIN 6        45900   38149
# 39       Domination Station        58000      74
# 40        Jonathan Schwartz        40200      26
# 41         Washington Watch        25000     164
# 42                    Newsy       146000   23498
# 43  American Conservativ...        32500    1577
# 44             fakeengineer        30500      96
# 45       Triggered Newscast        31600     146
# 46  Congressman Matt Gae...        11100     863
# 47             Laura Loomer        86900     126
# 48        THE LIBERTY DAILY        22600    2688
# 49      The Redneck Patriot        38900     486

# %%
path = '/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channel_embedding.npy'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['
# 18  http://www.youtube.com/channel/UC0WrrEOqUyDesO...
# 19  http://www.youtube.com/channel/UC72UssJ1DNQcak...
#
#                        name  subscribers  videos
# 0       A Blue Dot In Texas        10600     646
# 1                Julia Blog        10300     376
# 2   Tony Dortie - 24/7 E...        98700     333
# 3            Be Less Stupid        52100     309
# 4              Robert Reich       149000     221
# 5          Washington Watch        25000     164
# 6            Parody Project        50400      99
# 7                 WGBH News        17700    5938
# 8                 Brad Reed        13600     935
# 9                 Daily Kos        10800     878
# 10             PBS NewsHour      1380000   26035
# 11  Let The Madness Begi...        15700     630
# 12               Bud Meyers        10422    1509
# 13                  WMUR-TV        33300   53197
# 14  Andrew Yang for Pres...        90761      79
# 15                 Newsweek        19800    2789
# 16                Roll Call        12800    2590
# 17       Red Eagle Politics        10500      97
# 18             Sarah Burris        14800     368
# 19  WCVB Channel 5 Bosto...        53000   38396

# %%
path = '/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channel_embedding.npy'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCAuUUnT6oDeKwE6v1NGQxug'], k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
# 57004
#                   channel_id               category   join_date  \
# 0   UCAuUUnT6oDeKwE6v1NGQxug         People & Blogs  2006-12-06
# 1   UCsT0YIqwnpJCM-mx7-gSA4Q  Nonprofits & Activism  2009-06-23
# 2   UCvQECJukTDE2i6aCoMnS-Vg              Education  2006-10-01
# 3   UCHnyfMqiRRG1u-2MsSQLbXA              Education  2010-07-21
# 4   UCqnbDFdCpuN8CMEg0VuEBqA        News & Politics  2006-10-13
# 5   UCpVm7bg6pXKo1Pr6k5kxG9A          Entertainment  2006-05-07
# 6   UC7IcJI8PUf5Z3zKxnZvTBog              Education  2010-05-18
# 7   UCLXo7UDZvByw2ixzpQCufnA        News & Politics  2014-03-04
# 8   UC3XTzVzaHQEd30rQbuvCtTQ          Entertainment  2014-03-18
# 9   UCX6b17PVsYBQ0ip5gyeme-Q              Education  2006-05-20
# 10  UCftwRNsjfRo08xYE31tkiyw   Science & Technology  2005-09-23
# 11  UCsXVk37bltHxD1rDPwtNM8Q              Education  2013-07-09
# 12  UCoxcjq-8xIDTYp3uz647V5A   Science & Technology  2011-09-15
# 13  UC6107grRI4m0o2-emgoDnAA   Science & Technology  2006-04-04
# 14  UCC552Sd-3nyi_tk2BudLUzA              Education  2012-05-28
# 15  UC64UiPJwM_e9AqAd7RiD7JA              Education  2011-10-13
# 16  UCcyq283he07B7_KUX07mmtA        News & Politics  2009-10-02
# 17  UCK7tptUDHh-RYDsdxO1-5QQ        News & Politics  2007-06-18
# 18  UCUHW94eEFW7hkUMVaZz4eDg   Science & Technology  2011-06-20
# 19  UCUsN5ZwHx2kILm84-jPDeXw                 Comedy  2006-06-14
#
#                                                  link                   name  \
# 0   http://www.youtube.com/channel/UCAuUUnT6oDeKwE...                    TED
# 1   http://www.youtube.com/channel/UCsT0YIqwnpJCM-...             TEDx Talks
# 2   http://www.youtube.com/channel/UCvQECJukTDE2i6...              Big Think
# 3   http://www.youtube.com/channel/UCHnyfMqiRRG1u-...             Veritasium
# 4   http://www.youtube.com/channel/UCqnbDFdCpuN8CM...     The New York Times
# 5   http://www.youtube.com/channel/UCpVm7bg6pXKo1P...    National Geographic
# 6   http://www.youtube.com/channel/UC7IcJI8PUf5Z3z...     The School of Life
# 7   http://www.youtube.com/channel/UCLXo7UDZvByw2i...                    Vox
# 8   http://www.youtube.com/channel/UC3XTzVzaHQEd30...        LastWeekTonight
# 9   http://www.youtube.com/channel/UCX6b17PVsYBQ0i...            CrashCourse
# 10  http://www.youtube.com/channel/UCftwRNsjfRo08x...                  WIRED
# 11  http://www.youtube.com/channel/UCsXVk37bltHxD1...  Kurzgesagt – In a ...
# 12  http://www.youtube.com/channel/UCoxcjq-8xIDTYp...            Numberphile
# 13  http://www.youtube.com/channel/UC6107grRI4m0o2...        SmarterEveryDay
# 14  http://www.youtube.com/channel/UCC552Sd-3nyi_t...            AsapSCIENCE
# 15  http://www.youtube.com/channel/UC64UiPJwM_e9Aq...      Today I Found Out
# 16  http://www.youtube.com/channel/UCcyq283he07B7_...       Business Insider
# 17  http://www.youtube.com/channel/UCK7tptUDHh-RYD...    Wall Street Journal
# 18  http://www.youtube.com/channel/UCUHW94eEFW7hkU...          minutephysics
# 19  http://www.youtube.com/channel/UCUsN5ZwHx2kILm...         Comedy Central
#
#     subscribers  videos
# 0      14800000    3105
# 1      20700000  141627
# 2       2650000   11135
# 3       6370000     280
# 4       2150000    9619
# 5      12300000    9260
# 6       4870000     724
# 7       6570000    1048
# 8       7240000     286
# 9       9800000    1160
# 10      5100000    2902
# 11      9630035     105
# 12      3030000     537
# 13      7270000     309
# 14      8800000     317
# 15      2070000    1472
# 16      2040000    4680
# 17      1630000   25937
# 18      4790000     241
# 19      8540000    4818

# %%
path = '/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channel_embedding.npy'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCwTkM6CvIsYFaFiMKIKCqHw'], k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
# 57004
#                   channel_id              category   join_date  \
# 0   UCwTkM6CvIsYFaFiMKIKCqHw    Film and Animation  2005-11-27
# 1   UCwQJJVNbn_Tqze89xf83nhw         Entertainment  2007-09-12
# 2   UCFSILgKCKo35QYGz8Kob51g    Film and Animation  2008-01-03
# 3   UCwSIJCMWZC5GDM59wj7pMsg         Entertainment  2006-05-21
# 4   UCX8yUJVv_GCpBNw7yp1Y_4Q                Comedy  2006-10-23
# 5   UCSi5779nMiFTbLm3prHaa1g    Film and Animation  2008-01-15
# 6   UC1AJxP0vC_yqPUtr2MQttRQ        People & Blogs  2008-07-27
# 7   UCi_iW2lqB3ADsJOobe_8yeg    Film and Animation  2011-09-14
# 8   UC_yl-sQID1NrBwAcS1LRHmg                Comedy  2009-11-16
# 9   UCruD_lL-5fmllpKMSL-yCyQ         Entertainment  2006-06-05
# 10  UCQ2QDEN5wRiSJQXMAXRmwHg    Film and Animation  2007-07-03
# 11  UCtQp6YD3Uc7Q439xlWL6APA       Travel & Events  2006-06-01
# 12  UCYbinjMxWwjRpp4WqgDqEDA        People & Blogs  2006-03-25
# 13  UCc3pNIRzIZ8ynI38GO6H01Q  Science & Technology  2007-12-05
# 14  UCneoi6WTgRjMh4otvpwzv8w    Film and Animation  2006-05-23
# 15  UCpad81d4S1iUjbNxNAO8Qsg         Entertainment  2008-12-21
# 16  UC9vXJYvgswrEHfNveILWM2Q         Entertainment  2009-12-08
# 17  UC5CqAZGAoLtY6_V1O3BQh0w                 Music  2011-10-21
# 18  UCtggghgcffr7-OSjiRXRM3Q         Entertainment  2009-04-08
# 19  UCnooaiHw3_83DYOD3UHe3-A         Entertainment  2012-01-24
#
#                                                  link  \
# 0   http://www.youtube.com/channel/UCwTkM6CvIsYFaF...
# 1   http://www.youtube.com/channel/UCwQJJVNbn_Tqze...
# 2   http://www.youtube.com/channel/UCFSILgKCKo35QY...
# 3   http://www.youtube.com/channel/UCwSIJCMWZC5GDM...
# 4   http://www.youtube.com/channel/UCX8yUJVv_GCpBN...
# 5   http://www.youtube.com/channel/UCSi5779nMiFTbL...
# 6   http://www.youtube.com/channel/UC1AJxP0vC_yqPU...
# 7   http://www.youtube.com/channel/UCi_iW2lqB3ADsJ...
# 8   http://www.youtube.com/channel/UC_yl-sQID1NrBw...
# 9   http://www.youtube.com/channel/UCruD_lL-5fmllp...
# 10  http://www.youtube.com/channel/UCQ2QDEN5wRiSJQ...
# 11  http://www.youtube.com/channel/UCtQp6YD3Uc7Q43...
# 12  http://www.youtube.com/channel/UCYbinjMxWwjRpp...
# 13  http://www.youtube.com/channel/UCc3pNIRzIZ8ynI...
# 14  http://www.youtube.com/channel/UCneoi6WTgRjMh4...
# 15  http://www.youtube.com/channel/UCpad81d4S1iUjb...
# 16  http://www.youtube.com/channel/UC9vXJYvgswrEHf...
# 17  http://www.youtube.com/channel/UC5CqAZGAoLtY6_...
# 18  http://www.youtube.com/channel/UCtggghgcffr7-O...
# 19  http://www.youtube.com/channel/UCnooaiHw3_83DY...
#
#                        name  subscribers  videos
# 0            James Bond 007       115000     407
# 1   The Asylum - Officia...        11200     210
# 2             StudiocanalUK        97200    1844
# 3            Prime Video UK        53200     996
# 4          Anthony Ingruber        22100      77
# 5            Roadshow Films        85400    2138
# 6        20thCenturyFoxFilm        44900     477
# 7   Paramount Pictures U...       468000     976
# 8                 Mandatory        39100    1195
# 9   Sony Pictures Classi...        49800     412
# 10         LionsgateFilmsUK        95867    1173
# 11          Air New Zealand        80603     497
# 12                  Cinemax       155000    1639
# 13  Microsoft Office 365...       272000    1247
# 14  Magnolia Pictures & ...       198000    1348
# 15                legolambs        50000     100
# 16  ColumbiaPicturesPhil...       141000    1937
# 17           Film Music Fan        62500      57
# 18                    BAFTA        55600    2553
# 19  Fox Home Entertainme...        66538     423

# %%
path = '/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channel_embedding.npy'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCISF5OGuAtSLNF24TKTnXag'], k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
# 57004
#                   channel_id            category   join_date  \
# 0   UCISF5OGuAtSLNF24TKTnXag  Film and Animation  2013-12-17
# 1   UC8Wj98MR_oUHBpTjLsE3HuA  Film and Animation  2010-10-10
# 2   UCHKDtSVVEc686EW7jRSCpZA       Entertainment  2007-04-01
# 3   UCcZjYWpM72s-1cinYfeSCag      People & Blogs  2010-08-05
# 4   UCg3bKR3Z0rCmUe81X06EcaA       Entertainment  2015-11-21
# 5   UC94Z4HZJkhPm94YPH1GE3bw       Entertainment  2011-12-13
# 6   UCPflSzRRyzK2hhbVxNAnrhw  Film and Animation  2012-03-31
# 7   UChU79FLnClqlRSTSZe3EjNA  Film and Animation  2014-03-21
# 8   UCcGuE4cmWhB4XLjSKA8eRFA       Entertainment  2014-08-30
# 9   UCaRdKsgbUdMIp-9FwEsaokg  Film and Animation  2014-02-25
# 10  UCD_VOth7RmckN6DbmFJa__A       Entertainment  2013-08-31
# 11  UCVKVmfXSkqhfCIpLLXFF26w  Film and Animation  2013-09-05
# 12  UC9qgVkKRZUXcgHdf35Z-8dw  Film and Animation  2013-06-24
# 13  UCVv1vQYLgJ6STMJkK2aWMyQ       Entertainment  2015-07-07
# 14  UCyNqz2EG8jzW1QV_YBw14xw       Entertainment  2013-09-16
# 15  UCn5wtpa-WcFPeAXZumbZlyw  Film and Animation  2011-07-20
# 16  UCzNNpurJsoyTc6zGLnXJcPw  Film and Animation  2013-05-04
# 17  UCeNiHXL_aG6KwoMVQAtsANA       Entertainment  2013-04-05
# 18  UCMzfiTDOiuax4C7H1Uu88mw              Gaming  2012-02-17
# 19  UCtaL0UtIW2I3Iq6k0sV2lEw              Gaming  2014-03-18
#
#                                                  link  \
# 0   http://www.youtube.com/channel/UCISF5OGuAtSLNF...
# 1   http://www.youtube.com/channel/UC8Wj98MR_oUHBp...
# 2   http://www.youtube.com/channel/UCHKDtSVVEc686E...
# 3   http://www.youtube.com/channel/UCcZjYWpM72s-1c...
# 4   http://www.youtube.com/channel/UCg3bKR3Z0rCmUe...
# 5   http://www.youtube.com/channel/UC94Z4HZJkhPm94...
# 6   http://www.youtube.com/channel/UCPflSzRRyzK2hh...
# 7   http://www.youtube.com/channel/UChU79FLnClqlRS...
# 8   http://www.youtube.com/channel/UCcGuE4cmWhB4XL...
# 9   http://www.youtube.com/channel/UCaRdKsgbUdMIp-...
# 10  http://www.youtube.com/channel/UCD_VOth7RmckN6...
# 11  http://www.youtube.com/channel/UCVKVmfXSkqhfCI...
# 12  http://www.youtube.com/channel/UC9qgVkKRZUXcgH...
# 13  http://www.youtube.com/channel/UCVv1vQYLgJ6STM...
# 14  http://www.youtube.com/channel/UCyNqz2EG8jzW1Q...
# 15  http://www.youtube.com/channel/UCn5wtpa-WcFPeA...
# 16  http://www.youtube.com/channel/UCzNNpurJsoyTc6...
# 17  http://www.youtube.com/channel/UCeNiHXL_aG6Kwo...
# 18  http://www.youtube.com/channel/UCMzfiTDOiuax4C...
# 19  http://www.youtube.com/channel/UCtaL0UtIW2I3Iq...
#
#                        name  subscribers  videos
# 0                Magpiepony       736000     304
# 1               Pinkie Rose       247000     167
# 2   Scribbler Production...       327000    1767
# 3         DisneyFanatic2364       205000    1026
# 4               Blank Slate       121000     408
# 5                 EileMonty       504000     211
# 6                Pinkie Pie      1229394     451
# 7                Flutter525       858000    1297
# 8                 WatchPony       117000     341
# 9                  Ashley H        77200     500
# 10         The Brony Notion       256132     158
# 11               Moliminous       228000     778
# 12  My Little Pony Offic...       874016    1840
# 13                Tridashie       252744      48
# 14          TheLostNarrator       115000     336
# 15                EDplus777       687592     214
# 16                 MLPcandy        54700     358
# 17           Bronymonster44        69200     638
# 18             eric wartick       168734     103
# 19        MoliminousTheater       184000     251

# %% [markdown]
# ### Channels selected over the whole comments dataset
# We randomly choose 10 000 users over the dataset.
# For each user, we then pick two channels at random in the set of channels this user commented in.

# %%
selected_users_rw = np.random.randint(227495283-1, size=3000)

# %%
for v1, v2 in selected_channels_rw:
    if v1 == v2:
        print('haha')

# %%
selected_channels_rw = np.random.randint(129616-1, size=(3000, 2))

# %%
1 % 2
# Out:
# 1

# %%
# Load the channel tuple sparse matrix
S = scipy.sparse.load_npz('/dlabdata1/youtube_large/jouven/final_sparse_matrix/channels_more_300/sparse_matrix_for_word2vec.npz')
NB_SAMPLE = 3000

with open("/dlabdata1/youtube_large/jouven/channels_more_300/selected_users_word2vecf.pkl",'rb') as f:
     selected_users = pickle.load(f)
f.close()
selected_users = np.random.choice(selected_users, NB_SAMPLE, replace=False)

S = S[:, selected_users]
# Create and store channels tuples
channels_tuple = []
for i in range(S.shape[1]):
    idx = S[:, i].nonzero()
    idx = idx[0]
    
    selected_channels = np.random.choice(idx, 2, replace=False)
    channels_tuple.append((selected_channels[0], selected_channels[1]))
    
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_user_walk_known_users.pkl",'wb') as f:
     pickle.dump(channels_tuple, f)
f.close()

S = scipy.sparse.load_npz('/dlabdata1/youtube_large/jouven/final_sparse_matrix/channels_more_300/sparse_matrix_word2vec_users_commented_geq_2_channels.npz')

S2 = S[:, selected_users_rw]

# Create and store channels tuples
channels_tuple = []
last = 0
for i in range(S2.shape[1]):
    idx = S2[:, i].nonzero()
    idx = idx[0]
    
    if i % 2 == 1:
        selected_channel = np.random.choice(idx, 1)
        channels_tuple.append((last, selected_channel))
    else:
        last = np.random.choice(idx, 1)
    
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_random_walk_modified.pkl",'wb') as f:
     pickle.dump(channels_tuple, f)
f.close()

channels_tuple = []
for val in selected_channels_rw:
    channels_tuple.append((val[0], val[1]))
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_random_walk.pkl",'wb') as f:
     pickle.dump(channels_tuple, f)
f.close()


# Sample NB_SAMPLE from the set of users
selected_users = np.random.randint(S.shape[1] - 1, size=NB_SAMPLE)
S = S[:, selected_users]

# Create and store channels tuples
channels_tuple = []
for i in range(S.shape[1]):
    idx = S[:, i].nonzero()
    idx = idx[0]
    
    selected_channels = np.random.choice(idx, 2, replace=False)
    channels_tuple.append((selected_channels[0], selected_channels[1]))
    
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_user_walk.pkl",'wb') as f:
     pickle.dump(channels_tuple, f)
f.close()

# %%
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_user_walk.pkl",'rb') as f:
     channels_tuple = pickle.load(f)
f.close()

# %% [markdown]
# #### Random walk

# %%
def get_random_walk(df_embedding):
    with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_random_walk.pkl",'rb') as f:
         random_walk_channels = pickle.load(f)
    f.close()
    random_walk_distance = 0
    for val in random_walk_channels:
        random_walk_distance += distance.euclidean(df_embedding.iloc[val[0]], df_embedding.iloc[val[1]])
    return random_walk_distance

# %%
def get_random_walk_modified(df_embedding):
    with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_random_walk_modified.pkl",'rb') as f:
         random_walk_channels = pickle.load(f)
    f.close()
    random_walk_distance = 0
    for val in random_walk_channels:
        random_walk_distance += distance.euclidean(df_embedding.iloc[val[0]], df_embedding.iloc[val[1]])
    return random_walk_distance

# %% [markdown]
# #### Compute metrics: users walk distance and relative nearest neighbor ranking
#
# In this section we want to measure the euclidian distance of a user walk compared to a random walk.
#
# user walk: Euclidean distance in the embedding space between two randomly channels of a user.
# random walk: Euclidean distance in the embedding space between two randomly channels.
# position: Position of a channel taken from user u relatively of another channel taken from the same user in terms of its nearest neighbor ranking.

# %%
'''
Get the position of ref_channel relative to second_channel in terms of its nearest neighbors ranking.
PARAMETER:
    - ref_channel: The reference channel on which wwe compute it's k nearest neighbor
    - second_channel: The channel where we compute it's ranking relatively to ref_channel
    - dist: Euclidean distance between ref_channel and second_channel
    - index: annoy index
    - df_embedding: DataFrame representing the embedding space

RETURN: The position of second_channel relatively to ref_channel in terms of it's ranking

'''
def get_ranking_position_between_channels(ref_channel, second_channel, dist, index, df_embedding):
    
    nearest_neighbors_index = index.get_nns_by_item(ref_channel, len(df_embedding), search_k = 100000000)
    dist_k_th_nearest = distance.euclidean(df_embedding.iloc[ref_channel], 
                                           df_embedding.iloc[nearest_neighbors_index[len(nearest_neighbors_index)-1]])
    for i in range(0, len(nearest_neighbors_index)):
        if nearest_neighbors_index[i] == second_channel:
            return i

# %%
users_walk_tab = []
ranking_position_tab = []

len_random_set = len(channels_tuple)
len_embedding = len(channels_id)
 
files = ['/dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channels_more_300/size_200_sub_0043_neg_35_threshold_10/channel_embedding.npy']
for file in files: 
    print('file ', file)
    df_embedding = get_dataframe_in_embedding_space(file)
    n_comp = df_embedding.shape[1]
    print('n_comp ', n_comp)
    random_walk_distance = get_random_walk_modified(df_embedding)
        
    index = get_annoy_index(df_embedding)

    users_walk = 0
    ranking_position = 0

    for ref_channel, second_channel in channels_tuple:
        dist = distance.euclidean(df_embedding.iloc[ref_channel], df_embedding.iloc[second_channel])
        users_walk += dist
        ranking_position += get_ranking_position_between_channels(ref_channel, second_channel, dist, index, df_embedding)
    
    users_walk_tab.append(users_walk/random_walk_distance)
    ranking_position_tab.append(ranking_position/(len_random_set*len_embedding))
# Out:
# file  /dlabdata1/youtube_large/jouven/word2vecf_preprocessing/channels_more_300/size_200_sub_0043_neg_35_threshold_10/channel_embedding.npy
# n_comp  200

# %%
users_walk_tab
# Out:
# [1.9730998994803428]

# %%
ranking_position_tab
# Out:
# [0.555226085771304]

# %%
users_walk_tab
# Out:
# [2.2101317966239815]

# %%
ranking_position_tab
# Out:
# [0.555226085771304]

# %%
'''
Plot the results obtained when computing the metrics
'''
import plotly.graph_objects as go

components_name = ['Features dim 50', 'Features dim 100', 'Features dim 200', 'Features dim 500']
colors = ['b', 'g,', 'r', 'c']

fig = go.Figure()

for i in range(len(components_name)):
    fig.add_trace(go.Scatter(
        x=ranking_position_tab,
        y=users_walk_tab,
        marker=dict(color=colors[i], size=12),
        mode="markers",
        name=components_name[i],
    ))

fig.update_layout(title="Gender Earnings Disparity",
                  xaxis_title="Ranking position",
                  yaxis_title="Users walk distance")

fig.show()
