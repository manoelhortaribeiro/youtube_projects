# %%
import sys
import os
import operator
import numpy as np
import matplotlib.pyplot as plt
import time
import pandas as pd
import pickle

scriptpath = "../"
sys.path.append(os.path.abspath(scriptpath))
from helpers import *

# %% [markdown]
# Analysing the number of comments per channel in the comments dataset

# %%
channels_idx_to_nb_comments = sorted(channels_idx_to_nb_comments.values(), reverse = True)

# %%
channels_idx_to_nb_comments[145000: 145005]
# Out:
# [547, 547, 547, 547, 547]

# %%
x_min = 0
x_max = len(channels_idx_to_nb_comments)
highest_value = channels_idx_to_nb_comments[0]

# %%
plt.plot(channels_idx_to_nb_comments, 'ro')
plt.ylabel('number of comments')
plt.xlabel('channels')
plt.title('Number of comments per channel')
plt.show()

# %%
plt.plot(channels_idx_to_nb_comments)
plt.yscale('log')
plt.ylabel('number of comments')
plt.xlabel('channels')
plt.title('Number of comments per channel in y log scale')
plt.show()
