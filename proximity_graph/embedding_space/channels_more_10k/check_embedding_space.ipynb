# %% [markdown]
# This notebook checks the behaviour of the embedding space

# %%
import pickle
import random
import glob
import os
import sys
import scipy.sparse
import re

import numpy as np
import pandas as pd

from annoy import AnnoyIndex
from scipy.spatial import distance

scriptpath = "../../"
sys.path.append(os.path.abspath(scriptpath))
from helpers.helpers import *

# %%
'''
Retrieve the array obtained by apllying the dimentionality reduction algorithm
graph_matrix: SHAPE: (channels, n_comp)

PARAMETER:
    - file_path: the path where the embedding graph is stored

RETURN: 
    - df: DataFrame representing the graph in the embedding space
'''
def get_dataframe_in_embedding_space(file_path):
    graph_matrix = np.load(file_path)
    graph_matrix = graph_matrix['arr_0']
    df = pd.DataFrame(graph_matrix)
    df = df.rename(lambda x: 'dr'+str(x), axis='columns')
    return df

# %%
# Selected channels and id-index mapping
dict_channel_ind, dict_ind_channel, channels_id = filtered_channels_index_id_mapping()

# %% [markdown]
# ### Find k closest channel using annoy library

# %% [markdown]
# First to check how good is the embedding space, we are going to choose a channel and it's k closest channels in the embedding space. By looking at these channels in the YouTube website, we should get similar channels if the embedding space is good.

# %%
channelcrawler = pd.read_csv("/dlabdata1/youtube_large/channelcrawler.csv")
channelcrawler['channel_id'] = channelcrawler['link'].str.split('/').str[-1]
channelcrawler = channelcrawler[channelcrawler['channel_id'].apply(lambda row: row in channels_id)]

# %%
channelcrawler['category'].unique()
# Out:
# array(['Comedy', 'Gaming', 'Film and Animation', 'Science & Technology',
#        'Music', 'Education', 'Sports', 'People & Blogs', 'Entertainment',
#        'Nonprofits & Activism', 'News & Politics', 'Travel & Events',
#        'Howto & Style', 'Autos & Vehicles', 'Pets & Animals', nan],
#       dtype=object)

# %%
'''
Retrieve the array obtained by apllying the dimentinality reductin algorithm
graph_matrix: SHAPE: (channels, n_comp)

PARAMETERS:
    - df_embedding: DataFrame representing the graph in the embedding space
    - n_comp: number of components to use after the dimentionalit reduction

RETURN: The annoy index
'''
def get_annoy_index(df):
    index = AnnoyIndex(df.shape[1], "euclidean")  # Length of item vector that will be indexed
    df.apply(lambda row: index.add_item(row.name, np.array(row)), axis = 1)
    index.build(100) # 100 trees
    return index

# %%
def get_k_nearest_neighbors(path, ref_index_channel, k = 20):
    df = get_dataframe_in_embedding_space(path)
    index = get_annoy_index(df)
    nearest_neighbors_index = index.get_nns_by_item(ref_index_channel, k)
    nearest_neighbors_id = [dict_ind_channel[val] for val in nearest_neighbors_index]
    return nearest_neighbors_id

# %%
channelcrawler[channelcrawler['name'] == 'TEDx Talks']
# Out:
#                     category   join_date  \
# 12422  Nonprofits & Activism  2009-06-23
#
#                                                     link        name  \
# 12422  http://www.youtube.com/channel/UCsT0YIqwnpJCM-...  TEDx Talks
#
#        subscribers  videos                channel_id
# 12422     20700000  141627  UCsT0YIqwnpJCM-mx7-gSA4Q

# %%
path = '/dlabdata1/youtube_large/jouven/channel_embedding/channels_by_channels_normalized_comments_more_10k/reduced_fpca_200.npz'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCMpOz2KEfkSdd5JeIJh_fxw'], k= 40)

# %%
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
#                   channel_id         category   join_date  \
# 0   UCMpOz2KEfkSdd5JeIJh_fxw    Howto & Style  2009-01-18
# 1   UCLFW3EKD2My9swWH4eTLaYw    Howto & Style  2012-03-06
# 2   UCXbQzhqSvgVZTUyi1T4AU3w    Howto & Style  2011-08-31
# 3   UCK-4JyAcQYBasFAe367on7w    Howto & Style  2009-05-29
# 4   UCUt0ZA6l_EidUnBFMR9BZig    Howto & Style  2009-11-28
# 5   UCOtoxvHLKrIlWbt4MRBWfbQ    Howto & Style  2013-02-28
# 6   UCQWy33JxT07WWPdGBIuToPw    Howto & Style  2010-11-30
# 7   UCJttQwY6KBhwov_2wKywtqA    Howto & Style  2010-06-27
# 8   UCFghPtzFcmyDiID1ASMA4Dg    Howto & Style  2008-07-03
# 9   UCPG6A5tNaPfv2SRNW2beq5Q    Entertainment  2011-11-13
# 10  UCT27sjmi4NEYRBIRf-fmgow    Howto & Style  2010-06-23
# 11  UCXTAdFsBmxNK3_c8MUvSviQ    Howto & Style  2009-02-03
# 12  UCW6MKQtz-vrqpC7D7qJ3Baw    Howto & Style  2008-12-04
# 13  UCHj2_6e0Y2YdzHZDkkLa53Q   People & Blogs  2010-10-18
# 14  UCJz3WuXcsB-1KAeWOSfhY0Q    Howto & Style  2006-05-06
# 15  UCPRlGA2w7C_DVw-1ynolJYw   People & Blogs  2011-07-19
# 16  UCK2ACorzpH-igxuHZ2ObCEA   People & Blogs  2010-03-10
# 17  UCJyfryZQsoN_ttLFe6vYKmw    Howto & Style  2010-06-10
# 18  UCJqcphJAnsD5YDXcRFzTsOw    Howto & Style  2010-04-18
# 19  UCLhLyKIZYf4lCcilMujzXAA    Howto & Style  2009-07-22
# 20  UCYSMmZnOy9LEy5jhEgMyddQ  Travel & Events  2009-07-05
# 21  UCLF42C7y73FKA8ye_5Nn-Kw    Howto & Style  2012-11-14
# 22  UCJRFJl5UDs4Citzs-uRcrxQ    Howto & Style  2011-01-12
# 23  UCE1BqH-72EBs-siTbDAjOGQ    Howto & Style  2008-04-20
# 24  UCK7QFg6W9E7mM_AzRFlit-Q    Howto & Style  2011-10-04
# 25  UCM3P_G21gOSVdepXrEFojIg    Howto & Style  2011-01-26
# 26  UCtC8m_F7jX2fGOQ3_nomg4g    Howto & Style  2006-11-08
# 27  UCVKFs0cesQUEGtn8gQmhbHw    Howto & Style  2013-09-06
# 28  UCanxV6P3uYyM_QjIy9p-L_A    Howto & Style  2009-08-27
# 29  UC85jN0RMP-uJTIzhAcMFitA   People & Blogs  2010-10-06
# 30  UCXPOAAerLDAqb5pbuVbTbsA    Howto & Style  2010-07-22
# 31  UCeZn7qRN3JKVcEYK_dDg7JQ    Howto & Style  2010-11-19
# 32  UCVhekdkVuEjXrsyxR8ObiLg    Howto & Style  2008-11-17
# 33  UCITYLf5cx0_J7Qh76S9F11Q    Entertainment  2012-03-01
# 34  UCOK2ZYAhxDXELwAHMcKwD2g    Howto & Style  2007-09-30
# 35  UCEZufuEDQi-bHovN37Ra2EA    Howto & Style  2007-03-18
# 36  UCNVzgZLncxAG38SVP8rzf_g   People & Blogs  2009-02-04
# 37  UCEZtkE45zjun9zROKtcqOcQ    Howto & Style  2012-02-11
# 38  UCZQ0XPE7wxMafUf8dIHOxgQ    Howto & Style  2013-01-27
# 39  UCeGe5mF6zkOA17X6X1VIjkA    Howto & Style  2013-05-14
#
#                                                  link                name  \
# 0   http://www.youtube.com/channel/UCMpOz2KEfkSdd5...            Shaaanxo
# 1   http://www.youtube.com/channel/UCLFW3EKD2My9sw...       Chloe Morello
# 2   http://www.youtube.com/channel/UCXbQzhqSvgVZTU...       Lauren Curtis
# 3   http://www.youtube.com/channel/UCK-4JyAcQYBasF...          RachhLoves
# 4   http://www.youtube.com/channel/UCUt0ZA6l_EidUn...               SMLx0
# 5   http://www.youtube.com/channel/UCOtoxvHLKrIlWb...     RawBeautyKristi
# 6   http://www.youtube.com/channel/UCQWy33JxT07WWP...  LoveMelisaMichelle
# 7   http://www.youtube.com/channel/UCJttQwY6KBhwov...      NikkiPhillippi
# 8   http://www.youtube.com/channel/UCFghPtzFcmyDiI...       Lisa Eldridge
# 9   http://www.youtube.com/channel/UCPG6A5tNaPfv2S...      Shani Grimmond
# 10  http://www.youtube.com/channel/UCT27sjmi4NEYRB...    Jenny Claire Fox
# 11  http://www.youtube.com/channel/UCXTAdFsBmxNK3_...  Christen Dominique
# 12  http://www.youtube.com/channel/UCW6MKQtz-vrqpC...     Kayleigh Noelle
# 13  http://www.youtube.com/channel/UCHj2_6e0Y2YdzH...   Cassandra Bankson
# 14  http://www.youtube.com/channel/UCJz3WuXcsB-1KA...          Julia Graf
# 15  http://www.youtube.com/channel/UCPRlGA2w7C_DVw...      Shaaanxo Vlogs
# 16  http://www.youtube.com/channel/UCK2ACorzpH-igx...        itsJudysLife
# 17  http://www.youtube.com/channel/UCJyfryZQsoN_tt...     Claire Marshall
# 18  http://www.youtube.com/channel/UCJqcphJAnsD5YD...           Luxy Hair
# 19  http://www.youtube.com/channel/UCLhLyKIZYf4lCc...        Sophia Chang
# 20  http://www.youtube.com/channel/UCYSMmZnOy9LEy5...    Allison Anderson
# 21  http://www.youtube.com/channel/UCLF42C7y73FKA8...        Allie Glines
# 22  http://www.youtube.com/channel/UCJRFJl5UDs4Cit...   Danielle Mansutti
# 23  http://www.youtube.com/channel/UCE1BqH-72EBs-s...       Marlena Stell
# 24  http://www.youtube.com/channel/UCK7QFg6W9E7mM_...    WhatWouldLizzyDo
# 25  http://www.youtube.com/channel/UCM3P_G21gOSVde...      Rachel Talbott
# 26  http://www.youtube.com/channel/UCtC8m_F7jX2fGO...          Emily Noel
# 27  http://www.youtube.com/channel/UCVKFs0cesQUEGt...    Brittany Vasseur
# 28  http://www.youtube.com/channel/UCanxV6P3uYyM_Q...            Nitraa B
# 29  http://www.youtube.com/channel/UC85jN0RMP-uJTI...       Karissa Pukas
# 30  http://www.youtube.com/channel/UCXPOAAerLDAqb5...    Alexandrea Garza
# 31  http://www.youtube.com/channel/UCeZn7qRN3JKVcE...        leighannsays
# 32  http://www.youtube.com/channel/UCVhekdkVuEjXrs...        Alison Henry
# 33  http://www.youtube.com/channel/UCITYLf5cx0_J7Q...         LaVitaDiMeg
# 34  http://www.youtube.com/channel/UCOK2ZYAhxDXELw...      Brittany Balyn
# 35  http://www.youtube.com/channel/UCEZufuEDQi-bHo...              Leesha
# 36  http://www.youtube.com/channel/UCNVzgZLncxAG38...  EllesGlitterGossip
# 37  http://www.youtube.com/channel/UCEZtkE45zjun9z...       Amanda Ensing
# 38  http://www.youtube.com/channel/UCZQ0XPE7wxMafU...     Stephanie Lange
# 39  http://www.youtube.com/channel/UCeGe5mF6zkOA17...          Amy Macedo
#
#     subscribers  videos
# 0       3215340    1422
# 1       2700000     518
# 2       3530000     379
# 3       1450000     851
# 4       1000000     645
# 5        751000     627
# 6        571000     618
# 7       1360000     959
# 8       1930000     320
# 9       1590000     423
# 10       878000     448
# 11      4230000     360
# 12       691000     869
# 13       879000    1297
# 14       766236     882
# 15       555112     742
# 16      1660000    2893
# 17       986000     259
# 18      3200000     537
# 19       821000     362
# 20       469000     355
# 21       500000     451
# 22      1610000     412
# 23      1520000     754
# 24       433000     649
# 25      1210000     337
# 26      1020000    1750
# 27      1210000     339
# 28       772000     542
# 29       737127     503
# 30       899000     459
# 31       816000     756
# 32       843000     324
# 33       396000     503
# 34       376000     547
# 35       510000    1150
# 36       506713     248
# 37      1440000     488
# 38      1343733     425
# 39       995000     696

# %%
path = '/dlabdata1/youtube_large/jouven/channel_embedding/channels_by_channels_normalized_comments_more_10k/reduced_fpca_200.npz'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCZyCposXwcyopaACep44maQ'], k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
#                   channel_id              category   join_date  \
# 0   UCZyCposXwcyopaACep44maQ         Howto & Style  2011-09-29
# 1   UCZIIRX8rkNjVpP-oLMHpeDw                Sports  2012-03-02
# 2   UCaBqRxHEMomgFU-AkSfodCw        People & Blogs  2013-08-31
# 3   UCbq8_4_mFAx_rzDF5VT7MJw         Howto & Style  2013-11-11
# 4   UCZzhmrvDP3ueh7bYaTL4b7w                Sports  2016-09-24
# 5   UCZGNLDywn8hgzqrC9Mlz_Pw         Entertainment  2013-08-27
# 6   UCYlMlavtN2ppRd7a6U_4ymg        People & Blogs  2017-02-07
# 7   UC_Ih0f1H_eyHeLLT0Tzuh8g                Sports  2006-05-22
# 8   UC_9PPhlRLYdJby2OjNYfBEA         Entertainment  2014-06-20
# 9   UCaaApS4TMI3KueyAkIQv1XQ         Howto & Style  2011-10-03
# 10  UCXlnUMmbfvVBmc5NqzlbFVw                Comedy  2017-08-25
# 11  UCHdPuKshPHyRHE3rz75rXdw         Howto & Style  2011-08-02
# 12  UCWYzs-Mi7SM_n1EgvzIOn3w         Entertainment  2017-01-12
# 13  UCRFUw9QQy7ypUkIe-HOVdZw                Sports  2014-09-25
# 14  UC28fguRikdRFOujCjzyKFGQ  Science & Technology  2015-03-15
# 15  UCSNtgLG8S073khvrXtoZbog         Howto & Style  2013-07-18
# 16  UCOFCwvhDoUvYcfpD7RJKQwA             Education  2015-01-25
# 17  UC__YXWhWRTWhV99fs1t6oig                Gaming  2016-07-09
# 18  UCYGiWMEIKXL2EhIfPSUSmvg  Science & Technology  2006-10-15
# 19  UCZAUAzqAn88GTa8OoM9MJgA             Education  2014-04-13
#
#                                                  link  \
# 0   http://www.youtube.com/channel/UCZyCposXwcyopa...
# 1   http://www.youtube.com/channel/UCZIIRX8rkNjVpP...
# 2   http://www.youtube.com/channel/UCaBqRxHEMomgFU...
# 3   http://www.youtube.com/channel/UCbq8_4_mFAx_rz...
# 4   http://www.youtube.com/channel/UCZzhmrvDP3ueh7...
# 5   http://www.youtube.com/channel/UCZGNLDywn8hgzq...
# 6   http://www.youtube.com/channel/UCYlMlavtN2ppRd...
# 7   http://www.youtube.com/channel/UC_Ih0f1H_eyHeL...
# 8   http://www.youtube.com/channel/UC_9PPhlRLYdJby...
# 9   http://www.youtube.com/channel/UCaaApS4TMI3Kue...
# 10  http://www.youtube.com/channel/UCXlnUMmbfvVBmc...
# 11  http://www.youtube.com/channel/UCHdPuKshPHyRHE...
# 12  http://www.youtube.com/channel/UCWYzs-Mi7SM_n1...
# 13  http://www.youtube.com/channel/UCRFUw9QQy7ypUk...
# 14  http://www.youtube.com/channel/UC28fguRikdRFOu...
# 15  http://www.youtube.com/channel/UCSNtgLG8S073kh...
# 16  http://www.youtube.com/channel/UCOFCwvhDoUvYcf...
# 17  http://www.youtube.com/channel/UC__YXWhWRTWhV9...
# 18  http://www.youtube.com/channel/UCYGiWMEIKXL2Eh...
# 19  http://www.youtube.com/channel/UCZAUAzqAn88GTa...
#
#                        name  subscribers  videos
# 0                Alex Costa      2120000     543
# 1       Calisthenicmovement      2152446     208
# 2               CHRIS HERIA      1230000     102
# 3                   BluMaan      1530000     381
# 4             AlphaShred TV       418000     326
# 5                 Tai Lopez      1300000     138
# 6   Stronger Than The Wo...       357000     307
# 7              Simeon Panda      1220000     240
# 8                RiskyRobTV       333000     107
# 9                    AWxInc       412000     373
# 10               Jack Denmo       353000     146
# 11              Dre Drexler       577000     273
# 12            Jack ManleyTV      1340000      34
# 13                   Merijn       270000     561
# 14              The Zunigas       243000     481
# 15           Jordan O'Brien       439000     295
# 16                  V Shred      1330000     414
# 17       Deepak 8 Ball Pool       268000     377
# 18  ben's gadget reviews...       105000     375
# 19  Adina Rivers | MyTin...       969000     108

# %%
path = '/dlabdata1/youtube_large/jouven/channel_embedding/channels_by_channels_normalized_comments_more_10k/reduced_fpca_200.npz'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCAql2DyGU2un1Ei2nMYsqOA'], k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
#                   channel_id               category   join_date  \
# 0   UCAql2DyGU2un1Ei2nMYsqOA        News & Politics  2015-03-17
# 1   UCBTNyrZoiTweJ1PZsJgdWTA        News & Politics  2012-02-07
# 2   UC3o7kbpTUQ5-0WTMIp8sVwA        News & Politics  2006-01-23
# 3   UCBPBm0lmc-W0m6X-dXYTjqg        News & Politics  2007-11-12
# 4   UCAHlQMx1f3TbRImhHHGPNKA        News & Politics  2010-09-15
# 5   UC8aIq_l3wnoWDVu3sasgoew        News & Politics  2015-09-16
# 6   UCBLGQrOOfs5l7fay66B2-3Q         People & Blogs  2017-03-29
# 7   UCAR0Oi4L0Om4F26uwpANgCg   Science & Technology  2012-01-21
# 8   UCAVu4nbyK-IET2eFc9qqpAQ          Entertainment  2007-02-10
# 9   UC6ZFN9Tx6xh-skXCuRHCDpQ        News & Politics  2009-11-30
# 10  UCADaBeM0qiKEZIw9_OuYmuA        News & Politics  2010-02-11
# 11  UCBH5VZE_Y4F3CMcPIzPEB5A        News & Politics  2015-01-22
# 12  UC30uFZsplYyA5oHjV__GJEA  Nonprofits & Activism  2018-12-28
# 13  UCAkAq8ajQKqRcur5sMUg6hA        News & Politics  2010-09-18
# 14  UC0SMGmU6X9zJBGCGarr7ODQ        News & Politics  2019-01-02
# 15  UCAxy9vKN0Uh3N8kbQa5gG1A  Nonprofits & Activism  2014-11-08
# 16  UC6hld3om8u8ya_RTbA00iBg          Entertainment  2011-07-10
# 17  UCBoV37ykBaRnkXzi8dVhfTQ         People & Blogs  2013-03-26
# 18  UC9sXw4ZdPEIp6bYGvLW-_iA        News & Politics  2007-05-25
# 19  UC72UssJ1DNQcakZXm-B2-zw        News & Politics  2007-05-03
#
#                                                  link  \
# 0   http://www.youtube.com/channel/UCAql2DyGU2un1E...
# 1   http://www.youtube.com/channel/UCBTNyrZoiTweJ1...
# 2   http://www.youtube.com/channel/UC3o7kbpTUQ5-0W...
# 3   http://www.youtube.com/channel/UCBPBm0lmc-W0m6...
# 4   http://www.youtube.com/channel/UCAHlQMx1f3TbRI...
# 5   http://www.youtube.com/channel/UC8aIq_l3wnoWDV...
# 6   http://www.youtube.com/channel/UCBLGQrOOfs5l7f...
# 7   http://www.youtube.com/channel/UCAR0Oi4L0Om4F2...
# 8   http://www.youtube.com/channel/UCAVu4nbyK-IET2...
# 9   http://www.youtube.com/channel/UC6ZFN9Tx6xh-sk...
# 10  http://www.youtube.com/channel/UCADaBeM0qiKEZI...
# 11  http://www.youtube.com/channel/UCBH5VZE_Y4F3CM...
# 12  http://www.youtube.com/channel/UC30uFZsplYyA5o...
# 13  http://www.youtube.com/channel/UCAkAq8ajQKqRcu...
# 14  http://www.youtube.com/channel/UC0SMGmU6X9zJBG...
# 15  http://www.youtube.com/channel/UCAxy9vKN0Uh3N8...
# 16  http://www.youtube.com/channel/UC6hld3om8u8ya_...
# 17  http://www.youtube.com/channel/UCBoV37ykBaRnkX...
# 18  http://www.youtube.com/channel/UC9sXw4ZdPEIp6b...
# 19  http://www.youtube.com/channel/UC72UssJ1DNQcak...
#
#                        name  subscribers  videos
# 0            Donald J Trump       189000     222
# 1             Tulsi Gabbard        94600     464
# 2                       GOP        68700     969
# 3                   news672        25571    4068
# 4             Freedom Watch        45100     629
# 5   Let The Madness Begi...        15700     630
# 6       Silver Report Uncut        41200     761
# 7            1000frolly PhD        31300     167
# 8             Jason Asselin        36203    2006
# 9              PBS NewsHour      1380000   26035
# 10              WMAR-2 News        42900   43185
# 11      Real Vision Finance       192000     917
# 12        We Build The Wall        26000     135
# 13               #PIZZAGATE        14300     154
# 14       Red Eagle Politics        10500      97
# 15          RTR TRUTH MEDIA        17000     472
# 16                Joy Villa        46715     363
# 17            Mo Reese Delk        11800     621
# 18         vpro documentary       122743     208
# 19  WCVB Channel 5 Bosto...        53000   38396

# %%
dict_channel_ind['UC9pXxdNqCc2zjgRXSoowNNg']
# Out:
# 9629

# %%
path = '/dlabdata1/youtube_large/jouven/channel_embedding/channels_by_channels_normalized_comments_more_10k/reduced_fpca_200.npz'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UC9pXxdNqCc2zjgRXSoowNNg'], k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
#                   channel_id              category   join_date  \
# 0   UC9pXxdNqCc2zjgRXSoowNNg       News & Politics  2014-07-09
# 1   UC6xM7GvKd85duq5fw8qKBOQ       News & Politics  2006-01-22
# 2   UCB80iBRAaz8sYccjiZUobcw        People & Blogs  2007-12-12
# 3   UCuooZI9u0ZSGB58LMrT_T0w        People & Blogs  2006-06-07
# 4   UCuJ_tm9InltvVwcf71sn9zw       Travel & Events  2007-04-19
# 5   UCF_mQgKpqDBPDWF-pHRTMgg       News & Politics  2011-06-14
# 6   UC2oIvS_wzweWauJea77q1Dg       Travel & Events  2015-05-22
# 7   UCuKotzG8QrGmy-lSExEN9Pw         Entertainment  2011-06-22
# 8   UCtvGQztIvHC3jt-JY7a7bIQ                 Music  2010-07-27
# 9   UC7UAVEyiMRCRb8dWCpxC5qA       Travel & Events  2014-01-04
# 10  UCuI9mKTljZlI-y-eyaeGcNw                 Music  2005-12-28
# 11  UC9rRsBE2nFbnUSjtmv6Jq6w       Travel & Events  2015-03-15
# 12  UCu_mPlZbomAgNzfAUElRL7w         Howto & Style  2016-07-24
# 13  UCuSx-lf2ft7hPceGVNHybOw    Film and Animation  2014-07-01
# 14  UCtv1lg_1FJQnFbmtyirqD8w        People & Blogs  2015-07-01
# 15  UCto7KBa8QxsYLQLnPnKTd0w  Science & Technology  2016-03-08
# 16  UCt7SG8q4GUDMLfbkViwkWLQ                 Music  2009-10-23
# 17  UCuP2vJ6kRutQBfRmdcI92mA             Education  2016-01-20
# 18  UCuHRjYQVbZ1r48LL8MODEtw                 Music  2008-05-27
# 19  UCsmYknOXe6JMBK_WovyyIbw         Howto & Style  2008-02-16
#
#                                                  link  \
# 0   http://www.youtube.com/channel/UC9pXxdNqCc2zjg...
# 1   http://www.youtube.com/channel/UC6xM7GvKd85duq...
# 2   http://www.youtube.com/channel/UCB80iBRAaz8sYc...
# 3   http://www.youtube.com/channel/UCuooZI9u0ZSGB5...
# 4   http://www.youtube.com/channel/UCuJ_tm9InltvVw...
# 5   http://www.youtube.com/channel/UCF_mQgKpqDBPDW...
# 6   http://www.youtube.com/channel/UC2oIvS_wzweWau...
# 7   http://www.youtube.com/channel/UCuKotzG8QrGmy-...
# 8   http://www.youtube.com/channel/UCtvGQztIvHC3jt...
# 9   http://www.youtube.com/channel/UC7UAVEyiMRCRb8...
# 10  http://www.youtube.com/channel/UCuI9mKTljZlI-y...
# 11  http://www.youtube.com/channel/UC9rRsBE2nFbnUS...
# 12  http://www.youtube.com/channel/UCu_mPlZbomAgNz...
# 13  http://www.youtube.com/channel/UCuSx-lf2ft7hPc...
# 14  http://www.youtube.com/channel/UCtv1lg_1FJQnFb...
# 15  http://www.youtube.com/channel/UCto7KBa8QxsYLQ...
# 16  http://www.youtube.com/channel/UCt7SG8q4GUDMLf...
# 17  http://www.youtube.com/channel/UCuP2vJ6kRutQBf...
# 18  http://www.youtube.com/channel/UCuHRjYQVbZ1r48...
# 19  http://www.youtube.com/channel/UCsmYknOXe6JMBK...
#
#                        name  subscribers  videos
# 0       A Blue Dot In Texas        10600     646
# 1              Matt Orfalea        20800     232
# 2                     Storm        10000     312
# 3           Njenje Media TV        56400     672
# 4   Travelling with Bruc...        33800    1085
# 5   David Von Pein's JFK...        25500     899
# 6   The Motorhome Experi...        27500     431
# 7                   DMRnews        27100    1318
# 8                 gullivior        21700    5436
# 9               Casey Roman        25800     164
# 10                BEHRINGER       106000     892
# 11  Sailing Yacht Ruby R...        83900     178
# 12  The Mindful Movement...       208876     229
# 13              StarMediaEN       136000     617
# 14         North East Tarot        46500    2577
# 15              Reviews.org        37387     212
# 16          EuroArtsChannel       217000    1629
# 17      Lets Build That App       160000     410
# 18              BachScholar       105000    1156
# 19             Rick Cheadle        59408     910

# %%
path = '/dlabdata1/youtube_large/jouven/channel_embedding/channels_by_channels_normalized_comments_more_10k/reduced_fpca_200.npz'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCAuUUnT6oDeKwE6v1NGQxug'], k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
#                   channel_id              category   join_date  \
# 0   UCAuUUnT6oDeKwE6v1NGQxug        People & Blogs  2006-12-06
# 1   UC7IcJI8PUf5Z3zKxnZvTBog             Education  2010-05-18
# 2   UC9RM-iSvTu1uPJb8X5yp3EQ             Education  2010-02-11
# 3   UC7_gcs09iThXybpVgjHZ_7g             Education  2015-02-09
# 4   UCBa659QWEk1AI4Tg--mrJ2A             Education  2006-05-17
# 5   UCB6PV0cvJpzlcXRG7nz6PpQ  Science & Technology  2009-11-09
# 6   UC9pgQfOXRsp4UKrI8q0zjXQ             Education  2007-02-23
# 7   UCAL3JXZSzSm8AlZyD3nQdBA  Science & Technology  2015-05-01
# 8   UC9uD-W5zQHQuAVT2GdcLCvg  Science & Technology  2015-01-13
# 9   UCA071Pllf2wk-B8Rkwt47bQ  Science & Technology  2012-01-24
# 10  UCH4BNI0-FOK2dMXoFtViWHw             Education  2012-03-17
# 11  UC64UiPJwM_e9AqAd7RiD7JA             Education  2011-10-13
# 12  UCHnyfMqiRRG1u-2MsSQLbXA             Education  2010-07-21
# 13  UC4QZ_LsYcvcq7qOsOhpAX4A  Science & Technology  2007-12-03
# 14  UCAvBcst08Tfo4VNtIaRPTNw       News & Politics  2014-08-19
# 15  UC7vVhkEfw4nOGp8TyDk7RcQ  Science & Technology  2008-07-06
# 16  UCUHW94eEFW7hkUMVaZz4eDg  Science & Technology  2011-06-20
# 17  UCCZVmatSqIMTTB8uExk8xEg         Entertainment  2011-10-23
# 18  UCAhmDfQ1LfOYECmNNWgXJ7Q         Entertainment  2006-04-16
# 19  UC-2YHgc363EdcusLIBbgxzg         Entertainment  2006-10-13
#
#                                                  link  \
# 0   http://www.youtube.com/channel/UCAuUUnT6oDeKwE...
# 1   http://www.youtube.com/channel/UC7IcJI8PUf5Z3z...
# 2   http://www.youtube.com/channel/UC9RM-iSvTu1uPJ...
# 3   http://www.youtube.com/channel/UC7_gcs09iThXyb...
# 4   http://www.youtube.com/channel/UCBa659QWEk1AI4...
# 5   http://www.youtube.com/channel/UCB6PV0cvJpzlcX...
# 6   http://www.youtube.com/channel/UC9pgQfOXRsp4UK...
# 7   http://www.youtube.com/channel/UCAL3JXZSzSm8Al...
# 8   http://www.youtube.com/channel/UC9uD-W5zQHQuAV...
# 9   http://www.youtube.com/channel/UCA071Pllf2wk-B...
# 10  http://www.youtube.com/channel/UCH4BNI0-FOK2dM...
# 11  http://www.youtube.com/channel/UC64UiPJwM_e9Aq...
# 12  http://www.youtube.com/channel/UCHnyfMqiRRG1u-...
# 13  http://www.youtube.com/channel/UC4QZ_LsYcvcq7q...
# 14  http://www.youtube.com/channel/UCAvBcst08Tfo4V...
# 15  http://www.youtube.com/channel/UC7vVhkEfw4nOGp...
# 16  http://www.youtube.com/channel/UCUHW94eEFW7hkU...
# 17  http://www.youtube.com/channel/UCCZVmatSqIMTTB...
# 18  http://www.youtube.com/channel/UCAhmDfQ1LfOYEC...
# 19  http://www.youtube.com/channel/UC-2YHgc363Edcu...
#
#                        name  subscribers  videos
# 0                       TED     14800000    3105
# 1        The School of Life      4870000     724
# 2   Wendover Productions...      2220000     104
# 3            PBS Space Time      1770000     211
# 4                 Tom Scott      1890000     538
# 5               Motherboard      1400000     298
# 6                Lindybeige       907000     625
# 7   Primitive Technology...      9797999      48
# 8           Science Insider       963425     364
# 9        Anonymous Official      2580000     409
# 10  It's Okay To Be Smar...      2940000     292
# 11        Today I Found Out      2070000    1472
# 12               Veritasium      6370000     280
# 13               ColdFusion      1939075     331
# 14           Russia Insight       717926    2872
# 15           BostonDynamics      1400000      37
# 16            minutephysics      4790000     241
# 17              London Real      1090000    5698
# 18               David Icke       650000     888
# 19                Joe Scott       542000     495

# %%
path = '/dlabdata1/youtube_large/jouven/channel_embedding/channels_by_channels_normalized_comments_more_10k/reduced_fpca_200.npz'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCwTkM6CvIsYFaFiMKIKCqHw'], k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
#                   channel_id            category   join_date  \
# 0   UCwTkM6CvIsYFaFiMKIKCqHw  Film and Animation  2005-11-27
# 1   UCwQJJVNbn_Tqze89xf83nhw       Entertainment  2007-09-12
# 2   UCwSIJCMWZC5GDM59wj7pMsg       Entertainment  2006-05-21
# 3   UCwOj_g5BJXjrcqKszOZAAYA       Entertainment  2015-08-10
# 4   UCxxm-M-ca9WJ2k4tq8eP7og              Gaming  2011-03-08
# 5   UCx8Hvu3edWIwQhQZVvMT9aQ       Entertainment  2008-05-22
# 6   UCwBhXADStizYpJyXDUZkATg               Music  2008-04-02
# 7   UCxc5H6i4wBX5D6sGbxEuBDg  Film and Animation  2016-11-23
# 8   UCwLuX0LoZmlIFpfKvCHyELw       Entertainment  2014-09-15
# 9   UCxzzanTaBBNwZqPdLmxFr5w              Comedy  2014-09-12
# 10  UCxW1_hIpo3U7MWNbqzx9oXQ       Entertainment  2007-08-10
# 11  UCwjWT92QZRzA5pgOqFdbh8g              Sports  2009-10-05
# 12  UCyouSlyNTfwX_pnGvlfIL3Q  Film and Animation  2016-08-30
# 13  UCvBxvcqGSQkbs1BRafBIYSg               Music  2009-12-22
# 14  UCwF3VyalTHzL0L-GDlwtbRw              Gaming  2013-07-12
# 15  UCwodgWLBaJ11UYpcWezh2Ng               Music  2009-02-23
# 16  UCwd8uu2mtJUgHYRffUl2yPQ               Music  2006-05-05
# 17  UCvXB6Bdvh3fREeElPs0mGbQ              Gaming  2009-10-01
# 18  UCy1F61QvUUQXAXi2Voa_fUw              Sports  2006-07-05
# 19  UCy1zUiuM8c-cQRaef4ABfmA              Gaming  2016-01-12
#
#                                                  link  \
# 0   http://www.youtube.com/channel/UCwTkM6CvIsYFaF...
# 1   http://www.youtube.com/channel/UCwQJJVNbn_Tqze...
# 2   http://www.youtube.com/channel/UCwSIJCMWZC5GDM...
# 3   http://www.youtube.com/channel/UCwOj_g5BJXjrcq...
# 4   http://www.youtube.com/channel/UCxxm-M-ca9WJ2k...
# 5   http://www.youtube.com/channel/UCx8Hvu3edWIwQh...
# 6   http://www.youtube.com/channel/UCwBhXADStizYpJ...
# 7   http://www.youtube.com/channel/UCxc5H6i4wBX5D6...
# 8   http://www.youtube.com/channel/UCwLuX0LoZmlIFp...
# 9   http://www.youtube.com/channel/UCxzzanTaBBNwZq...
# 10  http://www.youtube.com/channel/UCxW1_hIpo3U7MW...
# 11  http://www.youtube.com/channel/UCwjWT92QZRzA5p...
# 12  http://www.youtube.com/channel/UCyouSlyNTfwX_p...
# 13  http://www.youtube.com/channel/UCvBxvcqGSQkbs1...
# 14  http://www.youtube.com/channel/UCwF3VyalTHzL0L...
# 15  http://www.youtube.com/channel/UCwodgWLBaJ11UY...
# 16  http://www.youtube.com/channel/UCwd8uu2mtJUgHY...
# 17  http://www.youtube.com/channel/UCvXB6Bdvh3fREe...
# 18  http://www.youtube.com/channel/UCy1F61QvUUQXAX...
# 19  http://www.youtube.com/channel/UCy1zUiuM8c-cQR...
#
#                        name  subscribers  videos
# 0            James Bond 007       115000     407
# 1   The Asylum - Officia...        11200     210
# 2            Prime Video UK        53200     996
# 3         Late to the Party        45300     975
# 4            Johnny Jawbone        50500     143
# 5                 medici.tv       197434    3005
# 6              Kellee Maize        20000      48
# 7                 StoryDive        44200      69
# 8          30 Rock Official        31100     240
# 9   Best of Simpsons Cha...        53400      68
# 10                GoldDerby        22100    4953
# 11               Lantern TV        24600    2529
# 12           Amazon Studios        69900     358
# 13        Flight Facilities       197000     130
# 14               EVE Online        88600     883
# 15              metricmusic       114000      86
# 16        Secession Studios       279000     286
# 17       Level Up Your Game        43100    1071
# 18       NTT IndyCar Series       251000    3990
# 19          Weekend Warrior        56000     128

# %%
path = '/dlabdata1/youtube_large/jouven/channel_embedding/channels_by_channels_normalized_comments_more_10k/reduced_fpca_200.npz'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCISF5OGuAtSLNF24TKTnXag'], k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
#                   channel_id            category   join_date  \
# 0   UCISF5OGuAtSLNF24TKTnXag  Film and Animation  2013-12-17
# 1   UCHKDtSVVEc686EW7jRSCpZA       Entertainment  2007-04-01
# 2   UCH-blHqGEo1dE35f6_y0j5A               Music  2015-10-31
# 3   UCLFd05hT4i87cu-IjSIwLUA              Gaming  2014-12-20
# 4   UCJDFINJB23y0MeXO6BX7EFw  Film and Animation  2011-08-18
# 5   UCMBpJ5kRKU1X5QBc_hmFyBg  Film and Animation  2013-03-14
# 6   UC8Wj98MR_oUHBpTjLsE3HuA  Film and Animation  2010-10-10
# 7   UCUmsZrGGKvQD8E3kSXQNs2g  Film and Animation  2011-08-17
# 8   UCKZphsoYAAIe2o2uItTQbOw  Film and Animation  2016-10-25
# 9   UCMOjuRCO7hLk4DNYXX8Tz4A  Film and Animation  2011-10-16
# 10  UCFmJVZwMulqflPJQeLs8kow              Gaming  2017-01-27
# 11  UCOuR-pJDNOEg3AOcK9Tuiig  Film and Animation  2012-08-09
# 12  UCJfHkeFkLLFK1zoQwKkSd9w       Entertainment  2017-04-03
# 13  UCDfRx9cA6fB-xiePpGE4ZEQ  Film and Animation  2013-10-02
# 14  UCJYxrxnPLiiAhJyVW3xK6QQ       Entertainment  2017-01-29
# 15  UCFSWlEpDBctm2ACzdU96YDg      People & Blogs  2015-01-30
# 16  UCJpL0JQKe7I2EbphDI7IKPw       Entertainment  2016-04-24
# 17  UCQuFY1w0Kx6-oneM0MYpIxA      People & Blogs  2015-05-28
# 18  UCQKvmqWnSf9qn3PYmG4HIuQ       Entertainment  2015-05-28
# 19  UCPflSzRRyzK2hhbVxNAnrhw  Film and Animation  2012-03-31
#
#                                                  link  \
# 0   http://www.youtube.com/channel/UCISF5OGuAtSLNF...
# 1   http://www.youtube.com/channel/UCHKDtSVVEc686E...
# 2   http://www.youtube.com/channel/UCH-blHqGEo1dE3...
# 3   http://www.youtube.com/channel/UCLFd05hT4i87cu...
# 4   http://www.youtube.com/channel/UCJDFINJB23y0Me...
# 5   http://www.youtube.com/channel/UCMBpJ5kRKU1X5Q...
# 6   http://www.youtube.com/channel/UC8Wj98MR_oUHBp...
# 7   http://www.youtube.com/channel/UCUmsZrGGKvQD8E...
# 8   http://www.youtube.com/channel/UCKZphsoYAAIe2o...
# 9   http://www.youtube.com/channel/UCMOjuRCO7hLk4D...
# 10  http://www.youtube.com/channel/UCFmJVZwMulqflP...
# 11  http://www.youtube.com/channel/UCOuR-pJDNOEg3A...
# 12  http://www.youtube.com/channel/UCJfHkeFkLLFK1z...
# 13  http://www.youtube.com/channel/UCDfRx9cA6fB-xi...
# 14  http://www.youtube.com/channel/UCJYxrxnPLiiAhJ...
# 15  http://www.youtube.com/channel/UCFSWlEpDBctm2A...
# 16  http://www.youtube.com/channel/UCJpL0JQKe7I2Eb...
# 17  http://www.youtube.com/channel/UCQuFY1w0Kx6-on...
# 18  http://www.youtube.com/channel/UCQKvmqWnSf9qn3...
# 19  http://www.youtube.com/channel/UCPflSzRRyzK2hh...
#
#                        name  subscribers  videos
# 0                Magpiepony       736000     304
# 1   Scribbler Production...       327000    1767
# 2                   Maloney       188882     159
# 3                  Starbeam       363000      93
# 4                   Rossali       497000     149
# 5                   YoshTea       131000     155
# 6               Pinkie Rose       247000     167
# 7          QuestionedTurkey       158000     751
# 8   Shavs Media Producti...       143000     202
# 9           MarlineAnimates       225000      16
# 10                   Geloxx       155000     143
# 11               Laizy- boy       312000     158
# 12             Foxji Gaming        20000     177
# 13             Lychee Chong       222679      42
# 14              Cocoa's Art       111185     277
# 15        Ijustwannahavefun       319000      77
# 16       Undertale Comic TV       722000     539
# 17              Tori Sakura        86800     106
# 18         SuperShadic X250       195000     251
# 19               Pinkie Pie      1229394     451

# %% [markdown]
# ### Channels selected over the whole comments dataset
# We randomly choose 10 000 users over the dataset.
# For each user, we then pick two channels at random in the set of channels this user commented in.

# %%
with open("/dlabdata1/youtube_large/jouven/channels_more_10k/channels_tuple_user_walk.pkl",'rb') as f:
     channels_tuple = pickle.load(f)
f.close()

# %% [markdown]
# #### Random walk

# %%
def get_random_walk(df_embedding):
    with open("/dlabdata1/youtube_large/jouven/channels_more_10k/channels_tuple_random_walk.pkl",'rb') as f:
         random_walk_channels = pickle.load(f)
    f.close()
    random_walk_distance = 0
    for val in random_walk_channels:
        random_walk_distance += distance.euclidean(df_embedding.iloc[val[0]], df_embedding.iloc[val[1]])
    return random_walk_distance

# %% [markdown]
# #### Compute metrics: users walk distance and relative nearest neighbor ranking
#
# In this section we want to measure the euclidian distance of a user walk compared to a random walk.
#
# user walk: Euclidean distance in the embedding space between two randomly channels of a user.
# random walk: Euclidean distance in the embedding space between two randomly channels.
# position: Position of a channel taken from user u relatively of another channel taken from the same user in terms of its nearest neighbor ranking.

# %%
'''
Get the position of ref_channel relative to second_channel in terms of its nearest neighbors ranking.
PARAMETER:
    - ref_channel: The reference channel on which wwe compute it's k nearest neighbor
    - second_channel: The channel where we compute it's ranking relatively to ref_channel
    - dist: Euclidean distance between ref_channel and second_channel
    - index: annoy index
    - df_embedding: DataFrame representing the embedding space

RETURN: The position of second_channel relatively to ref_channel in terms of it's ranking

'''
def get_ranking_position_between_channels(ref_channel, second_channel, dist, index, df_embedding):
    
    nearest_neighbors_index = index.get_nns_by_item(ref_channel, len(df_embedding), search_k = 100000000)
    dist_k_th_nearest = distance.euclidean(df_embedding.iloc[ref_channel], 
                                           df_embedding.iloc[nearest_neighbors_index[len(nearest_neighbors_index)-1]])
    for i in range(0, len(nearest_neighbors_index)):
        if nearest_neighbors_index[i] == second_channel:
            return i

# %%
users_walk_tab = []
ranking_position_tab = []

len_random_set = len(channels_tuple)
len_embedding = len(channels_id)

#path = '/dlabdata1/youtube_large/jouven/channel_embedding/limited_normalized_50/'
#files = glob.glob(path + '*.npz') 
files = ['/dlabdata1/youtube_large/jouven/channel_embedding/channels_by_channels_normalized_comments_more_10k/reduced_fpca_200.npz']
for file in files: 
    print('file ', file)
    df_embedding = get_dataframe_in_embedding_space(file)
    n_comp = df_embedding.shape[1]
    print('n_comp ', n_comp)
    random_walk_distance = get_random_walk(df_embedding)
        
    index = get_annoy_index(df_embedding)

    users_walk = 0
    ranking_position = 0

    for ref_channel, second_channel in channels_tuple:
        dist = distance.euclidean(df_embedding.iloc[ref_channel], df_embedding.iloc[second_channel])
        users_walk += dist
        ranking_position += get_ranking_position_between_channels(ref_channel, second_channel, dist, index, df_embedding)
    
    users_walk_tab.append(users_walk/random_walk_distance)
    ranking_position_tab.append(ranking_position/(len_random_set*len_embedding))
# Out:
# file  /dlabdata1/youtube_large/jouven/channel_embedding/channels_by_channels_normalized_comments_more_10k/reduced_fpca_200.npz
# n_comp  200

# %%
users_walk_tab
# Out:
# [8.968204126584432]

# %%
ranking_position_tab
# Out:
# [0.7003344443664772]
