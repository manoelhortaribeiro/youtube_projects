# %% [markdown]
# ## NOTEBOOK DESCRIPTION:
#
# This notebook checks the behaviour of the embedding space:
# - It first checks manually the nearest neighbors of some selected channels
# - It also compute the user jumper score which is a first barrier on the evaluation of the embedding

# %%
import pickle
import os
import sys
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE

scriptpath = "/home/jouven/youtube_projects/"
sys.path.append(os.path.abspath(scriptpath))

from helpers.helpers_channels_more_10k import *
from helpers.helpers_channel_embedding import *

scriptpath = "/home/jouven/youtube_projects"
sys.path.append(os.path.abspath(scriptpath))
from helpers.config_threshold_value import *

# %% [markdown]
# ### Useful functions

# %%
# Selected channels and id-index mapping
dict_channel_ind, dict_ind_channel, channels_id = filtered_channels_index_id_mapping()

# %%
PATH = '/dlabdata1/youtube_large/jouven/channel_embedding/channels_more_10k/proximity_graph/channel_by_channel_ln_30/reduced_fpca_200.npz'

# %%
channelcrawler = pd.read_csv("/dlabdata1/youtube_large/df_channels_en.tsv.gz", sep='\t')
# Select the rows being in the select channels
channelcrawler = channelcrawler[channelcrawler['channel'].apply(lambda row: row in channels_id)]

# %%
channelcrawler.head()
# Out:
#      category_cc   join_date                   channel  \
# 0         Gaming  2010-04-29  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 1      Education  2006-09-01  UCbCmjCuTUZos6Inko4u57UQ
# 2  Entertainment  2006-09-20  UCpEhnqL0y41EpW2TvWAHD7Q
# 3  Howto & Style  2016-11-15  UC295-Dw_tDNtZXFeAPAW6Aw
# 4         Sports  2007-05-11  UCJ5v_MCY6GNUBTO8-D3XoAg
#
#                    name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                PewDiePie       101000000       3956                 3.0
# 1  Cocomelon - Nursery ...        60100000        458                 7.0
# 2                SET India        56018869      32661                 8.0
# 3          5-Minute Crafts        60600000       3591                 9.0
# 4                      WWE        48400000      43421                11.0
#
#    weights
# 0    2.087
# 1    2.087
# 2    2.087
# 3    2.087
# 4    2.087

# %%
channelcrawler['category_cc'].unique()
# Out:
# array(['Gaming', 'Education', 'Entertainment', 'Howto & Style', 'Sports',
#        'Music', 'Film and Animation', 'Comedy', 'Nonprofits & Activism',
#        'People & Blogs', 'News & Politics', 'Science & Technology',
#        'Pets & Animals', 'Autos & Vehicles', 'Travel & Events', nan],
#       dtype=object)

# %% [markdown]
# ### Manually check the neirest neighbors of some selected channels

# %% [markdown]
# First to check how good is the embedding space, we are going to choose a channel and it's k closest channels in the embedding space. By looking at these channels in the YouTube website, we have a sense of how good/bad is the embedding.

# %%
# Looking at the neirest neigbors of `Shaaanxo` being a girl fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCMpOz2KEfkSdd5JeIJh_fxw'], dict_ind_channel, k= 20, embedding_type = 'proximity_graph')
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel     category_cc   join_date            name_cc  \
# 0   UCMpOz2KEfkSdd5JeIJh_fxw   Howto & Style  2009-01-18           Shaaanxo
# 1   UC21yq4sq8uxTcfgIxxyE9VQ   Howto & Style  2011-06-27        Carli Bybel
# 2   UCz0Qnv6KczUe3NH1wnpmqhA   Howto & Style  2006-11-27   Nicole Guerriero
# 3   UC9TreTE-iXwfwQl72DzDurA   Howto & Style  2009-01-04     Kandee Johnson
# 4   UCK2ACorzpH-igxuHZ2ObCEA  People & Blogs  2010-03-10       itsJudysLife
# 5   UCtC8m_F7jX2fGOQ3_nomg4g   Howto & Style  2006-11-08         Emily Noel
# 6   UCjEPwaev8_zrpafISAPhruA   Howto & Style  2007-06-07  Sam & Nic Chapman
# 7   UCLFW3EKD2My9swWH4eTLaYw   Howto & Style  2012-03-06      Chloe Morello
# 8   UC0FK_3h0Ec2iBKJ_Ah2su7A   Howto & Style  2008-04-07        itsjudytime
# 9   UCCvoAe__WFYMNAEN-C-CtYA   Howto & Style  2008-08-05         Wayne Goss
# 10  UCooQN8b9yPeNQgUFa9S5xew   Howto & Style  2009-07-22     Samantha Maria
# 11  UCXbQzhqSvgVZTUyi1T4AU3w   Howto & Style  2011-08-31      Lauren Curtis
# 12  UCzco9CewPf0F-SP1p6LhWrw   Howto & Style  2008-07-07      Gigi Gorgeous
# 13  UCJttQwY6KBhwov_2wKywtqA   Howto & Style  2010-06-27     NikkiPhillippi
# 14  UCo5zIpjl2OQkYatd8R0bDaw   Howto & Style  2008-06-15        Dulce Candy
# 15  UCK-4JyAcQYBasFAe367on7w   Howto & Style  2009-05-29         RachhLoves
# 16  UCz5ppm1BYc7tgUYIel3EWJw   Howto & Style  2007-09-29        ilikeweylie
# 17  UCOtoxvHLKrIlWbt4MRBWfbQ   Howto & Style  2013-02-28    RawBeautyKristi
# 18  UCgWfS_47YPVbKx5EK4FLm4A   Howto & Style  2010-03-01            Jenn Im
# 19  UCERTKUMXl6x8G79BmG6KtpQ   Howto & Style  2010-06-17      Meghan Rienks
#
#     subscribers_cc  videos_cc  subscriber_rank_sb  weights
# 0          3215340       1422              3566.0   2.2780
# 1          6190000        546              1234.0   2.0870
# 2          2870000        664              4160.0   2.3400
# 3          3900000        630              2276.0   2.1660
# 4          1660000       2893              8765.0   2.5830
# 5          1020000       1750             14802.0   2.7895
# 6          2160000        922              6338.0   2.4625
# 7          2700000        518              4490.0   2.3680
# 8          1330000        643             11957.0   2.6995
# 9          3670000       1357              2740.0   2.2180
# 10         1800000        795              8037.0   2.5600
# 11         3530000        379              3067.0   2.2335
# 12         2910000        513              4079.0   2.3260
# 13         1360000        959             11569.0   2.6770
# 14         2220000       1055              6090.0   2.4605
# 15         1450000        851              9742.0   2.6130
# 16         1710000        495              8545.0   2.5525
# 17          751000        627             18966.0   2.8875
# 18         2460000        672              4956.0   2.3655
# 19         2190000        761              6298.0   2.4700

# %%
# Looking at the neirest neigbors of `Alex Costa` being a men fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCZyCposXwcyopaACep44maQ'], dict_ind_channel, k= 20, embedding_type = 'proximity_graph')
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel           category_cc   join_date  \
# 0   UCqjwF8rxRsotnojGl4gM0Zw                Sports  2013-02-05
# 1   UCC-ygwC3ZfSRhIcao8a2zyQ         Howto & Style  2009-01-27
# 2   UCRAWGR5ySuIDNrotce8pI3w         Entertainment  2015-02-15
# 3   UCs_6DXZROU29pLvgQdCx4Ww             Education  2014-07-26
# 4   UC97k3hlbE-1rVN8y56zyEEA         Howto & Style  2009-02-02
# 5   UCDOZDfbVGOrywV4n0WeaRAA  Science & Technology  2011-10-13
# 6   UCVVAnxQ2YMC_qlc7QfPA2YQ         Howto & Style  2015-05-20
# 7   UCfYCRj25JJQ41JGPqiqXmJw       Travel & Events  2007-11-04
# 8   UC0ahC64OhIAS11TJX9Ig86A                Sports  2012-08-04
# 9   UCWwgaK7x0_FR1goeSRazfsQ  Science & Technology  2006-03-11
# 10  UCKuBf7CRNf4OYoDyTtAL5fg                Gaming  2018-02-27
# 11  UCgef_fFE9FEFZGQcHqp9aZw      Autos & Vehicles  2006-10-16
# 12  UCA1689_ZsbSvn6GIUz_ywrQ  Science & Technology  2009-10-18
# 13  UCBdw4dLCLLHmTgAOnW4V0hQ         Entertainment  2005-11-24
# 14  UCBzfdgfIAANfgP3xyhVaEfQ      Autos & Vehicles  2006-07-02
# 15  UCIJ0lLcABPdYGp7pRMGccAQ                Sports  2007-01-01
# 16  UCGbHUZA7_8Esbt8Pp97S2EQ                Gaming  2015-05-15
# 17  UCKmkpoEqg1sOMGEiIysP8Tw             Education  2008-11-10
# 18  UCaKZDEMDdQc8t6GzFj1_TDw             Education  2015-04-15
# 19  UCu3fngdIGYCQ-c7YG0e9FuQ      Autos & Vehicles  2006-08-31
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0             OFFICIALTHENX         4280000        212              1893.0
# 1   Slikhaar TV - Mens h...         2030000        603              6676.0
# 2                    SinsTV         1210000        113             12269.0
# 3                   Dan Lok         1900000       1363              6772.0
# 4          Bodybuilding.com         4540000       2398              1793.0
# 5          Bernardo Almeida          389130        525             43443.0
# 6            AlmazanKitchen         2740000        371              3711.0
# 7                  Sam Chui         1507443        270              7688.0
# 8             STRENGTH WARS         1146994        135             14106.0
# 9                   Samsung         3880000        939              2303.0
# 10              PUBG MOBILE         1489752        646              9145.0
# 11           RoyalJordanian         1220000       1107             12224.0
# 12           Ramesh Bakotra          963000       1209             15484.0
# 13                 The Rock         4470000        193              1879.0
# 14              Marchettino          567574       2075             29212.0
# 15       People are Awesome         3340000        579              3239.0
# 16               TalkToHand          824000        272             16673.0
# 17          Evan Carmichael         2020000       6119              6390.0
# 18              Be Inspired         5585165         96              1200.0
# 19      Matt Maran Motoring          396000       1909             45674.0
#
#     weights
# 0    2.0870
# 1    2.4925
# 2    2.7000
# 3    2.4920
# 4    2.0870
# 5    3.3865
# 6    2.2700
# 7    2.5365
# 8    2.8115
# 9    2.1665
# 10   2.5590
# 11   2.6980
# 12   2.8245
# 13   2.0870
# 14   2.9960
# 15   2.2720
# 16   2.8200
# 17   2.4580
# 18   2.0870
# 19   3.3290

# %%
# Looking at the neirest neigbors of `Magpiepony` which is a kids film
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCISF5OGuAtSLNF24TKTnXag'], dict_ind_channel, k= 20, embedding_type = 'proximity_graph')
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel         category_cc   join_date  \
# 0   UCISF5OGuAtSLNF24TKTnXag  Film and Animation  2013-12-17
# 1   UC94Z4HZJkhPm94YPH1GE3bw       Entertainment  2011-12-13
# 2   UC8Wj98MR_oUHBpTjLsE3HuA  Film and Animation  2010-10-10
# 3   UCPflSzRRyzK2hhbVxNAnrhw  Film and Animation  2012-03-31
# 4   UCHKDtSVVEc686EW7jRSCpZA       Entertainment  2007-04-01
# 5   UCMzfiTDOiuax4C7H1Uu88mw              Gaming  2012-02-17
# 6   UCsExrmgcYO0e--Q_hCdKfvg       Entertainment  2010-05-26
# 7   UCcZjYWpM72s-1cinYfeSCag      People & Blogs  2010-08-05
# 8   UCVv1vQYLgJ6STMJkK2aWMyQ       Entertainment  2015-07-07
# 9   UCn5wtpa-WcFPeAXZumbZlyw  Film and Animation  2011-07-20
# 10  UCyILnz6X5gFVkAR5D6w9xdA       Entertainment  2013-03-30
# 11  UCEVLYsU-nsH974JYihF2vSA               Music  2015-09-26
# 12  UCo1uLla-0wximfRNIzJpJRg      People & Blogs  2009-01-19
# 13  UCNzsYU0aWwjERj-9Y9HUEng       Entertainment  2015-12-14
# 14  UCwC-DciMGGk9AgpJ3hpreHw       Entertainment  2014-03-11
# 15  UCCLFxVP-PFDk7yZj208aAgg      Pets & Animals  2014-04-28
# 16  UC_Ucb4QsP0Mvg3qwP6ubpbw       Entertainment  2009-06-26
# 17  UCGydrkfIhUDNCotYQI8TJhA       Entertainment  2007-04-12
# 18  UCVKVmfXSkqhfCIpLLXFF26w  Film and Animation  2013-09-05
# 19  UCsyE3v8JFceD19NQ0RZPKuQ       Entertainment  2013-02-12
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                Magpiepony          736000        304             21120.0
# 1                 EileMonty          504000        211             33178.0
# 2               Pinkie Rose          247000        167             72414.0
# 3                Pinkie Pie         1229394        451             11840.0
# 4   Scribbler Production...          327000       1767             54604.0
# 5              eric wartick          168734        103            102730.0
# 6              Nerd Caliber          368000       2145             41049.0
# 7         DisneyFanatic2364          205000       1026             88028.0
# 8                 Tridashie          252744         48             67004.0
# 9                 EDplus777          687592        214             24914.0
# 10         viralutubevideos          146000        748            110885.0
# 11          The Goonie Show          106710         89            146727.0
# 12           World of Vegan           87600        504            182006.0
# 13  Little Angel: Nurser...         6570000        902               509.0
# 14       Talking Tom Heroes         2870000        156              3793.0
# 15               MashupZone         1470000        188              9976.0
# 16  Disney Channel Afric...         1126597       2594             10449.0
# 17       Cartoon Network UK         4310000       3293              1828.0
# 18               Moliminous          228000        778             79008.0
# 19                   Aleana          127000        264            133237.0
#
#     weights
# 0    2.9225
# 1    3.2020
# 2    3.8050
# 3    2.6965
# 4    3.5110
# 5    3.9895
# 6    3.3700
# 7    4.3405
# 8    4.0465
# 9    2.9640
# 10   4.9945
# 11   4.1045
# 12   5.6065
# 13   2.0870
# 14   2.2675
# 15   2.6375
# 16   2.6540
# 17   2.0870
# 18   3.6730
# 19   5.5020

# %%
# Looking at neirest neigbors of `Beyond the trailer` a channel for analysis of films
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCAXR2zenCwvRIyQd9ydtfaA'], dict_ind_channel, k= 20, embedding_type = 'proximity_graph')
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel         category_cc   join_date  \
# 0   UCAXR2zenCwvRIyQd9ydtfaA       Entertainment  2008-11-03
# 1   UC20DNxT_UjT49mYOIocJAww       Entertainment  2012-06-20
# 2   UCkDSAQ_5-yx5hmuvUcsJL7A       Entertainment  2013-08-16
# 3   UCKxQmKgrkUv4S7P5w0pLayw       Entertainment  2013-07-09
# 4   UCQMbqH7xJu5aTAPQ9y_U7WQ       Entertainment  2009-03-05
# 5   UCQzdMyuz0Lf4zo4uGcEujFw       Entertainment  2007-09-29
# 6   UCCqEeDAUf4Mg0GgEN658tkA       Entertainment  2011-01-06
# 7   UC64mtTJJgsU0Lty-7aCB-7w  Film and Animation  2011-06-25
# 8   UC7yRILFFJ2QZCykymr8LPwA     News & Politics  2011-10-08
# 9   UCBS7ypf4ccm6e_bu35EiAAA  Film and Animation  2009-04-11
# 10  UC4kjDjhexSVuC8JWk4ZanFw       Entertainment  2012-04-17
# 11  UC8CbFnDTYkiVweaz8y9wd_Q       Entertainment  2016-07-30
# 12  UClG1AcuVOU5Cn-ivHm3JRoA  Film and Animation  2018-01-07
# 13  UCkkcUZJ-vrt3HomsacbTNLg       Entertainment  2010-02-20
# 14  UCgIqhB8oD5SZ0yUSp71VCOQ       Entertainment  2015-03-03
# 15  UCtoMyXF4VFY3cB8fUcn7N4A       Entertainment  2006-09-19
# 16  UCz97F7dMxBNOfGYu3rx8aCw       Entertainment  2006-06-02
# 17  UCHCph-_jLba_9atyCZJPLQQ  Film and Animation  2007-03-05
# 18  UCRX7UEyE8kp35mPrgC2sosA  Film and Animation  2011-06-27
# 19  UCM7Srv4mxJejt2NLmumkRRQ       Entertainment  2011-08-17
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0        Beyond The Trailer          853000       5064             19744.0
# 1            ComicBookCast2          473000       7153             34911.0
# 2          Mr Sunday Movies         1090000        745             14457.0
# 3          Comics Explained         1750000       1886              8074.0
# 4   Fandom Entertainment...         1570000      10813              9597.0
# 5             GameofThrones         4751781        822              1713.0
# 6           Chris Stuckmann         1580000       1400              8486.0
# 7                Trevschan2          229000       3926             78996.0
# 8             New Rockstars         2340000       1045              5223.0
# 9         Everything Always          467000        420             31489.0
# 10           Variant Comics         1920000        739              7073.0
# 11         Star Wars Theory         1729073       1254              5979.0
# 12        The Cosmic Wonder          502993        744             34500.0
# 13            ForneverWorld          533000       4441             33294.0
# 14               Geekdom101          642000       1941             25251.0
# 15             AMC Theatres          396000       9046             44969.0
# 16  Sony Pictures Entert...         3760000       3451              2363.0
# 17  How It Should Have E...         9270000        355               608.0
# 18  JoBlo Movie Trailers...         2070000       5081              6408.0
# 19              WhatCulture         1890000       2180              7137.0
#
#     weights
# 0    2.8635
# 1    3.2230
# 2    2.8405
# 3    2.5550
# 4    2.5995
# 5    2.0870
# 6    2.5600
# 7    3.6780
# 8    2.3970
# 9    3.1295
# 10   2.5165
# 11   2.4605
# 12   3.1670
# 13   3.2015
# 14   2.9640
# 15   3.3400
# 16   2.1790
# 17   2.0870
# 18   2.4595
# 19   2.5220

# %% [markdown]
# ### User jumper implementation

# %%
# We randomly choose 3 000 users and for each user we select a random pair of channel
# channels_tuple = [(channel_1, channel_2), (...)]

with open(os.path.join(COMMON_PATH, "channels_tuple_user_walk.pkl"),'rb') as f:
     channels_tuple = pickle.load(f)
f.close()

# %%
files = [PATH]
users_walk_tab, ranking_position_tab = get_user_walk_and_position_ratio(files, channels_tuple, embedding_type = 'proximity_graph')
# Out:
# file  /dlabdata1/youtube_large/jouven/channel_embedding/channels_more_10k/proximity_graph/channel_by_channel_ln_30/reduced_fpca_200.npz
# n_comp  200

# %%
print('User walk = ' + str(users_walk_tab))
print('Ranking position ratio = ' + str(ranking_position_tab))
# Out:
# User walk = [19.1791386908005]
# Ranking position ratio = [0.6086923432273759]
