# %% [markdown]
# This notebook checks the behaviour of the embedding space

# %%
import pickle
import random
import glob
import os
import sys
import scipy.sparse
import re
#import torch

import numpy as np
import pandas as pd

from annoy import AnnoyIndex
from scipy.spatial import distance

scriptpath = "../../"
sys.path.append(os.path.abspath(scriptpath))
from helpers.helpers_channels_more_300 import *

# %%
'''
Retrieve the array obtained by apllying the dimentionality reduction algorithm
graph_matrix: SHAPE: (channels, n_comp)

PARAMETER:
    - file_path: the path where the embedding graph is stored

RETURN: 
    - df: DataFrame representing the graph in the embedding space
'''
def create_dataframe_in_embedding_space(model_path):
    graph_matrix = torch.load(model_path)['embedding'].cpu().detach().numpy()
    df = pd.DataFrame(graph_matrix)
    df = df.rename(lambda x: 'dr'+str(x), axis='columns')
    return df

def get_dataframe_in_embedding_space(model_path):
    #graph_matrix = torch.load(model_path)['embedding'].cpu().detach().numpy()
    #df = pd.DataFrame(graph_matrix)
    #df = df.rename(lambda x: 'dr'+str(x), axis='columns')
    return pd.read_csv(model_path, compression='gzip')

# %%
model_path = '/dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/CONTEXT_True_20_SUBSAMPLING_False_0.0043/models/model1.pth'
df = create_dataframe_in_embedding_space(model_path)

# %%
df.shape
# Out:
# (129616, 200)

# %%
df.to_csv('/dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/CONTEXT_True_20_SUBSAMPLING_False_0.0043/models/embedding1.csv.gz', compression='gzip', index = False)

# %%
# Selected channels and id-index mapping
dict_channel_ind, dict_ind_channel, channels_id = filtered_channels_index_id_mapping()

# %% [markdown]
# ### Find k closest channel using annoy library

# %% [markdown]
# First to check how good is the embedding space, we are going to choose a channel and it's k closest channels in the embedding space. By looking at these channels in the YouTube website, we should get similar channels if the embedding space is good.

# %%
channelcrawler = pd.read_csv("/dlabdata1/youtube_large/channelcrawler.csv")
channelcrawler['channel_id'] = channelcrawler['link'].str.split('/').str[-1]
channelcrawler = channelcrawler[channelcrawler['channel_id'].apply(lambda row: row in channels_id)]

# %%
channelcrawler['category'].unique()
# Out:
# array(['Film and Animation', 'Music', 'Comedy', 'Gaming',
#        'Science & Technology', 'Sports', 'Entertainment', 'Education',
#        'Nonprofits & Activism', 'People & Blogs', 'Howto & Style',
#        'News & Politics', 'Travel & Events', 'Autos & Vehicles',
#        'Pets & Animals', nan], dtype=object)

# %%
'''
Retrieve the array obtained by apllying the dimentinality reductin algorithm
graph_matrix: SHAPE: (channels, n_comp)

PARAMETERS:
    - df_embedding: DataFrame representing the graph in the embedding space
    - n_comp: number of components to use after the dimentionalit reduction

RETURN: The annoy index
'''
def get_annoy_index(df):
    index = AnnoyIndex(df.shape[1], "euclidean")  # Length of item vector that will be indexed
    df.apply(lambda row: index.add_item(row.name, np.array(row)), axis = 1)
    index.build(100) # 100 trees
    return index

# %%
def get_k_nearest_neighbors(path, ref_index_channel, k = 20):
    df = get_dataframe_in_embedding_space(path)
    index = get_annoy_index(df)
    nearest_neighbors_index = index.get_nns_by_item(ref_index_channel, k)
    nearest_neighbors_id = [dict_ind_channel[val] for val in nearest_neighbors_index]
    return nearest_neighbors_id

# %%
channelcrawler[channelcrawler['name'] == 'TEDx Talks']
# Out:
#                     category   join_date  \
# 12422  Nonprofits & Activism  2009-06-23
#
#                                                     link        name  \
# 12422  http://www.youtube.com/channel/UCsT0YIqwnpJCM-...  TEDx Talks
#
#        subscribers  videos                channel_id
# 12422     20700000  141627  UCsT0YIqwnpJCM-mx7-gSA4Q

# %%
path = '/dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/CONTEXT_True_20_SUBSAMPLING_False_0.0043/models/embedding1.csv.gz'
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCMpOz2KEfkSdd5JeIJh_fxw'], k= 40)

# %%
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
#                   channel_id        category   join_date  \
# 0   UCMpOz2KEfkSdd5JeIJh_fxw   Howto & Style  2009-01-18
# 1   UCbO9bltbkYwa56nZFQx6XJg   Howto & Style  2014-07-17
# 2   UCzTKskwIc_-a0cGvCXA848Q   Howto & Style  2008-06-23
# 3   UCkvK_5omS-42Ovgah8KRKtg   Howto & Style  2006-02-14
# 4   UC21yq4sq8uxTcfgIxxyE9VQ   Howto & Style  2011-06-27
# 5   UCGwPbAQdGA3_88WBuGtg9tw   Howto & Style  2010-12-03
# 6   UCF2oW5-MO8dB6ul9WH9xi0A  People & Blogs  2007-01-04
# 7   UCKMugoa0uHpjUuq14yOpagw   Howto & Style  2009-06-09
# 8   UCc6W7efUSkd9YYoxOnctlFg   Entertainment  2009-06-08
# 9   UC8v4vz_n2rys6Yxpj8LuOBA   Howto & Style  2013-01-26
# 10  UCz0Qnv6KczUe3NH1wnpmqhA   Howto & Style  2006-11-27
# 11  UC6jgzx2g3nlbaYkd8EMweKA   Howto & Style  2010-09-07
# 12  UCCvoAe__WFYMNAEN-C-CtYA   Howto & Style  2008-08-05
# 13  UC9TreTE-iXwfwQl72DzDurA   Howto & Style  2009-01-04
# 14  UC2LgZ_4GzSFQS-3a87_Jc6w  People & Blogs  2009-03-17
# 15  UCxj0QizmFhx7kVKSArHBCTA   Howto & Style  2011-03-09
# 16  UCjEPwaev8_zrpafISAPhruA   Howto & Style  2007-06-07
# 17  UC_GvMVffgctSISDkeWlKhXQ   Howto & Style  2009-06-29
# 18  UC9gFih9rw0zNCK3ZtoKQQyA          Comedy  2010-02-16
# 19  UCnjk78dOMbH-IMwNYLKSaqg   Howto & Style  2009-11-08
# 20  UC4GtJWgv_PLBiWFihNGbF0g   Howto & Style  2009-01-31
# 21  UC0FK_3h0Ec2iBKJ_Ah2su7A   Howto & Style  2008-04-07
# 22  UCG9nVSLp4nQlW79sY5ihRrg   Howto & Style  2013-08-17
# 23  UCLwUd5KtYONsRJ3UAOojZ0w  People & Blogs  2007-10-22
# 24  UCT8z80a4ESgO2Y4qajk-iXw   Howto & Style  2010-02-11
# 25  UCzTtkLZFy6wqD4SsA9_fTtw   Howto & Style  2009-02-16
# 26  UCuYx81nzzz4OFQrhbKDzTng   Howto & Style  2006-07-18
# 27  UCzqbfYjQmf9nLQPMxVgPhiA   Howto & Style  2010-11-11
# 28  UC2LOY_zd1ZAc1kZPyzoqhMQ   Entertainment  2009-08-08
# 29  UCDHQbU57NZilrhbuZNbQcRA   Howto & Style  2013-02-27
# 30  UCzJIliq68IHSn-Kwgjeg2AQ   Howto & Style  2006-03-12
# 31  UC0KiGuCTrehqzSQ7ikjxSQw   Howto & Style  2009-02-21
# 32  UCvVuqRzGVqRlmZYlTf99M_w   Entertainment  2007-09-19
# 33  UCvM1hVcRJmVWDtATYarC0KA   Howto & Style  2015-01-31
# 34  UCkk2vs5EXLFUMuVyhy7oOMQ   Howto & Style  2012-10-26
# 35  UCK2ACorzpH-igxuHZ2ObCEA  People & Blogs  2010-03-10
# 36  UCLFW3EKD2My9swWH4eTLaYw   Howto & Style  2012-03-06
# 37  UC5zSySQab9SA6Wz569WDgqw   Howto & Style  2009-10-24
# 38  UCoziFm3M4sHDq1kkx0UwtRw   Entertainment  2014-03-16
# 39  UCjHyFOH80C4x_2n_Korx4QQ  People & Blogs  2010-11-03
#
#                                                  link  \
# 0   http://www.youtube.com/channel/U
# 31  http://www.youtube.com/channel/UCIrrRLyFMVmmL9...
# 32  http://www.youtube.com/channel/UCTqMx8l2TtdZ7_...
# 33  http://www.youtube.com/channel/UCphTF9wHwhCt-B...
# 34  http://www.youtube.com/channel/UC5zJwsFtEs9WYe...
# 35  http://www.youtube.com/channel/UCGkSXL5saM8y3V...
# 36  http://www.youtube.com/channel/UCT0hbLDa-unWsn...
# 37  http://www.youtube.com/channel/UCO2WJZKQoDW4Te...
# 38  http://www.youtube.com/channel/UCvK4bOhULCpmLa...
# 39  http://www.youtube.com/channel/UCWZmCMB7mmKWcX...
#
#                        name  subscribers  videos
# 0                Alex Costa      2120000     543
# 1       Teachingmensfashion      4210000    1160
# 2                  alpha m.      5360000    1116
# 3                  The Rock      4470000     193
# 4             Unbox Therapy     15300000    1672
# 5        EverythingApplePro      7630000    1639
# 6                  Mo Vlogs      8280000    1500
# 7   ashish chanchlani vi...     14200000     130
# 8                Mark Wiens      4900000     993
# 9                   TechRax      6650000     501
# 10                      WWE     48400000   43421
# 11                 T-Series    112139463   13839
# 12         Marques Brownlee      9400000    1148
# 13         ChainsmokersVEVO     12000000     162
# 14          Grandpa Kitchen      5890000     223
# 15            UrAvgConsumer      2570000     790
# 16              BB Ki Vines     14962577     148
# 17                BigDawsTv      6340000     225
# 18              ThatWasEpic      3540000     189
# 19                   MrGear     10000000     873
# 20                     Deji      9840000    1704
# 21              CarryMinati      8036396     160
# 22                  Netflix     11100000    3166
# 23  F2Freestylers - Ulti...     10700000     629
# 24  Marvel Entertainment...     13200000    6332
# 25           PostMaloneVEVO      4064556      31
# 26                 Unisport      2023146    1539
# 27  America's Got Talent...     13400000    2206
# 28       JerryRigEverything      4410000     696
# 29                      KSI     20400000    1195
# 30           KSIOlajidebtHD      7412486     882
# 31                 SuperSaf      1390000     804
# 32              XEETECHCARE      1300000    4011
# 33                  What If      2440000     187
# 34           Professor Live      4190000     428
# 35              DJSnakeVEVO      6600000      32
# 36       FilmSelect Trailer      3080000     407
# 37              Geekyranjit      2766278    2648
# 38               Yes Theory      4250000     278
# 39               Miniminter      8210000    1659

# %%
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCAql2DyGU2un1Ei2nMYsqOA'], k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
#                   channel_id         category   join_date  \
# 0   UCAql2DyGU2un1Ei2nMYsqOA  News & Politics  2015-03-17
# 1   UCupvZG-5ko_eiXAupbDfxWw  News & Politics  2005-10-02
# 2   UC8p1vwvWtl6T73JiExfWs1g  News & Politics  2006-09-27
# 3   UCKZGcrxRAhdUi58Mdr565mw  News & Politics  2012-07-27
# 4   UCXIJgqnII2ZOINSWNOGFThA  News & Politics  2006-09-19
# 5   UC1yBKRuGpC1tSM73A0ZjYjQ  News & Politics  2005-12-21
# 6   UCeY0bbntWzzVIaj2z3QigXg  News & Politics  2006-07-19
# 7   UCuFFtHWoLl5fauMMD5Ww2jA  News & Politics  2014-07-25
# 8   UCP6HGa63sBC7-KHtkme-p-g  News & Politics  2006-03-20
# 9   UCBi2mrWuNuyYy4gbM6fU18Q  News & Politics  2006-08-07
# 10  UCVSNOxehfALut52NbkfRBaA  News & Politics  2008-03-14
# 11  UCdN4aXTrHAtfgbVG9HjBmxQ           Comedy  2019-01-02
# 11  http://www.youtube.com/channel/UCSqAtygCJCIdzW...
# 12  http://www.youtube.com/channel/UCmQXOAse-VnzuX...
# 13  http://www.youtube.com/channel/UChaDGuAPAwB2to...
# 14  http://www.youtube.com/channel/UC_3vfVLGjww6N6...
# 15  http://www.youtube.com/channel/UCG9lNhVqk9luFL...
# 16  http://www.youtube.com/channel/UCeh53ueba7retN...
# 17  http://www.youtube.com/channel/UCKrFXqpQj3gM98...
# 18  http://www.youtube.com/channel/UCPzWn8H-XhtHXG...
# 19  http://www.youtube.com/channel/UC7SYsaZNNprwAJ...
#
#                        name  subscribers  videos
# 0            James Bond 007       115000     407
# 1            DefendTheHouse       540000     538
# 2   Stream Movie Trailer...       253000     626
# 3                   Autocar       738000    1235
# 4                  Kassem G      2447833     482
# 5                 Lady Gaga     14495273     163
# 6            Scott Gairdner        72868      48
# 7               LindseyTime       498000     221
# 8   SOL - Supercars of L...       790000    1753
# 9                 PianoKeyz       462000     170
# 10             Cieon Movies       406000     769
# 11  PAINFULLY HONEST TEC...       168000     584
# 12      charlieissocoollike      2220000     234
# 13  Stupid Famous People...       272645    1386
# 14             MrThaiBox123       193000     600
# 15             5secondfilms       402000    1996
# 16         GuitarHeroPhenom       178000     522
# 17         NintendoCapriSun       409000    4677
# 18               MrChiCity3       221000      39
# 19          Empire Magazine        44647    1741

# %%
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UCISF5OGuAtSLNF24TKTnXag'], k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
#                   channel_id            category   join_date  \
# 0   UCISF5OGuAtSLNF24TKTnXag  Film and Animation  2013-12-17
# 1   UC1AEadAUKi6Zt-G3PatrU-Q  Film and Animation  2012-08-19
# 2   UCfR-4yZACIMRs3wNf0hel6g              Gaming  2013-06-18
# 3   UCeBnbqt4VRhotq2TQjkIi2A       Entertainment  2007-02-26
# 4   UCvD0DBYf-gY2dWarc4NEL9Q  Film and Animation  2013-08-27
# 5   UCK1HgDhsRulLj-pWi8XrqIA              Gaming  2012-07-23
# 6   UC_nEHeUEVNY5ZYLRWg8KoZQ  Film and Animation  2016-11-06
# 7   UCzYfz8uibvnB7Yc1LjePi4g              Gaming  2012-08-13
# 8   UCZBY6V8Lxmwu8gGRBOyO11w              Gaming  2014-06-16
# 9   UC1EBJfK7ltjYUFyzysKxr1g              Gaming  2014-04-05
# 10  UCqg2eLFNUu3QN3dttNeOWkw              Gaming  2010-08-20
# 11  UC94Z4HZJkhPm94YPH1GE3bw       Entertainment  2011-12-13
# 12  UCwTRjvjVge51X-ILJ4i22ew               Music  2012-11-16
# 13  UCUk7VggtJdo9XYTy3Z5QVAw              Gaming  2011-09-02
# 14  UCzeB_0FNcPIyUSjL_TL5lEw       Entertainment  2015-05-08
# 15  UC4qGmRZ7aLOLfVsSdj5Se2A       Entertainment  2014-10-29
# 16  UCHKDtSVVEc686EW7jRSCpZA       Entertainment  2007-04-01
# 17  UCR6g32TTJcIRwn71M9lPd-g       Entertainment  2010-06-20
# 18  UC3D_ZXHwaKekKwbO_LM48OQ  Film and Animation  2015-08-30
# 19  UC5M_h2S8Ldoc9M6f7B-_m6A       Entertainment  2005-10-10
#
#                                                  link  \
# 0   http://www.youtube.com/channel/UCISF5OGuAtSLNF...
# 1   http://www.youtube.com/channel/UC1AEadAUKi6Zt-...
# 2   http://www.youtube.com/channel/UCfR-4yZACIMRs3...
# 3   http://www.youtube.com/channel/UCeBnbqt4VRhotq...
# 4   http://www.youtube.com/channel/UCvD0DBYf-gY2dW...
# 5   http://www.youtube.com/channel/UCK1HgDhsRulLj-...
# 6   http://www.youtube.com/channel/UC_nEHeUEVNY5ZY...
# 7   http://www.youtube.com/channel/UCzYfz8uibvnB7Y...
# 8   http://www.youtube.com/channel/UCZBY6V8Lxmwu8g...
# 9   http://www.youtube.com/channel/UC1EBJfK7ltjYUF...
# 10  http://www.youtube.com/channel/UCqg2eLFNUu3QN3...
# 11  http://www.youtube.com/channel/UC94Z4HZJkhPm94...
# 12  http://www.youtube.com/channel/UCwTRjvjVge51X-...
# 13  http://www.youtube.com/channel/UCUk7VggtJdo9XY...
# 14  http://www.youtube.com/channel/UCzeB_0FNcPIyUS...
# 15  http://www.youtube.com/channel/UC4qGmRZ7aLOLfV...
# 16  http://www.youtube.com/channel/UCHKDtSVVEc686E...
# 17  http://www.youtube.com/channel/UCR6g32TTJcIRwn...
# 18  http://www.youtube.com/channel/UC3D_ZXHwaKekKw...
# 19  http://www.youtube.com/channel/UC5M_h2S8Ldoc9M...
#
#                        name  subscribers  videos
# 0                Magpiepony       736000     304
# 1            Letupita725HD★      2698245    2115
# 2                Bijuu Mike      2120000    1808
# 3               LaurenzSide      3410000    1397
# 4       MC Songs by MC Jams      1710000     328
# 5                Razzbowski      1160000    2101
# 6                  Wolfychu      2480000     101
# 7                    Aphmau      4840000    2991
# 8               Kubz Scouts      3160000    1440
# 9               Yandere Dev      2590000     159
# 10             iHasCupquake      6620000    4261
# 11                EileMonty       504000     211
# 12        Sing King Karaoke      6270000    1949
# 13                ItsFunneh      4850000    1309
# 14                 AzzyLand     10200000    1207
# 15                TheThings      4410000    1562
# 16  Scribbler Production...       327000    1767
# 17                   Kyutie      3610000    1804
# 18       Super Planet Dolan      1896611     121
# 19              Nickelodeon      6475581    3502

# %%
nearest_neighbors_id = get_k_nearest_neighbors(path, dict_channel_ind['UC_aP7p621ATY_yAa8jMqUVA'], k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel_id']).merge(channelcrawler)
nearest_neighbors
# Out:
#                   channel_id              category   join_date  \
# 0   UC_aP7p621ATY_yAa8jMqUVA  Science & Technology  2013-04-05
# 1   UC686IJyF40geirhYyJEMfIQ      Autos & Vehicles  2012-01-18
# 2   UCx3s3t5kpD4VMfJjDi5keXw  Science & Technology  2011-12-25
# 3   UCIMzhx509wEXMuGkTK-kD9Q      Autos & Vehicles  2006-03-11
# 4   UCuneWYkXOatJ4JH5QBXccBQ                Gaming  2009-11-27
# 5   UC86SBFIAgnYL3ll2ZDgmsuA      Autos & Vehicles  2012-04-18
# 6   UCVS6ejD9NLZvjsvhcbiDzjw  Science & Technology  2015-01-15
# 7   UCtwmze3hCYoI87uuYkcPFPA                Gaming  2012-11-26
# 8   UCwTkM6CvIsYFaFiMKIKCqHw    Film and Animation  2005-11-27
# 9   UCvj5S3f10rO6CoibatfRGzg                 Music  2008-09-17
# 10  UCyoSWGYKkusssZWzRrsX4RA      Autos & Vehicles  2008-10-31
# 11  UCxplsYwPGQVKyiopBAdCMYA                Sports  2007-01-27
# 12  UCTks0WxKbGHHa-aFhbvOBzA                Comedy  2006-04-20
# 13  UCq2eXCSiXldB4O0af_ulhIA       News & Politics  2008-03-03
# 14  UCpAMA6wo9hJYf_yUI8h_KeQ  Science & Technology  2006-10-25
# 15  UC66lTpcL4h5wqxCWioKQOrg      Autos & Vehicles  2006-11-21
# 16  UCQ0gZgLbqHywkNU_mDJKDzg    Film and Animation  2007-03-31
# 17  UCimkJT68lcDWZmVaIYRjOmA      Autos & Vehicles  2016-02-01
# 18  UCXFx-GHOyrQiiGqxE-J9fYA        People & Blogs  2006-04-17
# 19  UCHz5JQAUSkjxrosDIWCtEdw             Education  2009-02-23
#
#                                                  link  \
# 0   http://www.youtube.com/channel/UC_aP7p621ATY_y...
# 1   http://www.youtube.com/channel/UC686IJyF40geir...
# 2   http://www.youtube.com/channel/UCx3s3t5kpD4VMf...
# 3   http://www.youtube.com/channel/UCIMzhx509wEXMu...
# 4   http://www.youtube.com/channel/UCuneWYkXOatJ4J...
# 5   http://www.youtube.com/channel/UC86SBFIAgnYL3l...
# 6   http://www.youtube.com/channel/UCVS6ejD9NLZvjs...
# 7   http://www.youtube.com/channel/UCtwmze3hCYoI87...
# 8   http://www.youtube.com/channel/UCwTkM6CvIsYFaF...
# 9   http://www.youtube.com/channel/UCvj5S3f10rO6Co...
# 10  http://www.youtube.com/channel/UCyoSWGYKkusssZ...
# 11  http://www.youtube.com/channel/UCxplsYwPGQVKyi...
# 12  http://www.youtube.com/channel/UCTks0WxKbGHHa-...
# 13  http://www.youtube.com/channel/UCq2eXCSiXldB4O...
# 14  http://www.youtube.com/channel/UCpAMA6wo9hJYf_...
# 15  http://www.youtube.com/channel/UC66lTpcL4h5wqx...
# 16  http://www.youtube.com/channel/UCQ0gZgLbqHywkN...
# 17  http://www.youtube.com/channel/UCimkJT68lcDWZm...
# 18  http://www.youtube.com/channel/UCXFx-GHOyrQiiG...
# 19  http://www.youtube.com/channel/UCHz5JQAUSkjxro...
#
#                        name  subscribers  videos
# 0                NASA Video       391000    8232
# 1                SmurfinWRX       351000    1027
# 2             CoolHardLogic       106000      51
# 3                   Autocar       738000    1235
# 4               MotoGamesTV       203628    7077
# 5          TheStraightPipes       654192     314
# 6       Crosstalk Solutions       127000     483
# 7                WeaselZone       387000    2718
# 8            James Bond 007       115000     407
# 9             Jonathan Mann        40000    3753
# 10  SOL - Supercars of L...       790000    1753
# 11         hockeyfights.com       174000    9407
# 12               Goldentusk        68500     307
# 13       MichaelSavage4Prez        27500    3150
# 14            Tech Examined        45100    1124
# 15                MotorWeek       268000    3413
# 16         John Butler Trio       279384      88
# 17               Omni Rider        73400      72
# 18                softypapa        27100    1998
# 19          thechesswebsite       358000     368

# %% [markdown]
# ### Channels selected over the whole comments dataset
# We randomly choose 10 000 users over the dataset.
# For each user, we then pick two channels at random in the set of channels this user commented in.

# %%
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_user_walk.pkl",'rb') as f:
     channels_tuple = pickle.load(f)
f.close()

# %% [markdown]
# #### Random walk

# %%
def get_random_walk(df_embedding):
    with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_random_walk.pkl",'rb') as f:
         random_walk_channels = pickle.load(f)
    f.close()
    random_walk_distance = 0
    for val in random_walk_channels:
        random_walk_distance += distance.euclidean(df_embedding.iloc[val[0]], df_embedding.iloc[val[1]])
    return random_walk_distance

def get_random_walk_new(df_embedding):
    with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_random_walk_modified.pkl",'rb') as f:
         random_walk_channels = pickle.load(f)
    f.close()
    random_walk_distance = 0
    for val in random_walk_channels:
        random_walk_distance += distance.euclidean(df_embedding.iloc[val[0]], df_embedding.iloc[val[1]])
    return random_walk_distance

# %% [markdown]
# #### Compute metrics: users walk distance and relative nearest neighbor ranking
#
# In this section we want to measure the euclidian distance of a user walk compared to a random walk.
#
# user walk: Euclidean distance in the embedding space between two randomly channels of a user.
# random walk: Euclidean distance in the embedding space between two randomly channels.
# position: Position of a channel taken from user u relatively of another channel taken from the same user in terms of its nearest neighbor ranking.

# %%
'''
Get the position of ref_channel relative to second_channel in terms of its nearest neighbors ranking.
PARAMETER:
    - ref_channel: The reference channel on which wwe compute it's k nearest neighbor
    - second_channel: The channel where we compute it's ranking relatively to ref_channel
    - dist: Euclidean distance between ref_channel and second_channel
    - index: annoy index
    - df_embedding: DataFrame representing the embedding space

RETURN: The position of second_channel relatively to ref_channel in terms of it's ranking

'''
def get_ranking_position_between_channels(ref_channel, second_channel, index, df_embedding):
    
    nearest_neighbors_index = index.get_nns_by_item(ref_channel, len(df_embedding), search_k = 100000000)
    dist_k_th_nearest = distance.euclidean(df_embedding.iloc[ref_channel], 
                                           df_embedding.iloc[nearest_neighbors_index[len(nearest_neighbors_index)-1]])
    for i in range(0, len(nearest_neighbors_index)):
        if nearest_neighbors_index[i] == second_channel:
            return i

# %%
users_walk_tab = []
users_walk_tab_new = []
ranking_position_tab = []

len_random_set = len(channels_tuple)
len_embedding = len(channels_id)

#path = '/dlabdata1/youtube_large/jouven/channel_embedding/limited_normalized_50/'
#files = glob.glob(path + '*.npz') 
model_1 = '/dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/CONTEXT_True_20_SUBSAMPLING_False_0.0043/models/embedding1.csv.gz'

files = [model_1]
for file in files: 
    print('file ', file)
    df_embedding = get_dataframe_in_embedding_space(file)
    n_comp = df_embedding.shape[1]
    print('n_comp ', n_comp)
    random_walk_distance = get_random_walk(df_embedding)
    random_walk_distance_new = get_random_walk_new(df_embedding)
    index = get_annoy_index(df_embedding)
    users_walk = 0
    ranking_position = 0

    for ref_channel, second_channel in channels_tuple:
        users_walk += distance.euclidean(df_embedding.iloc[ref_channel], df_embedding.iloc[second_channel])
        ranking_position += get_ranking_position_between_channels(ref_channel, second_channel, index, df_embedding)
    
    users_walk_tab.append(users_walk/random_walk_distance)
    users_walk_tab_new.append(users_walk/random_walk_distance_new)
    ranking_position_tab.append(ranking_position/(len_random_set*len_embedding))
# Out:
# file  /dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/CONTEXT_True_20_SUBSAMPLING_False_0.0043/models/embedding1.csv.gz
# n_comp  200

# %%
users_walk_tab
# Out:
# [0.426133025248665]

# %%
ranking_position_tab
# Out:
# [0.08308940511459491]

# %%
users_walk_tab_new
# Out:
# [1.7966429514655458]

# %%
'''
Plot the results obtained when computing the metrics
'''
import plotly.graph_objects as go

components_name = ['Features dim 50', 'Features dim 100', 'Features dim 200', 'Features dim 500']
colors = ['b', 'g,', 'r', 'c']

fig = go.Figure()

for i in range(len(components_name)):
    fig.add_trace(go.Scatter(
        x=ranking_position_tab,
        y=users_walk_tab,
        marker=dict(color=colors[i], size=12),
        mode="markers",
        name=components_name[i],
    ))

fig.update_layout(title="Gender Earnings Disparity",
                  xaxis_title="Ranking position",
                  yaxis_title="Users walk distance")

fig.show()
