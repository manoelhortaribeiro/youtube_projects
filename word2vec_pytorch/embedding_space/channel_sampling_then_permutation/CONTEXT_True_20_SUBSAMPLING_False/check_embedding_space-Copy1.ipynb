# %% [markdown]
# This notebook checks the behaviour of the embedding space

# %%
import pickle
import os
import sys
#import torch

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE


scriptpath = "../../../"
sys.path.append(os.path.abspath(scriptpath))
from helpers.helpers_channels_more_300 import *
from helpers.helpers_channel_embedding import *

# %% [markdown]
# ### Create embedding from torch

# %%
#model_path = '/dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/CONTEXT_True_20_SUBSAMPLING_True_0.0043/models/model0.pth'
#df = create_dataframe_in_embedding_space(model_path)

# %%
#df.shape

# %%
#df.to_csv('/dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/CONTEXT_True_20_SUBSAMPLING_True_0.0043/models/embedding0.csv.gz', compression='gzip', index = False)

# %% [markdown]
# ### Useful functions

# %%
# Selected channels and id-index mapping
dict_channel_ind, dict_ind_channel, channels_id = filtered_channels_index_id_mapping()

# %%
PATH = '/dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/CONTEXT_True_20_SUBSAMPLING_False_0.0043/models/embedding0.csv.gz'

# %%
channelcrawler = pd.read_csv("/dlabdata1/youtube_large/df_channels_en.tsv.gz", sep='\t')
# Select the rows being in the select channels
channelcrawler = channelcrawler[channelcrawler['channel'].apply(lambda row: row in channels_id)]

# %%
channelcrawler.head()
# Out:
#      category_cc   join_date                   channel  \
# 0         Gaming  2010-04-29  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 1      Education  2006-09-01  UCbCmjCuTUZos6Inko4u57UQ
# 2  Entertainment  2006-09-20  UCpEhnqL0y41EpW2TvWAHD7Q
# 3  Howto & Style  2016-11-15  UC295-Dw_tDNtZXFeAPAW6Aw
# 4         Sports  2007-05-11  UCJ5v_MCY6GNUBTO8-D3XoAg
#
#                    name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                PewDiePie       101000000       3956                 3.0
# 1  Cocomelon - Nursery ...        60100000        458                 7.0
# 2                SET India        56018869      32661                 8.0
# 3          5-Minute Crafts        60600000       3591                 9.0
# 4                      WWE        48400000      43421                11.0
#
#    weights
# 0    2.087
# 1    2.087
# 2    2.087
# 3    2.087
# 4    2.087

# %%
channelcrawler['category_cc'].unique()
# Out:
# array(['Gaming', 'Education', 'Entertainment', 'Howto & Style', 'Sports',
#        'Music', 'Film and Animation', 'Comedy', 'Nonprofits & Activism',
#        'People & Blogs', 'News & Politics', 'Science & Technology',
#        'Pets & Animals', 'Autos & Vehicles', 'Travel & Events', nan],
#       dtype=object)

# %% [markdown]
# ### Manually check the neirest neighbors of some selected channels

# %% [markdown]
# First to check how good is the embedding space, we are going to choose a channel and it's k closest channels in the embedding space. By looking at these channels in the YouTube website, we have a sense of how good/bad is the embedding.

# %%
# Looking at the neirest neigbors of `Shaaanxo` being a girl fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCMpOz2KEfkSdd5JeIJh_fxw'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel     category_cc   join_date  \
# 0   UCMpOz2KEfkSdd5JeIJh_fxw   Howto & Style  2009-01-18
# 1   UCbO9bltbkYwa56nZFQx6XJg   Howto & Style  2014-07-17
# 2   UCzTKskwIc_-a0cGvCXA848Q   Howto & Style  2008-06-23
# 3   UCkvK_5omS-42Ovgah8KRKtg   Howto & Style  2006-02-14
# 4   UC21yq4sq8uxTcfgIxxyE9VQ   Howto & Style  2011-06-27
# 5   UCGwPbAQdGA3_88WBuGtg9tw   Howto & Style  2010-12-03
# 6   UCF2oW5-MO8dB6ul9WH9xi0A  People & Blogs  2007-01-04
# 7   UCKMugoa0uHpjUuq14yOpagw   Howto & Style  2009-06-09
# 8   UCc6W7efUSkd9YYoxOnctlFg   Entertainment  2009-06-08
# 9   UC8v4vz_n2rys6Yxpj8LuOBA   Howto & Style  2013-01-26
# 10  UCz0Qnv6KczUe3NH1wnpmqhA   Howto & Style  2006-11-27
# 11  UC6jgzx2g3nlbaYkd8EMweKA   Howto & Style  2010-09-07
# 12  UCCvoAe__WFYMNAEN-C-CtYA   Howto & Style  2008-08-05
# 13  UC9TreTE-iXwfwQl72DzDurA   Howto & Style  2009-01-04
# 14  UC2LgZ_4GzSFQS-3a87_Jc6w  People & Blogs  2009-03-17
# 15  UCxj0QizmFhx7kVKSArHBCTA   Howto & Style  2011-03-09
# 16  UCjEPwaev8_zrpafISAPhruA   Howto & Style  2007-06-07
# 17  UC_GvMVffgctSISDkeWlKhXQ   Howto & Style  2009-06-29
# 18  UC9gFih9rw0zNCK3ZtoKQQyA          Comedy  2010-02-16
# 19  UCnjk78dOMbH-IMwNYLKSaqg   Howto & Style  2009-11-08
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                  Shaaanxo         3215340       1422              3566.0
# 1                 Manny Mua         4800000        426              1910.0
# 2           NikkieTutorials        12269235        742               312.0
# 3               jeffreestar        16000000        357               222.0
# 4               Carli Bybel         6190000        546              1234.0
# 5             grav3yardgirl         8560000       1536               725.0
# 6            blndsundoll4mj         4900000       2420              1808.0
# 7                 Laura Lee         4400000        638              2083.0
# 8              Bethany Mota        10200000        483               545.0
# 9            KathleenLights         4140000        979              2308.0
# 10         Nicole Guerriero         2870000        664              4160.0
# 11              Jaclyn Hill         5890000        344              1348.0
# 12               Wayne Goss         3670000       1357              2740.0
# 13           Kandee Johnson         3900000        630              2276.0
# 14  Cute Girls Hairstyle...         5660000        612              1427.0
# 15             Casey Holmes         1770000        730              8208.0
# 16        Sam & Nic Chapman         2160000        922              6338.0
# 17                 dope2111         5940000        239              1313.0
# 18             JennaMarbles        19900000        466               139.0
# 19       Samantha Schuerman          292000       1330             57003.0
#
#     weights
# 0    2.2780
# 1    2.0870
# 2    2.0870
# 3    2.0870
# 4    2.0870
# 5    2.0870
# 6    2.0870
# 7    2.1200
# 8    2.0870
# 9    2.1680
# 10   2.3400
# 11   2.0870
# 12   2.2180
# 13   2.1660
# 14   2.0870
# 15   2.5370
# 16   2.4625
# 17   2.0870
# 18   2.0870
# 19   3.5210

# %%
# Looking at the neirest neigbors of `Alex Costa` being a men fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCZyCposXwcyopaACep44maQ'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel           category_cc   join_date  \
# 0   UCZyCposXwcyopaACep44maQ         Howto & Style  2011-09-29
# 1   UChNN7VBxPTiNrqjUaQd9bxA         Howto & Style  2012-09-14
# 2   UC1KbedtKa3d5dleFR6OjQMg         Howto & Style  2008-07-06
# 3   UCBdw4dLCLLHmTgAOnW4V0hQ         Entertainment  2005-11-24
# 4   UCj34AOIMl_k1fF7hcBkD_dw  Science & Technology  2009-01-27
# 5   UC_hoQDD6zKcIqpIYLsFbBeA        People & Blogs  2013-09-22
# 6   UC7eHZXheF8nVOfwB2PEslMw                Comedy  2009-07-06
# 7   UCyEd6QBSgat5kkC6svyjudA       Travel & Events  2009-02-02
# 8   UCmlsu3V3SzIm2Jmo0S0qiMg         Entertainment  2009-09-21
# 9   UCJ5v_MCY6GNUBTO8-D3XoAg                Sports  2007-05-11
# 10  UCRzzwLpLiUNIs6YOPe33eMg                 Music  2012-10-22
# 11  UC1of9ELYwB623fWaAMRDVFA         Howto & Style  2017-08-26
# 12  UC9fSZHEh6XsRpX-xJc6lT3A  Science & Technology  2012-01-01
# 13  UCqwUrj10mAEsqezcItqvwEw         Entertainment  2015-06-20
# 14  UCSrnmu3W6YXWU_85DKT5arg                Comedy  2014-06-17
# 15  UCo6DJdltbIub80bLiyJRv3w         Entertainment  2015-06-17
# 16  UCj22tfcQrWG7EMEKS0qLeEg                Comedy  2014-10-30
# 17  UCOhtMAg7xh8wv_wUHMgFc-Q                 Music  2014-09-30
# 18  UC5SQGzkWyQSW_fe-URgq7xw                Sports  2009-01-13
# 19  UCGmnsW623G1r-Chmo5RB4Yw                Gaming  2011-01-26
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                Alex Costa         2120000        543              5370.0
# 1       Teachingmensfashion         4210000       1160              2093.0
# 2                  alpha m.         5360000       1116              1376.0
# 3                  The Rock         4470000        193              1879.0
# 4        EverythingApplePro         7630000       1639               826.0
# 5                  Mo Vlogs         8280000       1500               693.0
# 6   ashish chanchlani vi...        14200000        130               218.0
# 7                Mark Wiens         4900000        993              1493.0
# 8                   TechRax         6650000        501              1065.0
# 9                       WWE        48400000      43421                11.0
# 10         ChainsmokersVEVO        12000000        162               384.0
# 11          Grandpa Kitchen         5890000        223              1025.0
# 12            UrAvgConsumer         2570000        790              4426.0
# 13              BB Ki Vines        14962577        148               205.0
# 14              ThatWasEpic         3540000        189              2103.0
# 15                   MrGear        10000000        873               480.0
# 16              CarryMinati         8036396        160               598.0
# 17           PostMaloneVEVO         4064556         31              2468.0
# 18                 Unisport         2023146       1539              6093.0
# 19           KSIOlajidebtHD         7412486        882               784.0
#
#     weights
# 0    2.4170
# 1    2.1225
# 2    2.0870
# 3    2.0870
# 4    2.0870
# 5    2.0870
# 6    2.0870
# 7    2.0870
# 8    2.0870
# 9    2.0870
# 10   2.0870
# 11   2.0870
# 12   2.3715
# 13   2.0870
# 14   2.1255
# 15   2.0870
# 16   2.0870
# 17   2.1935
# 18   2.4610
# 19   2.0870

# %%
# Looking at the neirest neigbors of `Magpiepony` which is a kids film
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCISF5OGuAtSLNF24TKTnXag'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel         category_cc   join_date  \
# 0   UCISF5OGuAtSLNF24TKTnXag  Film and Animation  2013-12-17
# 1   UC1AEadAUKi6Zt-G3PatrU-Q  Film and Animation  2012-08-19
# 2   UCfR-4yZACIMRs3wNf0hel6g              Gaming  2013-06-18
# 3   UCeBnbqt4VRhotq2TQjkIi2A       Entertainment  2007-02-26
# 4   UCvD0DBYf-gY2dWarc4NEL9Q  Film and Animation  2013-08-27
# 5   UCK1HgDhsRulLj-pWi8XrqIA              Gaming  2012-07-23
# 6   UC_nEHeUEVNY5ZYLRWg8KoZQ  Film and Animation  2016-11-06
# 7   UCzYfz8uibvnB7Yc1LjePi4g              Gaming  2012-08-13
# 8   UCZBY6V8Lxmwu8gGRBOyO11w              Gaming  2014-06-16
# 9   UC1EBJfK7ltjYUFyzysKxr1g              Gaming  2014-04-05
# 10  UCqg2eLFNUu3QN3dttNeOWkw              Gaming  2010-08-20
# 11  UC94Z4HZJkhPm94YPH1GE3bw       Entertainment  2011-12-13
# 12  UCwTRjvjVge51X-ILJ4i22ew               Music  2012-11-16
# 13  UCUk7VggtJdo9XYTy3Z5QVAw              Gaming  2011-09-02
# 14  UCzeB_0FNcPIyUSjL_TL5lEw       Entertainment  2015-05-08
# 15  UC4qGmRZ7aLOLfVsSdj5Se2A       Entertainment  2014-10-29
# 16  UCHKDtSVVEc686EW7jRSCpZA       Entertainment  2007-04-01
# 17  UCR6g32TTJcIRwn71M9lPd-g       Entertainment  2010-06-20
# 18  UC3D_ZXHwaKekKwbO_LM48OQ  Film and Animation  2015-08-30
# 19  UC5M_h2S8Ldoc9M6f7B-_m6A       Entertainment  2005-10-10
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                Magpiepony          736000        304             21120.0
# 1            Letupita725HD★         2698245       2115              4054.0
# 2                Bijuu Mike         2120000       1808              5865.0
# 3               LaurenzSide         3410000       1397              2774.0
# 4       MC Songs by MC Jams         1710000        328              8154.0
# 5                Razzbowski         1160000       2101             13434.0
# 6                  Wolfychu         2480000        101              4780.0
# 7                    Aphmau         4840000       2991              1807.0
# 8               Kubz Scouts         3160000       1440              3303.0
# 9               Yandere Dev         2590000        159              4657.0
# 10             iHasCupquake         6620000       4261              1109.0
# 11                EileMonty          504000        211             33178.0
# 12        Sing King Karaoke         6270000       1949              1039.0
# 13                ItsFunneh         4850000       1309              1600.0
# 14                 AzzyLand        10200000       1207               455.0
# 15                TheThings         4410000       1562              1936.0
# 16  Scribbler Production...          327000       1767             54604.0
# 17                   Kyutie         3610000       1804              2923.0
# 18       Super Planet Dolan         1896611        121              7396.0
# 19              Nickelodeon         6475581       3502              1005.0
#
#     weights
# 0    2.9225
# 1    2.3350
# 2    2.4595
# 3    2.2200
# 4    2.5565
# 5    2.8135
# 6    2.3640
# 7    2.0870
# 8    2.2885
# 9    2.3890
# 10   2.0870
# 11   3.2020
# 12   2.0870
# 13   2.0870
# 14   2.0870
# 15   2.0865
# 16   3.5110
# 17   2.2260
# 18   2.5320
# 19   2.0870

# %%
# Looking at neirest neigbors of `Beyond the trailer` a channel for analysis of films
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCAXR2zenCwvRIyQd9ydtfaA'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel         category_cc   join_date  \
# 0   UCAXR2zenCwvRIyQd9ydtfaA       Entertainment  2008-11-03
# 1   UCDiFRMQWpcp8_KD4vwIVicw       Entertainment  2012-10-12
# 2   UCaWd5_7JhbQBe4dknZhsHJg       Entertainment  2007-01-25
# 3   UCi8e0iOVk1fEOogdfu4YgfA  Film and Animation  2011-04-01
# 4   UCOpcACMWblDls9Z6GERVi1A  Film and Animation  2008-10-03
# 5   UCa6vGFO9ty8v5KZJXQxdhaw       Entertainment  2006-09-20
# 6   UCi7GJNg51C3jgmYTUwqoUXA              Comedy  2008-06-23
# 7   UC8-Th83bH_thdKZDJCrn88g              Comedy  2006-01-08
# 8   UCjmJDM5pRKbUlVIzDYYWb6g       Entertainment  2006-10-17
# 9   UCWOA1ZGywLbqmigxE4Qlvuw       Entertainment  2012-07-17
# 10  UCQMbqH7xJu5aTAPQ9y_U7WQ       Entertainment  2009-03-05
# 11  UCP1iRaFlS5EYjJBryFV9JPw       Entertainment  2015-11-25
# 12  UCCqEeDAUf4Mg0GgEN658tkA       Entertainment  2011-01-06
# 13  UCHEf6T_gVq4tlW5i91ESiWg       Entertainment  2013-07-30
# 14  UCp0hYYBW6IMayGgR-WeoCvQ       Entertainment  2006-11-21
# 15  UCay_OLhWtf9iklq8zg_or0g      People & Blogs  2013-04-09
# 16  UCYUQQgogVeQY8cMQamhHJcg  Film and Animation  2012-12-11
# 17  UCuuU2L90sqhQahV1IkhCPaQ  Film and Animation  2014-05-12
# 18  UCKy1dAqELo0zrOtPkf0eTMw              Gaming  2006-09-19
# 19  UC3rLoj87ctEHCcS7BuvIzkQ       Entertainment  2015-11-19
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0        Beyond The Trailer          853000       5064             19744.0
# 1         Emergency Awesome         3210000       3949              3268.0
# 2             WatchMojo.com        21284359      17081               114.0
# 3       Movieclips Trailers        13900000       8084               267.0
# 4            Screen Junkies         6660000       1014              1096.0
# 5         Jimmy Kimmel Live        15200000       4207               212.0
# 6                 Team Coco         7290000       7901               873.0
# 7   The Tonight Show Sta...        22100000       5450                96.0
# 8   Warner Bros. Picture...         7660000       2397               779.0
# 9                   Netflix        11100000       3166               346.0
# 10  Fandom Entertainment...         1570000      10813              9597.0
# 11                   Looper         4820000       2533              1758.0
# 12          Chris Stuckmann         1580000       1400              8486.0
# 13                    REACT        12000000       1758               357.0
# 14             TheEllenShow        34400000      10692                28.0
# 15                    As/Is        10600000       3932               484.0
# 16               CinemaSins         8640000        768               685.0
# 17               Zero Media         1330000       2186             11648.0
# 18                      IGN        12400000     134606               333.0
# 19                   MsMojo         2826860       2777              3584.0
#
#     weights
# 0    2.8635
# 1    2.2750
# 2    2.0870
# 3    2.0870
# 4    2.0870
# 5    2.0870
# 6    2.0870
# 7    2.0870
# 8    2.0870
# 9    2.0870
# 10   2.5995
# 11   2.0870
# 12   2.5600
# 13   2.0870
# 14   2.0870
# 15   2.0870
# 16   2.0870
# 17   2.6620
# 18   2.0870
# 19   2.2825

# %% [markdown]
# ### User jumper implementation

# %%
# We randomly choose 3 000 users and for each user we select a random pair of channel
# channels_tuple = [(channel_1, channel_2), (...)]
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_user_walk.pkl",'rb') as f:
     channels_tuple = pickle.load(f)
f.close()

# %%
files = [PATH]
users_walk_tab, users_walk_tab_new, ranking_position_tab = get_user_walk_and_position_ratio(files, channels_tuple)

# %%
print('User walk = ' + str(users_walk_tab))
print("User walk (new way) = " + str(users_walk_tab_new))
print('Ranking position ratio = ' + str(ranking_position_tab))
# Out:
# [0.4285789192126741]

# %% [markdown]
# ### Plot the embedding

# %% [markdown]
# A good way to understand the general behavior of the embedding is to project the model in 2D

# %%
ix_to_word, word_to_ix = channel_to_name(channelcrawler, dict_channel_ind)

# %%
EMBEDDING = get_dataframe_in_embedding_space(PATH)
print('\n', 'running TSNE...')
tsne = TSNE(n_components = 2).fit_transform(EMBEDDING)
print('tsne.shape: ', tsne.shape) #(15, 2)
# Out:
#  running TSNE...

# %%
np.save('tsne.npy', x_tsne_full)
# np.load('tsne.npy')

# %%
############ VISUALIZING ############
x, y = [], []
annotations = []
for idx, coord in enumerate(tsne):
    # print(coord)
    annotations.append(ix_to_word[idx])
    x.append(coord[0])
    y.append(coord[1])
    
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_more_4000k_subs.pkl",'rb') as f:
     test_words = pickle.load(f)[:500]
f.close()
#extended = ['UCMpOz2KEfkSdd5JeIJh_fxw', 'UCZyCposXwcyopaACep44maQ', 'UCAql2DyGU2un1Ei2nMYsqOA', 'UC9pXxdNqCc2zjgRXSoowNNg', 'UCAXR2zenCwvRIyQd9ydtfaA', 'UCISF5OGuAtSLNF24TKTnXag']
extended = ['UCNcdbMyA59zE-Vk668bKWOg', ]
test_words += extended
#test_words.append('UCMpOz2KEfkSdd5JeIJh_fxw')
#test_words.append('UCZyCposXwcyopaACep44maQ')
#test_words.append('UCAql2DyGU2un1Ei2nMYsqOA')
#test_words.append('UC9pXxdNqCc2zjgRXSoowNNg')
#test_words.append('UCwTkM6CvIsYFaFiMKIKCqHw')
#test_words.append('UCISF5OGuAtSLNF24TKTnXag')

#test_words = TEST_WORDS_VIZ
#print('test_words: ', test_words)

plt.figure(figsize = (50, 50))
for i in range(len(test_words)):
    word = ix_to_word[dict_channel_ind[test_words[i]]]
    #print('word: ', word)
    vocab_idx = word_to_ix[word]
    # print('vocab_idx: ', vocab_idx)
    plt.scatter(x[vocab_idx], y[vocab_idx])
    if test_words[i] in extended:
        plt.annotate(word, xy = (x[vocab_idx], y[vocab_idx]), \
        ha='right',va='bottom', fontsize = 30)
    else:
        plt.annotate(word, xy = (x[vocab_idx], y[vocab_idx]), \
            ha='right',va='bottom')

plt.show()

# %%
channelcrawler.loc[channelcrawler['name'] == 'Disney Junior']
# Out:
#             category   join_date  \
# 38291  Entertainment  2008-04-22
#
#                                                     link           name  \
# 38291  http://www.youtube.com/channel/UCNcdbMyA59zE-V...  Disney Junior
#
#        subscribers  videos                channel_id
# 38291      4970000    1726  UCNcdbMyA59zE-Vk668bKWOg

# %%
len(extended)
# Out:
# 18

# %% [markdown]
# Plot to visualize the embeddingg in 2D.
# The channels appearing in the plot are the channels having more than 4000k subsribers. In addition, we have 20 colored channels representing the selected pairs in the "axis projection process".
# The seed pair is in violet.
# For every pair of selected channels: the first channel of this tuple has a lower size compared to the second one.
#
# The pairs represented on the plot corresponds to the seed pair: (Beyond the trailer, Magpiepony) representing the kids vs adult axis.

# %%
############ VISUALIZING ############
x, y = [], []
annotations = []
for idx, coord in enumerate(tsne):
    # print(coord)
    annotations.append(ix_to_word[idx])
    x.append(coord[0])
    y.append(coord[1])
    
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_more_4000k_subs.pkl",'rb') as f:
     test_words = pickle.load(f)
f.close()
#extended = ['UCMpOz2KEfkSdd5JeIJh_fxw', 'UCZyCposXwcyopaACep44maQ', 'UCAql2DyGU2un1Ei2nMYsqOA', 'UC9pXxdNqCc2zjgRXSoowNNg', 'UCAXR2zenCwvRIyQd9ydtfaA', 'UCISF5OGuAtSLNF24TKTnXag']

with open("/dlabdata1/youtube_large/jouven/channels_more_300/embedding_pairs.pkl",'rb') as f:
    extended = pickle.load(f)
f.close()
test_words += extended

colors = ['indigo', 'forestgreen', 'mediumblue', 'orangered', 'dodgerblue', 'brown', 'deepskyblue', 'crimson', 'black', 'tan']
plt.figure(figsize = (50, 50))
for i in range(len(test_words)):
    word = ix_to_word[dict_channel_ind[test_words[i]]]
    #print('word: ', word)
    vocab_idx = word_to_ix[word]
    # print('vocab_idx: ', vocab_idx)
    plt.scatter(x[vocab_idx], y[vocab_idx])
    if test_words[i] in extended:
        index = extended.index(test_words[i])
        if index % 2:
            plt.annotate(word, xy = (x[vocab_idx], y[vocab_idx]), \
            ha='right',va='bottom', fontsize = 20, color = colors[int(index/2)])
        else:
            plt.annotate(word, xy = (x[vocab_idx], y[vocab_idx]), \
            ha='right',va='bottom', fontsize = 30, color = colors[int(index/2)])
    else:
        plt.annotate(word, xy = (x[vocab_idx], y[vocab_idx]), \
            ha='right',va='bottom', color = 'gray')
plt.savefig("/home/jouven/youtube_projects/w2v.png")
plt.show()

# %% [markdown]
# Plot to visualize the embeddingg in 2D.
# The channels appearing in the plot are the channels having more than 4000k subsribers. In addition, we have 20 colored channels representing the selected pairs in the "axis projection process".
# The seed pair is in violet.
# For every pair of selected channels: the first channel of this tuple has a lower size compared to the second one.
#
# The pairs represented on the plot corresponds to the seed pair: (Beyond the trailer, Magpiepony) representing the kids vs adult axis.

# %%
############ VISUALIZING ############
SAMPLES = 500
x, y = [], []
annotations = []
for idx, coord in enumerate(tsne):
    # print(coord)
    annotations.append(ix_to_word[idx])
    x.append(coord[0])
    y.append(coord[1])

test_words = [dict_ind_channel[channel] for channel in random.sample(range(len(channels_id)), SAMPLES)]
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_more_4000k_subs.pkl",'rb') as f:
     test_words = pickle.load(f)
f.close()
#extended = ['UCMpOz2KEfkSdd5JeIJh_fxw', 'UCZyCposXwcyopaACep44maQ', 'UCAql2DyGU2un1Ei2nMYsqOA', 'UC9pXxdNqCc2zjgRXSoowNNg', 'UCAXR2zenCwvRIyQd9ydtfaA', 'UCISF5OGuAtSLNF24TKTnXag']

with open("/dlabdata1/youtube_large/jouven/channels_more_300/embedding_pairs.pkl",'rb') as f:
    extended = pickle.load(f)
f.close()
test_words += extended

colors = ['indigo', 'forestgreen', 'mediumblue', 'orangered', 'dodgerblue', 'brown', 'deepskyblue', 'crimson', 'black', 'tan']
plt.figure(figsize = (50, 50))
for i in range(len(test_words)):
    word = ix_to_word[dict_channel_ind[test_words[i]]]
    #print('word: ', word)
    vocab_idx = word_to_ix[word]
    # print('vocab_idx: ', vocab_idx)
    plt.scatter(x[vocab_idx], y[vocab_idx])
    if test_words[i] in extended:
        index = extended.index(test_words[i])
        if index % 2:
            plt.annotate(word, xy = (x[vocab_idx], y[vocab_idx]), \
            ha='right',va='bottom', fontsize = 20, color = colors[int(index/2)])
        else:
            plt.annotate(word, xy = (x[vocab_idx], y[vocab_idx]), \
            ha='right',va='bottom', fontsize = 30, color = colors[int(index/2)])
    else:
        plt.annotate(word, xy = (x[vocab_idx], y[vocab_idx]), \
            ha='right',va='bottom', color = 'gray')
plt.savefig("/home/jouven/youtube_projects/w2v.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-93f5c6306ba5> in <module>
#       5 for idx, coord in enumerate(tsne):
#       6     # print(coord)
# ----> 7     annotations.append(ix_to_word[idx])
#       8     x.append(coord[0])
#       9     y.append(coord[1])
#
# NameError: name 'ix_to_word' is not defined
