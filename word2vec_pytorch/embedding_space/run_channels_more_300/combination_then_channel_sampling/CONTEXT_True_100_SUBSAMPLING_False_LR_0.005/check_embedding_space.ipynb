# %% [markdown]
# ## NOTEBOOK DESCRIPTION:
#
# This notebook checks the behaviour of the embedding space:
# - It first checks manually the nearest neighbors of some selected channels
# - It also compute the user jumper score which is a first barrier on the evaluation of the embedding

# %%
import pickle
import os
import sys
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE

scriptpath = "/home/jouven/youtube_projects/"
sys.path.append(os.path.abspath(scriptpath))

from helpers.helpers_channels_more_300 import *
from helpers.helpers_channel_embedding import *

scriptpath = "/home/jouven/youtube_projects"
sys.path.append(os.path.abspath(scriptpath))
from helpers.config_threshold_value import *

# %% [markdown]
# ### Useful functions

# %%
# Selected channels and id-index mapping
dict_channel_ind, dict_ind_channel, channels_id = filtered_channels_index_id_mapping()

# %%
PATH = '/dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/combination_then_channel_sampling/CONTEXT_True_100_SUBSAMPLING_False_0.0043_LR_0.005/models/embedding.csv.gz'

# %%
channelcrawler = pd.read_csv("/dlabdata1/youtube_large/df_channels_en.tsv.gz", sep='\t')
# Select the rows being in the select channels
channelcrawler = channelcrawler[channelcrawler['channel'].apply(lambda row: row in channels_id)]

# %%
channelcrawler.head()
# Out:
#      category_cc   join_date                   channel  \
# 0         Gaming  2010-04-29  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 1      Education  2006-09-01  UCbCmjCuTUZos6Inko4u57UQ
# 2  Entertainment  2006-09-20  UCpEhnqL0y41EpW2TvWAHD7Q
# 3  Howto & Style  2016-11-15  UC295-Dw_tDNtZXFeAPAW6Aw
# 4         Sports  2007-05-11  UCJ5v_MCY6GNUBTO8-D3XoAg
#
#                    name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                PewDiePie       101000000       3956                 3.0
# 1  Cocomelon - Nursery ...        60100000        458                 7.0
# 2                SET India        56018869      32661                 8.0
# 3          5-Minute Crafts        60600000       3591                 9.0
# 4                      WWE        48400000      43421                11.0
#
#    weights
# 0    2.087
# 1    2.087
# 2    2.087
# 3    2.087
# 4    2.087

# %%
channelcrawler['category_cc'].unique()
# Out:
# array(['Gaming', 'Education', 'Entertainment', 'Howto & Style', 'Sports',
#        'Music', 'Film and Animation', 'Comedy', 'Nonprofits & Activism',
#        'People & Blogs', 'News & Politics', 'Science & Technology',
#        'Pets & Animals', 'Autos & Vehicles', 'Travel & Events', nan],
#       dtype=object)

# %% [markdown]
# ### Manually check the neirest neighbors of some selected channels

# %% [markdown]
# First to check how good is the embedding space, we are going to choose a channel and it's k closest channels in the embedding space. By looking at these channels in the YouTube website, we have a sense of how good/bad is the embedding.

# %%
# Looking at the neirest neigbors of `Shaaanxo` being a girl fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCMpOz2KEfkSdd5JeIJh_fxw'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel     category_cc   join_date              name_cc  \
# 0   UCMpOz2KEfkSdd5JeIJh_fxw   Howto & Style  2009-01-18             Shaaanxo
# 1   UCCvoAe__WFYMNAEN-C-CtYA   Howto & Style  2008-08-05           Wayne Goss
# 2   UCzTKskwIc_-a0cGvCXA848Q   Howto & Style  2008-06-23      NikkieTutorials
# 3   UC8v4vz_n2rys6Yxpj8LuOBA   Howto & Style  2013-01-26       KathleenLights
# 4   UCKMugoa0uHpjUuq14yOpagw   Howto & Style  2009-06-09            Laura Lee
# 5   UCxj0QizmFhx7kVKSArHBCTA   Howto & Style  2011-03-09         Casey Holmes
# 6   UCjHyFOH80C4x_2n_Korx4QQ  People & Blogs  2010-11-03           ThatsHeart
# 7   UCCgDVqiPU10shxzmwkMwJ6A   Howto & Style  2009-09-22        PiinkSparkles
# 8   UCc6W7efUSkd9YYoxOnctlFg   Entertainment  2009-06-08         Bethany Mota
# 9   UCzTtkLZFy6wqD4SsA9_fTtw   Howto & Style  2009-02-16          Krazyrayray
# 10  UCM3P_G21gOSVdepXrEFojIg   Howto & Style  2011-01-26       Rachel Talbott
# 11  UCE1BqH-72EBs-siTbDAjOGQ   Howto & Style  2008-04-20        Marlena Stell
# 12  UCkvK_5omS-42Ovgah8KRKtg   Howto & Style  2006-02-14          jeffreestar
# 13  UC9TreTE-iXwfwQl72DzDurA   Howto & Style  2009-01-04       Kandee Johnson
# 14  UCK2ACorzpH-igxuHZ2ObCEA  People & Blogs  2010-03-10         itsJudysLife
# 15  UCz0Qnv6KczUe3NH1wnpmqhA   Howto & Style  2006-11-27     Nicole Guerriero
# 16  UCWQGYk4mXa7wHmjxb1T00XQ  People & Blogs  2009-07-19         Megan Parken
# 17  UCT9lRRTBWIqMIfVgSyfsg7Q   Howto & Style  2010-06-07       PRINCESSJOULES
# 18  UCzEolHECo7JmmkWMGDYaSOA   Howto & Style  2010-12-05  AlexandrasGirlyTalk
# 19  UCcZ2nCUn7vSlMfY5PoH982Q   Howto & Style  2007-12-04       Still GlamorUs
#
#     subscribers_cc  videos_cc  subscriber_rank_sb  weights
# 0          3215340       1422              3566.0   2.2780
# 1          3670000       1357              2740.0   2.2180
# 2         12269235        742               312.0   2.0870
# 3          4140000        979              2308.0   2.1680
# 4          4400000        638              2083.0   2.1200
# 5          1770000        730              8208.0   2.5370
# 6          2200000        432              6234.0   2.4680
# 7          1170000       1557             13926.0   2.8105
# 8         10200000        483               545.0   2.0870
# 9          3570000        374              2954.0   2.2220
# 10         1210000        337             13160.0   2.7555
# 11         1520000        754              9894.0   2.6430
# 12        16000000        357               222.0   2.0870
# 13         3900000        630              2276.0   2.1660
# 14         1660000       2893              8765.0   2.5830
# 15         2870000        664              4160.0   2.3400
# 16          754000        797             23406.0   2.9950
# 17          531000        535             33917.0   3.2035
# 18         3250000        205              3107.0   2.2355
# 19         1010000        680             16966.0   2.8445

# %%
# Looking at the neirest neigbors of `Alex Costa` being a men fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCZyCposXwcyopaACep44maQ'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel           category_cc   join_date  \
# 0   UCZyCposXwcyopaACep44maQ         Howto & Style  2011-09-29
# 1   UC1KbedtKa3d5dleFR6OjQMg         Howto & Style  2008-07-06
# 2   UChNN7VBxPTiNrqjUaQd9bxA         Howto & Style  2012-09-14
# 3   UCqwUrj10mAEsqezcItqvwEw         Entertainment  2015-06-20
# 4   UCmRfQHc3U4fV1-i8Ry1HmtA         Howto & Style  2010-12-06
# 5   UCbq8_4_mFAx_rzDF5VT7MJw         Howto & Style  2013-11-11
# 6   UCFJZQtrh5Ksncayy2FaoNbQ             Education  2014-09-24
# 7   UCSXFaThRuBGbqOaZsTxZnTQ        People & Blogs  2015-07-10
# 8   UC7eHZXheF8nVOfwB2PEslMw                Comedy  2009-07-06
# 9   UCsTcErHg8oDvUnTzoqsYeNw  Science & Technology  2010-12-21
# 10  UCMrW_BDWQ0WCvvgmoRfbIfw                Comedy  2015-06-13
# 11  UCiAq_SU0ED1C6vWFMnw8Ekg       Travel & Events  2013-03-13
# 12  UCEVG5ZsurV3r_lA-XFRSP2w                Gaming  2014-06-23
# 13  UCqhnX4jA0A5paNd1v-zEysw                Sports  2009-03-11
# 14  UCX2v47KsDKqajrEYFV7GbBg                 Music  2009-05-12
# 15  UCz97F7dMxBNOfGYu3rx8aCw         Entertainment  2006-06-02
# 16  UCrfkB8kEd58c9wWGWsWIwEA         Entertainment  2014-01-06
# 17  UCd5xLBi_QU6w7RGm5TTznyQ       Travel & Events  2011-06-06
# 18  UC6sa7vq4zBuS5DxTUCWCchQ        People & Blogs  2013-10-11
# 19  UC4r8l3rcFBr9xJ2PZd7zNhw        People & Blogs  2013-11-17
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                Alex Costa         2120000        543              5370.0
# 1                  alpha m.         5360000       1116              1376.0
# 2       Teachingmensfashion         4210000       1160              2093.0
# 3               BB Ki Vines        14962577        148               205.0
# 4       Real Men Real Style         2400000       1315              4867.0
# 5                   BluMaan         1530000        381              9009.0
# 6   Vishuddha Das *Spiri...          576000        382             31243.0
# 7                  Mensutra         1340000        123             11589.0
# 8   ashish chanchlani vi...        14200000        130               218.0
# 9             Unbox Therapy        15300000       1672               206.0
# 10         The RawKnee Show          984957        124             14226.0
# 11          The Food Ranger         3420000        253              2704.0
# 12             Beaker's Lab          762000       1548             21134.0
# 13                    GoPro         7810000       2096               762.0
# 14                 AkonVEVO         3651603         37              2907.0
# 15  Sony Pictures Entert...         3760000       3451              2363.0
# 16                 Funk You         2671315        219              4565.0
# 17             High On Life          627746        385             28273.0
# 18                Lana Rose         1680000        143              8320.0
# 19            Saygin Yalcin          938000         91             17859.0
#
#     weights
# 0    2.4170
# 1    2.0870
# 2    2.1225
# 3    2.0870
# 4    2.3575
# 5    2.5520
# 6    3.1245
# 7    2.6665
# 8    2.0870
# 9    2.0870
# 10   2.8465
# 11   2.2165
# 12   2.9215
# 13   2.0870
# 14   2.2285
# 15   2.1790
# 16   2.3805
# 17   3.0185
# 18   2.5460
# 19   2.8630

# %%
# Looking at the neirest neigbors of `Magpiepony` which is a kids film
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCISF5OGuAtSLNF24TKTnXag'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel         category_cc   join_date  \
# 0   UCISF5OGuAtSLNF24TKTnXag  Film and Animation  2013-12-17
# 1   UC1AEadAUKi6Zt-G3PatrU-Q  Film and Animation  2012-08-19
# 2   UCPflSzRRyzK2hhbVxNAnrhw  Film and Animation  2012-03-31
# 3   UCHKDtSVVEc686EW7jRSCpZA       Entertainment  2007-04-01
# 4   UC_5niPa-d35gg88HaS7RrIw       Entertainment  2012-02-11
# 5   UCelMeixAOTs2OQAAi9wU8-g       Entertainment  2013-11-03
# 6   UCaC1b7X2r8OqxlGhXdDwB_w  Film and Animation  2007-07-08
# 7   UCD_VOth7RmckN6DbmFJa__A       Entertainment  2013-08-31
# 8   UChU79FLnClqlRSTSZe3EjNA  Film and Animation  2014-03-21
# 9   UCZBY6V8Lxmwu8gGRBOyO11w              Gaming  2014-06-16
# 10  UCcZjYWpM72s-1cinYfeSCag      People & Blogs  2010-08-05
# 11  UCkQ3eqNNaFrBZ_WbnCIMN8w  Film and Animation  2011-10-19
# 12  UC8arUfjrhlKXqdUFduWKYZw       Entertainment  2011-05-04
# 13  UC1U4UsSHxCw5s7fcNIzsfkA       Entertainment  2015-06-15
# 14  UCfWKtQSrBE7Z_FNyXaASmBg       Entertainment  2014-01-21
# 15  UCu6v4AdYxVH5fhfq9mi5llA  Film and Animation  2014-02-17
# 16  UCTil5w82CDH6HRmkjcPbsZw  Film and Animation  2012-04-21
# 17  UCVv1vQYLgJ6STMJkK2aWMyQ       Entertainment  2015-07-07
# 18  UC3McNQHov_mlOk3Wg6U5Caw              Comedy  2013-01-20
# 19  UCmcvhjZS3t2p8HErfq5BDuQ       Entertainment  2009-06-29
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                Magpiepony          736000        304             21120.0
# 1            Letupita725HD★         2698245       2115              4054.0
# 2                Pinkie Pie         1229394        451             11840.0
# 3   Scribbler Production...          327000       1767             54604.0
# 4                    Disney         3970000        791              2206.0
# 5              CookieSwirlC        12200000       3182               327.0
# 6             PhantomSavage          326000       1018             52984.0
# 7          The Brony Notion          256132        158             70689.0
# 8                Flutter525          858000       1297             20180.0
# 9               Kubz Scouts         3160000       1440              3303.0
# 10        DisneyFanatic2364          205000       1026             88028.0
# 11                   shgurr         2060000         68              6256.0
# 12                 Chaos55t          249000        374             68004.0
# 13               PawesomeTV          286000        760             62665.0
# 14       ToyBoxCollectibles          590000        533             31546.0
# 15  Let Me Explain Studi...         2450000         62              4527.0
# 16          WinxClubEnglish         1021797        940             15105.0
# 17                Tridashie          252744         48             67004.0
# 18  discontinued channel...          763182         45             21086.0
# 19              LPSskittles          279000         84             66635.0
#
#     weights
# 0    2.9225
# 1    2.3350
# 2    2.6965
# 3    3.5110
# 4    2.1435
# 5    2.0870
# 6    3.5430
# 7    3.7420
# 8    2.8735
# 9    2.2885
# 10   4.3405
# 11   2.4685
# 12   4.1265
# 13   3.8680
# 14   3.1090
# 15   2.3720
# 16   2.7850
# 17   4.0465
# 18   2.9245
# 19   4.0230

# %%
# Looking at neirest neigbors of `Beyond the trailer` a channel for analysis of films
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCAXR2zenCwvRIyQd9ydtfaA'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel           category_cc   join_date  \
# 0   UCAXR2zenCwvRIyQd9ydtfaA         Entertainment  2008-11-03
# 1   UCs1APU4_lj3PgZz2B4HeadA         Entertainment  2008-01-10
# 2   UCbu2SsF-Or3Rsn3NxqODImw                Gaming  2006-04-09
# 3   UCq0OueAsdxH6b8nyAspwViw         Entertainment  2006-06-19
# 4   UC8-Th83bH_thdKZDJCrn88g                Comedy  2006-01-08
# 5   UClFSU9_bUb4Rc6OYfTt5SPw       News & Politics  2006-09-16
# 6   UCgRQHK8Ttr1j9xCEpCAlgbQ         Entertainment  2006-03-04
# 7   UCkkcUZJ-vrt3HomsacbTNLg         Entertainment  2010-02-20
# 8   UCxo8ooAqXiObjuaIy10ud0A  Science & Technology  2013-10-27
# 9   UCGIY_O-8vW4rfX98KlMkvRg                Gaming  2005-12-27
# 10  UC6yzV_xgKn8r77FkcmZyMSg                Gaming  2010-10-29
# 11  UCgwv23FVv3lqh567yagXfNg                 Music  2010-05-20
# 12  UCPDXXXJj9nax0fr0Wfc048g                Comedy  2006-10-09
# 13  UCUnRn1f78foyP26XGkRfWsA                Gaming  2009-05-25
# 14  UC1cVTv6C0Unv6TtadjBvYRA    Film and Animation  2012-02-21
# 15  UCVWifhNM3tx877Z7h3ovtRA         Entertainment  2015-07-18
# 16  UC9YydG57epLqxA9cTzZXSeQ                Gaming  2006-01-17
# 17  UCSVv3TMby4KxNOVT1lYy9oA                Gaming  2007-02-22
# 18  UCiifkYAs_bq1pt_zbNAzYGg         Entertainment  2011-08-19
# 19  UClVrJwcIy7saPcGc1nct80A                 Music  2006-06-09
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0        Beyond The Trailer          853000       5064             19744.0
# 1                Blind Wave          442000       4580             37540.0
# 2                  GameSpot         4090000      33422              2295.0
# 3        Universal Pictures         2330000        830              4478.0
# 4   The Tonight Show Sta...        22100000       5450                96.0
# 5           Philip DeFranco         6400000       2627              1170.0
# 6                   Variety          448000       2961             30776.0
# 7             ForneverWorld          533000       4441             33294.0
# 8            Beyond Science         2100000        469              6564.0
# 9                  Nintendo         6050000       3791              1180.0
# 10       PlayStation Access         1820000       2776              7130.0
# 11          DisneyMusicVEVO        15600000        949               177.0
# 12             CollegeHumor        13400000       3517               298.0
# 13        GameSpot Trailers          607000       9030             25939.0
# 14            Rapid Trailer          780000       1615             20263.0
# 15                FoundFlix         1470000        306              9529.0
# 16             Call of Duty         5990000       1330              1259.0
# 17               TetraNinja         1910000       9950              7316.0
# 18                       DC         2380000       2587              5036.0
# 19          Fueled By Ramen        12400000       1166               343.0
#
#     weights
# 0    2.8635
# 1    3.2365
# 2    2.1680
# 3    2.3605
# 4    2.0870
# 5    2.0870
# 6    3.0490
# 7    3.2015
# 8    2.4930
# 9    2.0870
# 10   2.5230
# 11   2.0870
# 12   2.0870
# 13   3.0305
# 14   2.8810
# 15   2.5965
# 16   2.0870
# 17   2.5420
# 18   2.3910
# 19   2.0870

# %%
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCaCTtPkowVggMiUYhQmlcMw'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel     category_cc   join_date              name_cc  \
# 0   UCaCTtPkowVggMiUYhQmlcMw          Sports  2015-12-30    CrossFit Invictus
# 1   UC6wB_e6YQncYgpv_QrMGHCQ          Sports  2012-06-26      Revive Stronger
# 2   UCg4o4z4Xrk9SG4wX3Kpmydw          Sports  2011-04-21          Noah Ohlsen
# 3   UCrnXgvpJ56xtqVvsKh8RYYw  People & Blogs  2009-03-07  BigJsExtremeFitness
# 4   UC_kTqkxIUpycqnCGTcbwxow  People & Blogs  2011-10-29  Kara Corey Fit Life
# 5   UCy18P-QY4lIRAJpvZdsfMeQ          Sports  2014-10-16     Misfit Athletics
# 6   UCcoMAyqHdAfLPD-1hAQ2r6A  People & Blogs  2012-10-09          Silent Mike
# 7   UCLqH-U2TXzj1h7lyYQZLNQQ          Sports  2006-11-04        Greg Doucette
# 8   UCTiLQnvtKMfle0lQaNL817g          Sports  2010-06-12          Ben Pollack
# 9   UC4514FwdRy5gI6CdC9GPb0w          Sports  2011-03-05       Chris Bumstead
# 10  UCMoe2ZnSFIFcayGVv__xFEA  People & Blogs  2016-06-21          Stefi Cohen
# 11  UCAEA2TQF-EC1JTJhMb2osbA       Education  2006-08-15     Top Form Fitness
# 12  UCqfeXppJ0gH-xMteusTeVEg          Sports  2006-04-01      Zach Even - Esh
# 13  UCGXRegKvroyGv8HbN35AjKA   Howto & Style  2009-06-10       Sean Nalewanyj
# 14  UCs9b1SWEVJ2N4_l6eJIHJ2Q          Sports  2015-04-03         Ben Bergeron
# 15  UCiT4lJYXVC5Ev8Mlp8o7-Zg  People & Blogs  2013-03-27          Brooke Ence
# 16  UCLLFCfdlsyqCjFRxyHyCaKg  People & Blogs  2010-12-21           Kai Greene
# 17  UCWDto2R36n9pwwXq1HgjYHA          Sports  2015-07-09        Julie Foucher
# 18  UCdQopH6gZf6ZUk9TG9loapQ  People & Blogs  2015-06-20         Russel Orhii
# 19  UCYlG9AHZStenkJgXLj6w61A  People & Blogs  2012-04-17      Calum von Moger
#
#     subscribers_cc  videos_cc  subscriber_rank_sb  weights
# 0            27200        196            440262.0   7.1160
# 1            21850        777            507999.0   7.1675
# 2            50200        201            258307.0   6.4685
# 3           101000       1174            166057.0   5.4045
# 4           127000       1187            130233.0   4.0920
# 5            18402        404            608916.0   8.5115
# 6           160000        715             99506.0   3.7985
# 7            82300        458            178614.0   5.1825
# 8            50000        199            279108.0   6.6775
# 9           214000        135             66420.0   4.0085
# 10           78700         56            153474.0   5.2985
# 11           29800        375            365917.0   8.3480
# 12           31000       2335            422168.0   7.3105
# 13          170000        479            101458.0   3.7325
# 14           30600        128            396788.0   6.9700
# 15          239000        119             64868.0   3.8265
# 16          381000        167             44774.0   3.3530
# 17           16100        127            690819.0  10.0600
# 18          191000        617             83155.0   4.2190
# 19          849000        414             19237.0   2.8690

# %% [markdown]
# ### User jumper implementation

# %%
# We randomly choose 3 000 users and for each user we select a random pair of channel
# channels_tuple = [(channel_1, channel_2), (...)]
with open(os.path.join(COMMON_PATH, "channels_tuple_user_walk.pkl"),'rb') as f:
     channels_tuple = pickle.load(f)
f.close()

# %%
files = [PATH]
users_walk_tab, ranking_position_tab = get_user_walk_and_position_ratio(files, channels_tuple)
# Out:
# file  /dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/combination_then_channel_sampling/CONTEXT_True_100_SUBSAMPLING_False_0.0043_LR_0.005/models/embedding.csv.gz
# n_comp  200

# %%
print('User walk = ' + str(users_walk_tab))
print('Ranking position ratio = ' + str(ranking_position_tab))
# Out:
# User walk = [0.5441455219810676]
# Ranking position ratio = [0.0847494043945192]

# %%
# Results correspondining to halow number of subscribers
# The file having the channels is positionned at "/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_user_walk_low_subscribers.pkl"
# Only used for the report !
# print('User walk = ' + str(users_walk_tab))
# print('Ranking position ratio = ' + str(ranking_position_tab))
# Out:
# User walk = [0.17131994879327683]
# User walk (new way) = [8115.975221785797]
# Ranking position ratio = [0.2754236930967362]

# %% [markdown]
# ### Plot the embedding

# %% [markdown]
# A good way to understand the general behavior of the embedding is to project the model in 2D.

# %%
ix_to_word, word_to_ix = channel_to_name(channelcrawler, dict_channel_ind)

# %%
# Project the embedding in 2D
'''
EMBEDDING = get_dataframe_in_embedding_space(PATH)

print("\n', 'running TSNE...")
tsne = TSNE(n_components = 2).fit_transform(EMBEDDING)
print("tsne.shape: ", tsne.shape) 

# Save the projected embedding in the 2D plane
np.save('/home/jouven/youtube_projects/word2vec_pytorch/embedding_space/run_channels_more_300/combination_then_channel_sampling/CONTEXT_True_100_SUBSAMPLING_False_LR_0.005//tsne.npy', tsne)
'''

# %%
# Save the projected embedding in the 2D plane
tsne = np.load('/home/jouven/youtube_projects/word2vec_pytorch/embedding_space/run_channels_more_300/combination_then_channel_sampling/CONTEXT_True_100_SUBSAMPLING_False_LR_0.005//tsne.npy')

# %% [markdown]
# Plot to visualize the embeddingg in 2D.
# The channels appearing in the plot are the channels having more than 4000k subsribers. In addition, we have 20 colored channels representing the selected pairs in the "axis projection process".

# %%
ix_to_word[dict_channel_ind['UCAXR2zenCwvRIyQd9ydtfaA']]

# %%
############ VISUALIZING ############
SAMPLES = 500
x, y = [], []
annotations = []
for idx, coord in enumerate(tsne):
    # print(coord)
    annotations.append(ix_to_word[idx])
    x.append(coord[0])
    y.append(coord[1])

test_words = [dict_ind_channel[channel] for channel in random.sample(range(len(channels_id)), SAMPLES)]
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_more_4000k_subs.pkl",'rb') as f:
     test_words = pickle.load(f)
f.close()
extended = ['UCISF5OGuAtSLNF24TKTnXag', 'UCej8z9NGaA9Hdd8k5hueXKw']
test_words = random.sample(test_words, SAMPLES)
test_words += extended
plt.figure(figsize = (50, 50))
for i in range(len(test_words)):
    word = ix_to_word[dict_channel_ind[test_words[i]]]
    vocab_idx = word_to_ix[word]
    plt.scatter(x[vocab_idx], y[vocab_idx])
    if test_words[i] in extended:
        plt.annotate(word, xy = (x[vocab_idx], y[vocab_idx]), \
            ha='right',va='bottom', color = 'gray', fontsize = 30)
    else:
        plt.annotate(word, xy = (x[vocab_idx], y[vocab_idx]), \
                ha='right',va='bottom', color = 'gray', fontsize = 12)
#plt.savefig("/home/jouven/youtube_projects/w2v.png")
plt.title("Embedding visualization in 2D using channels having more than 4000k subsribers")
plt.show()
