# %% [markdown]
# ## NOTEBOOK DESCRIPTION:
#
# This notebook checks the behaviour of the embedding space:
# - It first checks manually the nearest neighbors of some selected channels
# - It also compute the user jumper score which is a first barrier on the evaluation of the embedding

# %%
import pickle
import os
import sys
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE

scriptpath = "/home/jouven/youtube_projects/"
sys.path.append(os.path.abspath(scriptpath))

from helpers.helpers_channels_more_300 import *
from helpers.helpers_channel_embedding import *

scriptpath = "/home/jouven/youtube_projects"
sys.path.append(os.path.abspath(scriptpath))
from helpers.config_threshold_value import *

# %% [markdown]
# ### Useful functions

# %%
# Selected channels and id-index mapping
dict_channel_ind, dict_ind_channel, channels_id = filtered_channels_index_id_mapping()

# %%
PATH = '/dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/channel_sampling_then_permutation/CONTEXT_True_20_SUBSAMPLING_True_0.001_LR_0.018/models/embedding0.csv.gz'

# %%
channelcrawler = pd.read_csv("/dlabdata1/youtube_large/df_channels_en.tsv.gz", sep='\t')
# Select the rows being in the select channels
channelcrawler = channelcrawler[channelcrawler['channel'].apply(lambda row: row in channels_id)]

# %%
channelcrawler.head()
# Out:
#      category_cc   join_date                   channel  \
# 0         Gaming  2010-04-29  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 1      Education  2006-09-01  UCbCmjCuTUZos6Inko4u57UQ
# 2  Entertainment  2006-09-20  UCpEhnqL0y41EpW2TvWAHD7Q
# 3  Howto & Style  2016-11-15  UC295-Dw_tDNtZXFeAPAW6Aw
# 4         Sports  2007-05-11  UCJ5v_MCY6GNUBTO8-D3XoAg
#
#                    name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                PewDiePie       101000000       3956                 3.0
# 1  Cocomelon - Nursery ...        60100000        458                 7.0
# 2                SET India        56018869      32661                 8.0
# 3          5-Minute Crafts        60600000       3591                 9.0
# 4                      WWE        48400000      43421                11.0
#
#    weights
# 0    2.087
# 1    2.087
# 2    2.087
# 3    2.087
# 4    2.087

# %%
channelcrawler['category_cc'].unique()
# Out:
# array(['Gaming', 'Education', 'Entertainment', 'Howto & Style', 'Sports',
#        'Music', 'Film and Animation', 'Comedy', 'Nonprofits & Activism',
#        'People & Blogs', 'News & Politics', 'Science & Technology',
#        'Pets & Animals', 'Autos & Vehicles', 'Travel & Events', nan],
#       dtype=object)

# %% [markdown]
# ### Manually check the neirest neighbors of some selected channels

# %% [markdown]
# First to check how good is the embedding space, we are going to choose a channel and it's k closest channels in the embedding space. By looking at these channels in the YouTube website, we have a sense of how good/bad is the embedding.

# %%
# Looking at the neirest neigbors of `Shaaanxo` being a girl fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCMpOz2KEfkSdd5JeIJh_fxw'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel     category_cc   join_date           name_cc  \
# 0   UCMpOz2KEfkSdd5JeIJh_fxw   Howto & Style  2009-01-18          Shaaanxo
# 1   UCc6W7efUSkd9YYoxOnctlFg   Entertainment  2009-06-08      Bethany Mota
# 2   UCbO9bltbkYwa56nZFQx6XJg   Howto & Style  2014-07-17         Manny Mua
# 3   UC6jgzx2g3nlbaYkd8EMweKA   Howto & Style  2010-09-07       Jaclyn Hill
# 4   UC9TreTE-iXwfwQl72DzDurA   Howto & Style  2009-01-04    Kandee Johnson
# 5   UCkvK_5omS-42Ovgah8KRKtg   Howto & Style  2006-02-14       jeffreestar
# 6   UCGwPbAQdGA3_88WBuGtg9tw   Howto & Style  2010-12-03     grav3yardgirl
# 7   UCKMugoa0uHpjUuq14yOpagw   Howto & Style  2009-06-09         Laura Lee
# 8   UCzTKskwIc_-a0cGvCXA848Q   Howto & Style  2008-06-23   NikkieTutorials
# 9   UC9gFih9rw0zNCK3ZtoKQQyA          Comedy  2010-02-16      JennaMarbles
# 10  UC21yq4sq8uxTcfgIxxyE9VQ   Howto & Style  2011-06-27       Carli Bybel
# 11  UCCvoAe__WFYMNAEN-C-CtYA   Howto & Style  2008-08-05        Wayne Goss
# 12  UCuYx81nzzz4OFQrhbKDzTng   Howto & Style  2006-07-18     Michelle Phan
# 13  UCF2oW5-MO8dB6ul9WH9xi0A  People & Blogs  2007-01-04    blndsundoll4mj
# 14  UC4GtJWgv_PLBiWFihNGbF0g   Howto & Style  2009-01-31  eleventhgorgeous
# 15  UCzco9CewPf0F-SP1p6LhWrw   Howto & Style  2008-07-07     Gigi Gorgeous
# 16  UCzTtkLZFy6wqD4SsA9_fTtw   Howto & Style  2009-02-16       Krazyrayray
# 17  UCp0hYYBW6IMayGgR-WeoCvQ   Entertainment  2006-11-21      TheEllenShow
# 18  UCG9nVSLp4nQlW79sY5ihRrg   Howto & Style  2013-08-17      Desi Perkins
# 19  UC8v4vz_n2rys6Yxpj8LuOBA   Howto & Style  2013-01-26    KathleenLights
#
#     subscribers_cc  videos_cc  subscriber_rank_sb  weights
# 0          3215340       1422              3566.0    2.278
# 1         10200000        483               545.0    2.087
# 2          4800000        426              1910.0    2.087
# 3          5890000        344              1348.0    2.087
# 4          3900000        630              2276.0    2.166
# 5         16000000        357               222.0    2.087
# 6          8560000       1536               725.0    2.087
# 7          4400000        638              2083.0    2.120
# 8         12269235        742               312.0    2.087
# 9         19900000        466               139.0    2.087
# 10         6190000        546              1234.0    2.087
# 11         3670000       1357              2740.0    2.218
# 12         8856703        250               664.0    2.087
# 13         4900000       2420              1808.0    2.087
# 14         1700000        756              8745.0    2.576
# 15         2910000        513              4079.0    2.326
# 16         3570000        374              2954.0    2.222
# 17        34400000      10692                28.0    2.087
# 18         3290000        359              3358.0    2.288
# 19         4140000        979              2308.0    2.168

# %%
# Looking at the neirest neigbors of `Alex Costa` being a men fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCZyCposXwcyopaACep44maQ'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel           category_cc   join_date  \
# 0   UCZyCposXwcyopaACep44maQ         Howto & Style  2011-09-29
# 1   UCsTcErHg8oDvUnTzoqsYeNw  Science & Technology  2010-12-21
# 2   UChNN7VBxPTiNrqjUaQd9bxA         Howto & Style  2012-09-14
# 3   UCBJycsmduvYEL83R_U4JriQ  Science & Technology  2008-03-21
# 4   UCRzzwLpLiUNIs6YOPe33eMg                 Music  2012-10-22
# 5   UC_hoQDD6zKcIqpIYLsFbBeA        People & Blogs  2013-09-22
# 6   UCWFKCr40YwOZQx8FHU_ZqqQ         Howto & Style  2012-07-23
# 7   UCmlsu3V3SzIm2Jmo0S0qiMg         Entertainment  2009-09-21
# 8   UCMiJRAwDNSNzuYeN2uWa0pA  Science & Technology  2011-04-20
# 9   UCyEd6QBSgat5kkC6svyjudA       Travel & Events  2009-02-02
# 10  UC5-gWZXAQqSGVfPHkA7NRiQ                 Music  2008-10-02
# 11  UC1of9ELYwB623fWaAMRDVFA         Howto & Style  2017-08-26
# 12  UC4rlAVgAK0SGk-yTfe48Qpw         Howto & Style  2017-03-15
# 13  UCo6DJdltbIub80bLiyJRv3w         Entertainment  2015-06-17
# 14  UCu4X846OSea5YU6S8fIpy1A                Comedy  2012-06-20
# 15  UCTqMx8l2TtdZ7_1A40qrFiQ  Science & Technology  2013-06-18
# 16  UCBdw4dLCLLHmTgAOnW4V0hQ         Entertainment  2005-11-24
# 17  UCDlQwv99CovKafGvxyaiNDA  Science & Technology  2010-03-24
# 18  UCT2X19JJaJGUN7mrYuImANQ         Entertainment  2006-06-29
# 19  UC2vcjazcVurVmpn5svBRA-Q             Education  2015-10-02
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                Alex Costa         2120000        543              5370.0
# 1             Unbox Therapy        15300000       1672               206.0
# 2       Teachingmensfashion         4210000       1160              2093.0
# 3          Marques Brownlee         9400000       1148               530.0
# 4          ChainsmokersVEVO        12000000        162               384.0
# 5                  Mo Vlogs         8280000       1500               693.0
# 6        JerryRigEverything         4410000        696              1717.0
# 7                   TechRax         6650000        501              1065.0
# 8            Mrwhosetheboss         2740000       1215              3367.0
# 9                Mark Wiens         4900000        993              1493.0
# 10               Bebe Rexha         6930000         74               933.0
# 11          Grandpa Kitchen         5890000        223              1025.0
# 12              BRIGHT SIDE        29800000       2872                36.0
# 13                   MrGear        10000000        873               480.0
# 14                BigDawsTv         6340000        225              1020.0
# 15              XEETECHCARE         1300000       4011             10892.0
# 16                 The Rock         4470000        193              1879.0
# 17        Jonathan Morrison         2650000       1141              4548.0
# 18  America's Got Talent...        13400000       2206               258.0
# 19                FTD Facts          749742        725             20086.0
#
#     weights
# 0    2.4170
# 1    2.0870
# 2    2.1225
# 3    2.0870
# 4    2.0870
# 5    2.0870
# 6    2.0870
# 7    2.0870
# 8    2.2890
# 9    2.0870
# 10   2.0870
# 11   2.0870
# 12   2.0870
# 13   2.0870
# 14   2.0870
# 15   2.6250
# 16   2.0870
# 17   2.3720
# 18   2.0870
# 19   2.8650

# %%
# Looking at the neirest neigbors of `Magpiepony` which is a kids film
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCISF5OGuAtSLNF24TKTnXag'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel         category_cc   join_date  \
# 0   UCISF5OGuAtSLNF24TKTnXag  Film and Animation  2013-12-17
# 1   UCfR-4yZACIMRs3wNf0hel6g              Gaming  2013-06-18
# 2   UCZBY6V8Lxmwu8gGRBOyO11w              Gaming  2014-06-16
# 3   UC_nEHeUEVNY5ZYLRWg8KoZQ  Film and Animation  2016-11-06
# 4   UCfguohQ13Uez5UWqJbZA5Qg               Music  2012-09-09
# 5   UCHCph-_jLba_9atyCZJPLQQ  Film and Animation  2007-03-05
# 6   UCt4qeayu0d0Yo5NHx_3xY9A              Gaming  2012-11-12
# 7   UCroJ5uxmGr-WOtXUPyqeh6g              Gaming  2011-06-07
# 8   UCMsgXPD3wzzt8RxHJmXH7hQ       Entertainment  2006-02-28
# 9   UC5VnC5l4dkFR0oVaPL_en2A              Gaming  2013-01-16
# 10  UC3D_ZXHwaKekKwbO_LM48OQ  Film and Animation  2015-08-30
# 11  UCeBnbqt4VRhotq2TQjkIi2A       Entertainment  2007-02-26
# 12  UCGwu0nbY2wSkW8N-cghnLpA  Film and Animation  2014-02-17
# 13  UC_1HVMnw-610qx54iEiWk7A           Education  2014-12-18
# 14  UC80Z-cIOdR6upfnrPJ8Q00A              Comedy  2009-03-15
# 15  UCOYWgypDktXdb-HfZnSMK6A              Comedy  2006-05-30
# 16  UC5dr8DMXhPeU3yKpEn8nR7Q              Gaming  2011-03-21
# 17  UCQqXoLLNReC3yFAIkX4vDJA              Gaming  2006-10-11
# 18  UCkQ3eqNNaFrBZ_WbnCIMN8w  Film and Animation  2011-10-19
# 19  UCFeqAfEuKm7lIg2ddQzh61A      People & Blogs  2011-06-12
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                Magpiepony          736000        304             21120.0
# 1                Bijuu Mike         2120000       1808              5865.0
# 2               Kubz Scouts         3160000       1440              3303.0
# 3                  Wolfychu         2480000        101              4780.0
# 4       VideoGameRapBattles          365258         93             46158.0
# 5   How It Should Have E...         9270000        355               608.0
# 6                SirSkyward          185000       1920             97587.0
# 7         Random Encounters         2780000        754              3860.0
# 8           Cartoon Network         5890000       5962              1095.0
# 9             VenturianTale         2840000       3300              4233.0
# 10       Super Planet Dolan         1896611        121              7396.0
# 11              LaurenzSide         3410000       1397              2774.0
# 12        Jaiden Animations         6730000         87               906.0
# 13               akidearest         2140000        453              5780.0
# 14           Thomas Sanders         3260000        200              3344.0
# 15                   TomSka         6130000        164              1216.0
# 16           Typhoon Cinema         3060098        723              3627.0
# 17                Mike Inel         1280000         52             11465.0
# 18                   shgurr         2060000         68              6256.0
# 19                 Emirichu         1790000         50              7120.0
#
#     weights
# 0    2.9225
# 1    2.4595
# 2    2.2885
# 3    2.3640
# 4    3.3090
# 5    2.0870
# 6    3.3950
# 7    2.2805
# 8    2.0870
# 9    2.3540
# 10   2.5320
# 11   2.2200
# 12   2.0870
# 13   2.4590
# 14   2.2895
# 15   2.0870
# 16   2.2750
# 17   2.6575
# 18   2.4685
# 19   2.5190

# %%
# Looking at neirest neigbors of `Beyond the trailer` a channel for analysis of films
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCAXR2zenCwvRIyQd9ydtfaA'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel           category_cc   join_date  \
# 0   UCAXR2zenCwvRIyQd9ydtfaA         Entertainment  2008-11-03
# 1   UCDiFRMQWpcp8_KD4vwIVicw         Entertainment  2012-10-12
# 2   UCa6vGFO9ty8v5KZJXQxdhaw         Entertainment  2006-09-20
# 3   UCpko_-a4wgz2u_DgDgd9fqA        People & Blogs  2011-08-10
# 4   UCBi2mrWuNuyYy4gbM6fU18Q       News & Politics  2006-08-07
# 5   UCi8e0iOVk1fEOogdfu4YgfA    Film and Animation  2011-04-01
# 6   UC8-Th83bH_thdKZDJCrn88g                Comedy  2006-01-08
# 7   UCvC4D8onUfXzvjTOM-dBfEA         Entertainment  2005-06-16
# 8   UC4PooiX37Pld1T8J5SYT-SQ         Entertainment  2008-09-17
# 9   UCCj956IF62FbT7Gouszaj9w         Entertainment  2005-11-12
# 10  UCjmJDM5pRKbUlVIzDYYWb6g         Entertainment  2006-10-17
# 11  UC0v-tlzsn0QZwJnkiaUSJVQ         Entertainment  2007-06-04
# 12  UCXhSCMRRPyxSoyLSPFxK7VA         Entertainment  2010-02-13
# 13  UCHEf6T_gVq4tlW5i91ESiWg         Entertainment  2013-07-30
# 14  UCp0hYYBW6IMayGgR-WeoCvQ         Entertainment  2006-11-21
# 15  UCmv1CLT6ZcFdTJMHxaR9XeA                 Music  2011-09-10
# 16  UCftwRNsjfRo08xYE31tkiyw  Science & Technology  2005-09-23
# 17  UCsTcErHg8oDvUnTzoqsYeNw  Science & Technology  2010-12-21
# 18  UClFSU9_bUb4Rc6OYfTt5SPw       News & Politics  2006-09-16
# 19  UCWOA1ZGywLbqmigxE4Qlvuw         Entertainment  2012-07-17
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0        Beyond The Trailer          853000       5064             19744.0
# 1         Emergency Awesome         3210000       3949              3268.0
# 2         Jimmy Kimmel Live        15200000       4207               212.0
# 3             BuzzFeedVideo        19400000       6334               158.0
# 4                  ABC News         6640000      48869               978.0
# 5       Movieclips Trailers        13900000       8084               267.0
# 6   The Tonight Show Sta...        22100000       5450                96.0
# 7   Marvel Entertainment...        13200000       6332               302.0
# 8   Good Mythical Mornin...        15700000       2307               210.0
# 9                       BBC         7100000      20914               833.0
# 10  Warner Bros. Picture...         7660000       2397               779.0
# 11                      FBE        19600000       2080               143.0
# 12          Matthew Santoro         6380000        872              1174.0
# 13                    REACT        12000000       1758               357.0
# 14             TheEllenShow        34400000      10692                28.0
# 15              PTXofficial        17100000        201               176.0
# 16                    WIRED         5100000       2902              1354.0
# 17            Unbox Therapy        15300000       1672               206.0
# 18          Philip DeFranco         6400000       2627              1170.0
# 19                  Netflix        11100000       3166               346.0
#
#     weights
# 0    2.8635
# 1    2.2750
# 2    2.0870
# 3    2.0870
# 4    2.0870
# 5    2.0870
# 6    2.0870
# 7    2.0870
# 8    2.0870
# 9    2.0870
# 10   2.0870
# 11   2.0870
# 12   2.0870
# 13   2.0870
# 14   2.0870
# 15   2.0870
# 16   2.0870
# 17   2.0870
# 18   2.0870
# 19   2.0870

# %% [markdown]
# ### User jumper implementation

# %%
# We randomly choose 3 000 users and for each user we select a random pair of channel
# channels_tuple = [(channel_1, channel_2), (...)]
with open(os.path.join(COMMON_PATH, "channels_tuple_user_walk.pkl"),'rb') as f:
     channels_tuple = pickle.load(f)
f.close()

# %%
files = [PATH]
users_walk_tab, ranking_position_tab = get_user_walk_and_position_ratio(files, channels_tuple)
# Out:
# file  /dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/channel_sampling_then_permutation/CONTEXT_True_20_SUBSAMPLING_True_0.001_LR_0.018/models/embedding0.csv.gz
# n_comp  200

# %%
print('User walk = ' + str(users_walk_tab))
print('Ranking position ratio = ' + str(ranking_position_tab))
# Out:
# User walk = [0.41953733475940824]
# Ranking position ratio = [0.09397382859112044]
