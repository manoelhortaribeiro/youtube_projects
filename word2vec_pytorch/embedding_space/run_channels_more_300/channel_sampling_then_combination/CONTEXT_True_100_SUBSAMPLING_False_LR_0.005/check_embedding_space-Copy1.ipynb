# %% [markdown]
# ## NOTEBOOK DESCRIPTION:
#
# This notebook checks the behaviour of the embedding space:
# - It first checks manually the nearest neighbors of some selected channels
# - It also compute the user jumper score which is a first barrier on the evaluation of the embedding

# %%
import pickle
import os
import sys
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE

scriptpath = "/home/jouven/youtube_projects/"
sys.path.append(os.path.abspath(scriptpath))

from helpers.helpers_channels_more_300 import *
from helpers.helpers_channel_embedding import *

# %% [markdown]
# ### Useful functions

# %%
# Selected channels and id-index mapping
dict_channel_ind, dict_ind_channel, channels_id = filtered_channels_index_id_mapping()

# %%
PATH = '/dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/channel_sampling_then_combination/CONTEXT_True_100_SUBSAMPLING_FALSE_0.001_LR_0.005/models/embedding.csv.gz'

# %%
channelcrawler = pd.read_csv("/dlabdata1/youtube_large/df_channels_en.tsv.gz", sep='\t')
# Select the rows being in the select channels
channelcrawler = channelcrawler[channelcrawler['channel'].apply(lambda row: row in channels_id)]

# %%
channelcrawler.head()
# Out:
#      category_cc   join_date                   channel  \
# 0         Gaming  2010-04-29  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 1      Education  2006-09-01  UCbCmjCuTUZos6Inko4u57UQ
# 2  Entertainment  2006-09-20  UCpEhnqL0y41EpW2TvWAHD7Q
# 3  Howto & Style  2016-11-15  UC295-Dw_tDNtZXFeAPAW6Aw
# 4         Sports  2007-05-11  UCJ5v_MCY6GNUBTO8-D3XoAg
#
#                    name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                PewDiePie       101000000       3956                 3.0
# 1  Cocomelon - Nursery ...        60100000        458                 7.0
# 2                SET India        56018869      32661                 8.0
# 3          5-Minute Crafts        60600000       3591                 9.0
# 4                      WWE        48400000      43421                11.0
#
#    weights
# 0    2.087
# 1    2.087
# 2    2.087
# 3    2.087
# 4    2.087

# %%
channelcrawler['category_cc'].unique()
# Out:
# array(['Gaming', 'Education', 'Entertainment', 'Howto & Style', 'Sports',
#        'Music', 'Film and Animation', 'Comedy', 'Nonprofits & Activism',
#        'People & Blogs', 'News & Politics', 'Science & Technology',
#        'Pets & Animals', 'Autos & Vehicles', 'Travel & Events', nan],
#       dtype=object)

# %% [markdown]
# ### Manually check the neirest neighbors of some selected channels

# %% [markdown]
# First to check how good is the embedding space, we are going to choose a channel and it's k closest channels in the embedding space. By looking at these channels in the YouTube website, we have a sense of how good/bad is the embedding.

# %%
# Looking at the neirest neigbors of `Shaaanxo` being a girl fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCMpOz2KEfkSdd5JeIJh_fxw'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel     category_cc   join_date            name_cc  \
# 0   UCMpOz2KEfkSdd5JeIJh_fxw   Howto & Style  2009-01-18           Shaaanxo
# 1   UCCvoAe__WFYMNAEN-C-CtYA   Howto & Style  2008-08-05         Wayne Goss
# 2   UCE1BqH-72EBs-siTbDAjOGQ   Howto & Style  2008-04-20      Marlena Stell
# 3   UCo5zIpjl2OQkYatd8R0bDaw   Howto & Style  2008-06-15        Dulce Candy
# 4   UCjHyFOH80C4x_2n_Korx4QQ  People & Blogs  2010-11-03         ThatsHeart
# 5   UC8v4vz_n2rys6Yxpj8LuOBA   Howto & Style  2013-01-26     KathleenLights
# 6   UCzTKskwIc_-a0cGvCXA848Q   Howto & Style  2008-06-23    NikkieTutorials
# 7   UCxj0QizmFhx7kVKSArHBCTA   Howto & Style  2011-03-09       Casey Holmes
# 8   UC21yq4sq8uxTcfgIxxyE9VQ   Howto & Style  2011-06-27        Carli Bybel
# 9   UCM3P_G21gOSVdepXrEFojIg   Howto & Style  2011-01-26     Rachel Talbott
# 10  UCGwPbAQdGA3_88WBuGtg9tw   Howto & Style  2010-12-03      grav3yardgirl
# 11  UCc6W7efUSkd9YYoxOnctlFg   Entertainment  2009-06-08       Bethany Mota
# 12  UCPRlGA2w7C_DVw-1ynolJYw  People & Blogs  2011-07-19     Shaaanxo Vlogs
# 13  UCG9nVSLp4nQlW79sY5ihRrg   Howto & Style  2013-08-17       Desi Perkins
# 14  UCKMugoa0uHpjUuq14yOpagw   Howto & Style  2009-06-09          Laura Lee
# 15  UCooQN8b9yPeNQgUFa9S5xew   Howto & Style  2009-07-22     Samantha Maria
# 16  UCkJHb4rTNd8PIMD9S0UPCiw   Howto & Style  2009-07-15          thataylaa
# 17  UCZ90tZPn-ue2BmRAcDD88tA   Howto & Style  2010-01-04      Amanda Steele
# 18  UC9TreTE-iXwfwQl72DzDurA   Howto & Style  2009-01-04     Kandee Johnson
# 19  UCJRFJl5UDs4Citzs-uRcrxQ   Howto & Style  2011-01-12  Danielle Mansutti
#
#     subscribers_cc  videos_cc  subscriber_rank_sb  weights
# 0          3215340       1422              3566.0   2.2780
# 1          3670000       1357              2740.0   2.2180
# 2          1520000        754              9894.0   2.6430
# 3          2220000       1055              6090.0   2.4605
# 4          2200000        432              6234.0   2.4680
# 5          4140000        979              2308.0   2.1680
# 6         12269235        742               312.0   2.0870
# 7          1770000        730              8208.0   2.5370
# 8          6190000        546              1234.0   2.0870
# 9          1210000        337             13160.0   2.7555
# 10         8560000       1536               725.0   2.0870
# 11        10200000        483               545.0   2.0870
# 12          555112        742             29412.0   3.0150
# 13         3290000        359              3358.0   2.2880
# 14         4400000        638              2083.0   2.1200
# 15         1800000        795              8037.0   2.5600
# 16          769000        894             21754.0   2.9375
# 17         2700000        437              4606.0   2.3870
# 18         3900000        630              2276.0   2.1660
# 19         1610000        412              9194.0   2.5580

# %%
# Looking at the neirest neigbors of `Alex Costa` being a men fashion channel
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCZyCposXwcyopaACep44maQ'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel           category_cc   join_date  \
# 0   UCZyCposXwcyopaACep44maQ         Howto & Style  2011-09-29
# 1   UC1KbedtKa3d5dleFR6OjQMg         Howto & Style  2008-07-06
# 2   UChNN7VBxPTiNrqjUaQd9bxA         Howto & Style  2012-09-14
# 3   UCklSaeqb0wONcyEv44PV-iQ                Comedy  2017-08-08
# 4   UCgFpJKyIywUc8arDxhABGPw  Science & Technology  2011-11-25
# 5   UCWsEZ9v1KC8b5VYjYbEewJA  Science & Technology  2011-03-22
# 6   UCe0TLA0EsQbE-MjuHXevj2A         Howto & Style  2006-12-16
# 7   UCu4X846OSea5YU6S8fIpy1A                Comedy  2012-06-20
# 8   UCSrnmu3W6YXWU_85DKT5arg                Comedy  2014-06-17
# 9   UC5fqfItld8kQufe3djD6wAw         Howto & Style  2011-10-10
# 10  UCtQEjfEFzba37ozoXK40r3w        People & Blogs  2013-09-29
# 11  UCWYzs-Mi7SM_n1EgvzIOn3w         Entertainment  2017-01-12
# 12  UCBdw4dLCLLHmTgAOnW4V0hQ         Entertainment  2005-11-24
# 13  UC0zYuwJf9-i3ROZ1F30gV4w         Howto & Style  2011-12-29
# 14  UCiAq_SU0ED1C6vWFMnw8Ekg       Travel & Events  2013-03-13
# 15  UCTqMx8l2TtdZ7_1A40qrFiQ  Science & Technology  2013-06-18
# 16  UCIJ0lLcABPdYGp7pRMGccAQ                Sports  2007-01-01
# 17  UCsTcErHg8oDvUnTzoqsYeNw  Science & Technology  2010-12-21
# 18  UCtinbF-Q-fVthA0qrFQTgXQ        People & Blogs  2010-02-15
# 19  UCVlMUh4WsDQvOxCJJXmWwdw  Science & Technology  2013-06-16
#
#                 name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0            Alex Costa         2120000        543              5370.0
# 1              alpha m.         5360000       1116              1376.0
# 2   Teachingmensfashion         4210000       1160              2093.0
# 3     The Daily Dropout         1907121        280              6761.0
# 4       UnlockRiver.com         1411980        245             10323.0
# 5         Nick Ackerman          490000       1616             33875.0
# 6            ATHLEAN-X™         8520000       1049               657.0
# 7             BigDawsTv         6340000        225              1020.0
# 8           ThatWasEpic         3540000        189              2103.0
# 9        Brett Maverick          636000        222             25157.0
# 10         How to Beast          641000        350             21034.0
# 11        Jack ManleyTV         1340000         34             11112.0
# 12             The Rock         4470000        193              1879.0
# 13          Robin James          291000        524             59774.0
# 14      The Food Ranger         3420000        253              2704.0
# 15          XEETECHCARE         1300000       4011             10892.0
# 16   People are Awesome         3340000        579              3239.0
# 17        Unbox Therapy        15300000       1672               206.0
# 18         CaseyNeistat        11500000       1015               405.0
# 19        Matthew Moniz          406000        747             41409.0
#
#     weights
# 0    2.4170
# 1    2.0870
# 2    2.1225
# 3    2.4865
# 4    2.6605
# 5    3.2070
# 6    2.0870
# 7    2.0870
# 8    2.1255
# 9    2.9560
# 10   2.9230
# 11   2.6360
# 12   2.0870
# 13   3.6015
# 14   2.2165
# 15   2.6250
# 16   2.2720
# 17   2.0870
# 18   2.0870
# 19   3.3695

# %%
# Looking at the neirest neigbors of `Magpiepony` which is a kids film
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCISF5OGuAtSLNF24TKTnXag'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel         category_cc   join_date  \
# 0   UCISF5OGuAtSLNF24TKTnXag  Film and Animation  2013-12-17
# 1   UC1AEadAUKi6Zt-G3PatrU-Q  Film and Animation  2012-08-19
# 2   UCcZjYWpM72s-1cinYfeSCag      People & Blogs  2010-08-05
# 3   UCD_VOth7RmckN6DbmFJa__A       Entertainment  2013-08-31
# 4   UC9qgVkKRZUXcgHdf35Z-8dw  Film and Animation  2013-06-24
# 5   UCkQ3eqNNaFrBZ_WbnCIMN8w  Film and Animation  2011-10-19
# 6   UC1RMBtYn0Fw8Pf7KuvkrRNw              Gaming  2009-11-01
# 7   UCcGuE4cmWhB4XLjSKA8eRFA       Entertainment  2014-08-30
# 8   UCPflSzRRyzK2hhbVxNAnrhw  Film and Animation  2012-03-31
# 9   UCZBY6V8Lxmwu8gGRBOyO11w              Gaming  2014-06-16
# 10  UCMsgXPD3wzzt8RxHJmXH7hQ       Entertainment  2006-02-28
# 11  UChU79FLnClqlRSTSZe3EjNA  Film and Animation  2014-03-21
# 12  UCU3fglxsmECS7G6XtOytNAQ       Entertainment  2010-03-25
# 13  UCu6v4AdYxVH5fhfq9mi5llA  Film and Animation  2014-02-17
# 14  UCQTyMsas9G2_NAQkZFI-2UQ              Gaming  2012-05-02
# 15  UC-r13SLLdZtZNmuC2bMnlmw  Film and Animation  2013-09-27
# 16  UCHKDtSVVEc686EW7jRSCpZA       Entertainment  2007-04-01
# 17  UCelMeixAOTs2OQAAi9wU8-g       Entertainment  2013-11-03
# 18  UCc7sgU-zW6hQrgv9i6hsbPw  Film and Animation  2012-12-28
# 19  UC9JxbE2SBXAAQ4YOH9GP0Ag              Comedy  2012-01-14
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0                Magpiepony          736000        304             21120.0
# 1            Letupita725HD★         2698245       2115              4054.0
# 2         DisneyFanatic2364          205000       1026             88028.0
# 3          The Brony Notion          256132        158             70689.0
# 4   My Little Pony Offic...          874016       1840             12248.0
# 5                    shgurr         2060000         68              6256.0
# 6                Vannamelon          919000        241             17845.0
# 7                 WatchPony          117000        341            144609.0
# 8                Pinkie Pie         1229394        451             11840.0
# 9               Kubz Scouts         3160000       1440              3303.0
# 10          Cartoon Network         5890000       5962              1095.0
# 11               Flutter525          858000       1297             20180.0
# 12  MandaPanda Toy Colle...          403000        308             43366.0
# 13  Let Me Explain Studi...         2450000         62              4527.0
# 14            Michaela Laws          365000        716             48494.0
# 15                   Hasbro         3620000       8328              2857.0
# 16  Scribbler Production...          327000       1767             54604.0
# 17             CookieSwirlC        12200000       3182               327.0
# 18                 yum soda          346000        714             52811.0
# 19             LittleshyFiM          172000        222             94206.0
#
#     weights
# 0    2.9225
# 1    2.3350
# 2    4.3405
# 3    3.7420
# 4    2.6960
# 5    2.4685
# 6    2.8605
# 7    4.0540
# 8    2.6965
# 9    2.2885
# 10   2.0870
# 11   2.8735
# 12   3.3925
# 13   2.3720
# 14   3.4070
# 15   2.2280
# 16   3.5110
# 17   2.0870
# 18   3.5390
# 19   3.9705

# %%
# Looking at neirest neigbors of `Beyond the trailer` a channel for analysis of films
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCAXR2zenCwvRIyQd9ydtfaA'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel         category_cc   join_date  \
# 0   UCAXR2zenCwvRIyQd9ydtfaA       Entertainment  2008-11-03
# 1   UCWvMmm_sSdgALpo1Ci4WvtQ       Entertainment  2007-02-04
# 2   UCQMbqH7xJu5aTAPQ9y_U7WQ       Entertainment  2009-03-05
# 3   UCzNWVDZQ55bjq8uILZ7_wyQ  Film and Animation  2011-06-27
# 4   UCRgUg0jJUgGMadGPzzmu8cw       Entertainment  2008-07-16
# 5   UCi8e0iOVk1fEOogdfu4YgfA  Film and Animation  2011-04-01
# 6   UCCqEeDAUf4Mg0GgEN658tkA       Entertainment  2011-01-06
# 7   UC7v3-2K1N84V67IF-WTRG-Q       Entertainment  2007-03-07
# 8   UCTAgbu2l6_rBKdbTvEodEDw       Entertainment  2007-06-17
# 9   UCP1iRaFlS5EYjJBryFV9JPw       Entertainment  2015-11-25
# 10  UCLRlryMfL8ffxzrtqv0_k_w       Entertainment  2014-08-18
# 11  UCM7Srv4mxJejt2NLmumkRRQ       Entertainment  2011-08-17
# 12  UCzcRQ3vRNr6fJ1A9rqFn7QA  Film and Animation  2006-08-10
# 13  UCaA3Cnh8B_jmfTLX9GjIqEw       Entertainment  2011-03-20
# 14  UCiifkYAs_bq1pt_zbNAzYGg       Entertainment  2011-08-19
# 15  UCq0OueAsdxH6b8nyAspwViw       Entertainment  2006-06-19
# 16  UCLyYEq4ODlw3OD9qhGqwimw  Film and Animation  2011-09-21
# 17  UCVtL1edhT8qqY-j2JIndMzg  Film and Animation  2006-06-24
# 18  UCWOA1ZGywLbqmigxE4Qlvuw       Entertainment  2012-07-17
# 19  UCRX7UEyE8kp35mPrgC2sosA  Film and Animation  2011-06-27
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0        Beyond The Trailer          853000       5064             19744.0
# 1           Collider Videos          583000       9074             30710.0
# 2   Fandom Entertainment...         1570000      10813              9597.0
# 3   FRESH Movie Trailers...         4150000       6543              2211.0
# 4         GameSpot Universe          596000       4512             28150.0
# 5       Movieclips Trailers        13900000       8084               267.0
# 6           Chris Stuckmann         1580000       1400              8486.0
# 7              Jeremy Jahns         1600000       1584              8351.0
# 8                   Nerdist         2690000       2370              4427.0
# 9                    Looper         4820000       2533              1758.0
# 10  KinoCheck Internatio...         2703663       2663              3977.0
# 11              WhatCulture         1890000       2180              7137.0
# 12                ONE Media         2360621       3763              4967.0
# 13         HN Entertainment          411000       6552             44650.0
# 14                       DC         2380000       2587              5036.0
# 15       Universal Pictures         2330000        830              4478.0
# 16         Movieclips Indie         1500000       9368              9608.0
# 17                  CineFix         3410000       1990              3015.0
# 18                  Netflix        11100000       3166               346.0
# 19  JoBlo Movie Trailers...         2070000       5081              6408.0
#
#     weights
# 0    2.8635
# 1    3.0665
# 2    2.5995
# 3    2.1430
# 4    3.0100
# 5    2.0870
# 6    2.5600
# 7    2.5415
# 8    2.3700
# 9    2.0870
# 10   2.3070
# 11   2.5220
# 12   2.3650
# 13   3.3705
# 14   2.3910
# 15   2.3605
# 16   2.5990
# 17   2.2295
# 18   2.0870
# 19   2.4595

# %%
nearest_neighbors_id = get_k_nearest_neighbors(PATH, dict_channel_ind['UCaCTtPkowVggMiUYhQmlcMw'], dict_ind_channel, k= 20)
nearest_neighbors = pd.DataFrame(nearest_neighbors_id, columns = ['channel']).merge(channelcrawler)
nearest_neighbors
# Out:
#                      channel     category_cc   join_date  \
# 0   UCaCTtPkowVggMiUYhQmlcMw          Sports  2015-12-30
# 1   UCg4o4z4Xrk9SG4wX3Kpmydw          Sports  2011-04-21
# 2   UCWDto2R36n9pwwXq1HgjYHA          Sports  2015-07-09
# 3   UCj6Pm9XJJBdxFrJ4nw6ZEAQ       Education  2015-08-02
# 4   UCTw6CZg_va2CWaENxhhPcSA          Sports  2013-07-30
# 5   UCQHhd5lxVEkGidVXXegTisw          Sports  2014-07-01
# 6   UCrfUPwsgeu_Gp9xJ1Z9v1Jg          Sports  2011-01-14
# 7   UCzUd3H_e_qWqs4dR4GxVHOQ  People & Blogs  2017-02-14
# 8   UCoQ9JsZw8RT8w6uqDmq12Hg          Sports  2017-03-20
# 9   UCs9b1SWEVJ2N4_l6eJIHJ2Q          Sports  2015-04-03
# 10  UC4rs8ppJ8Hn4buQgYVCBdtg          Sports  2014-01-29
# 11  UC2NB6YdnNfyV8F5shCbqJQg   Howto & Style  2014-04-01
# 12  UCHGLzofW9eeaE4qunupa84g  People & Blogs  2015-01-15
# 13  UCF4GParg0qcuYXGZwfuYemA          Sports  2017-09-20
# 14  UCJLZhluuIvBBbWJtCXMDy6g          Sports  2013-03-28
# 15  UCSaWOJZ1kyZ54B5njsbOAsw          Sports  2017-03-31
# 16  UC1lfnF3avRvtFm_wajLLhyg  People & Blogs  2014-07-01
# 17  UCtIDxwi1nhEkwLqCcnSrwpA          Sports  2008-04-30
# 18  UCy18P-QY4lIRAJpvZdsfMeQ          Sports  2014-10-16
# 19  UCuJmic6xIVEzEqDAc8QwIeg          Sports  2010-01-07
#
#                     name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 0         CrossFit Invictus           27200        196            440262.0
# 1               Noah Ohlsen           50200        201            258307.0
# 2             Julie Foucher           16100        127            690819.0
# 3   Working Against Grav...           16900        128            639884.0
# 4   USN UK - Ultimate Sp...           19200        226            605238.0
# 5   Structure Your Stren...           19300        485            541864.0
# 6              Gracie Davis           18700       1147            604357.0
# 7       Training Think Tank           19200        287            582830.0
# 8               Logan Sneed           30800        593            418137.0
# 9              Ben Bergeron           30600        128            396788.0
# 10        Fitness Deal News           13601        430            678217.0
# 11               LilMonstar           21600        154            562027.0
# 12          Iraki Nutrition           13600         73            773653.0
# 13                CompTrain           26900         99            391825.0
# 14  Blue Star Nutraceuti...           57334        139            233384.0
# 15         Tia-Clair Toomey           34200         31            339788.0
# 16               TeamRICHEY          208596        993             79056.0
# 17                     NSCA           18800        251            540964.0
# 18         Misfit Athletics           18402        404            608916.0
# 19          DigitalMuscleTV           16900        103            656910.0
#
#     weights
# 0    7.1160
# 1    6.4685
# 2   10.0600
# 3    9.8300
# 4    9.5685
# 5    8.7070
# 6    9.6795
# 7    6.6245
# 8    6.1990
# 9    6.9700
# 10  10.5675
# 11  10.7965
# 12  11.0350
# 13   6.9380
# 14   6.3385
# 15   6.0865
# 16   3.6700
# 17   8.5565
# 18   8.5115
# 19   8.3660

# %% [markdown]
# ### User jumper implementation

# %%
# We randomly choose 3 000 users and for each user we select a random pair of channel
# channels_tuple = [(channel_1, channel_2), (...)]
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_tuple_user_walk.pkl",'rb') as f:
     channels_tuple = pickle.load(f)
f.close()

# %%
files = [PATH]
users_walk_tab, users_walk_tab_new, ranking_position_tab = get_user_walk_and_position_ratio(files, channels_tuple)
# Out:
# file  /dlabdata1/youtube_large/jouven/word2vec_pytorch/run_channels_more_300/channel_sampling_then_combination/CONTEXT_True_100_SUBSAMPLING_FALSE_0.001_LR_0.005/models/embedding.csv.gz
# n_comp  200

# %%
print('User walk = ' + str(users_walk_tab))
print("User walk (new way) = " + str(users_walk_tab_new))
print('Ranking position ratio = ' + str(ranking_position_tab))
# Out:
# User walk = [0.16400865275979634]
# User walk (new way) = [8079.310844979832]
# Ranking position ratio = [0.2396947468872818]

# %%
print('User walk = ' + str(users_walk_tab))
print("User walk (new way) = " + str(users_walk_tab_new))
print('Ranking position ratio = ' + str(ranking_position_tab))
# Out:
# User walk = [0.5014768278075578]
# User walk (new way) = [1.6468997642238445]
# Ranking position ratio = [0.07208960544994446]

# %% [markdown]
# ### Plot the embedding

# %%
ix_to_word, word_to_ix = channel_to_name(channelcrawler, dict_channel_ind)

# %%
# Project the embedding in 2D
'''
EMBEDDING = get_dataframe_in_embedding_space(PATH)

print("\n', 'running TSNE...")
tsne = TSNE(n_components = 2).fit_transform(EMBEDDING)
print("tsne.shape: ", tsne.shape) 

# Save the projected embedding in the 2D plane
np.save('/home/jouven/youtube_projects/word2vec_pytorch/embedding_space/run_channels_more_300/channel_sampling_then_combination/CONTEXT_True_100_SUBSAMPLING_False_LR_0.005/tsne.npy', tsne)
'''
# Out:
# '\nEMBEDDING = get_dataframe_in_embedding_space(PATH)\n\nprint("\n\', \'running TSNE...")\ntsne = TSNE(n_components = 2).fit_transform(EMBEDDING)\nprint("tsne.shape: ", tsne.shape) \n\n# Save the projected embedding in the 2D plane\nnp.save(\'/home/jouven/youtube_projects/word2vec_pytorch/embedding_space/run_channels_more_300/channel_sampling_then_combination/CONTEXT_True_100_SUBSAMPLING_False_LR_0.005/tsne.npy\', tsne)\n'

# %%
# Load the projected embedding in the 2D plane
tsne = np.load('/home/jouven/youtube_projects/word2vec_pytorch/embedding_space/run_channels_more_300/channel_sampling_then_combination/CONTEXT_True_100_SUBSAMPLING_False_LR_0.005/tsne.npy')

# %% [markdown]
# Plot to visualize the embeddingg in 2D.
# The channels appearing in the plot are the channels having more than 4000k subsribers. In addition, we have 20 colored channels representing the selected pairs in the "axis projection process".

# %%
############ VISUALIZING ############
SAMPLES = 500
x, y = [], []
annotations = []
for idx, coord in enumerate(tsne):
    # print(coord)
    annotations.append(ix_to_word[idx])
    x.append(coord[0])
    y.append(coord[1])

test_words = [dict_ind_channel[channel] for channel in random.sample(range(len(channels_id)), SAMPLES)]
with open("/dlabdata1/youtube_large/jouven/channels_more_300/channels_more_4000k_subs.pkl",'rb') as f:
     test_words = pickle.load(f)
f.close()
test_words = random.sample(test_words, SAMPLES)
plt.figure(figsize = (50, 50))
for i in range(len(test_words)):
    word = ix_to_word[dict_channel_ind[test_words[i]]]
    vocab_idx = word_to_ix[word]
    plt.scatter(x[vocab_idx], y[vocab_idx])
    
    plt.annotate(word, xy = (x[vocab_idx], y[vocab_idx]), \
            ha='right',va='bottom', color = 'gray', fontsize = 12)
plt.xlabel('x coodrinate')
plt.ylabel('y coodrinate')
plt.savefig("/home/jouven/youtube_projects/word2vec_pytorch/embedding_space/run_channels_more_300/channel_sampling_then_combination/CONTEXT_True_100_SUBSAMPLING_False_LR_0.005/embedding_2d.pdf")
#plt.title("Embedding visualization in 2D using channels having more than 4000k subsribers")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 45908 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 52992 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_pdf.py:2001: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_pdf.py:2001: RuntimeWarning: Glyph 45908 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_pdf.py:2001: RuntimeWarning: Glyph 52992 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_pdf.py:2001: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_pdf.py:2099: RuntimeWarning: Glyph 50896 missing from current font.
#   flags=LOAD_NO_HINTING)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_pdf.py:2099: RuntimeWarning: Glyph 45908 missing from current font.
#   flags=LOAD_NO_HINTING)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_pdf.py:2099: RuntimeWarning: Glyph 52992 missing from current font.
#   flags=LOAD_NO_HINTING)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_pdf.py:2099: RuntimeWarning: Glyph 51060 missing from current font.
#   flags=LOAD_NO_HINTING)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 45908 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 52992 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 45908 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 52992 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
