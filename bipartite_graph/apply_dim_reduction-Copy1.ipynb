# %%
import scipy.sparse
import random
import os
import sys

import numpy as np

from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import IncrementalPCA

# %%
# Number of parameter wanted after the dimentionality reduction
n_components = [10, 20, 30]

# %%
graph_sparse_matrix = scipy.sparse.load_npz('/dlabdata1/youtube_large/jouven/final_embedding_sparse_matrix/sparse_matrix_bipartite.npz')

# %%
print(graph_sparse_matrix.count_nonzero())
# Out:
# 2435222

# %%
import pickle
with open("/dlabdata1/youtube_large/jouven/sparse_matrix_construction/idx_50.pkl",'rb') as f:
    print(pickle.load(f))
f.close()
# Out:
# [8370605749]

# %% [markdown]
# ### Truncated SVD

# %% [markdown]
# Load the big sparse matrix corresponding to all the edges and then apply truncated svd method from sklearn. This transformer performs linear dimensionality reduction by means of truncated singular value decomposition (SVD). Contrary to PCA, this estimator does not center the data before computing the singular value decomposition. This means it can work with sparse matrices efficiently.

# %%
graph_sparse_matrix.shape[1]
# Out:
# 436488207

# %%
def check_directory(dir_1):
    
    if not os.path.exists(dir_1): 
        os.makedirs(dir_1)

# %%
dir_1 = '/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/'
check_directory(dir_1)
for n_comp in n_components:
    print(n_comp)
    trunc_svd = TruncatedSVD(n_components = n_comp)
    graph_reduced = trunc_svd.fit_transform(graph_sparse_matrix)
    # Save the array into npz format
    np.savez_compressed('/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/bipartite_matrix_reduced_rsvd_'+ str(20) +'.npz', graph_reduced)
# Out:
# 10
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-a1e1a532a4f3> in <module>()
#       4     print(n_comp)
#       5     trunc_svd = TruncatedSVD(n_components = n_comp)
# ----> 6     graph_reduced = trunc_svd.fit_transform(graph_sparse_matrix)
#       7     # Save the array into npz format
#       8     np.savez_compressed('/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/bipartite_matrix_reduced_rsvd_'+ str(20) +'.npz', graph_reduced)
#
# /scratch/jouven/anaconda3/lib/python3.6/site-packages/sklearn/decomposition/truncated_svd.py in fit_transform(self, X, y)
#     172             U, Sigma, VT = randomized_svd(X, self.n_components,
#     173                                           n_iter=self.n_iter,
# --> 174                                           random_state=random_state)
#     175         else:
#     176             raise ValueError("unknown algorithm %r" % self.algorithm)
#
# /scratch/jouven/anaconda3/lib/python3.6/site-packages/sklearn/utils/extmath.py in randomized_svd(M, n_components, n_oversamples, n_iter, power_iteration_normalizer, transpose, flip_sign, random_state)
#     324
#     325     Q = randomized_range_finder(M, n_random, n_iter,
# --> 326                                 power_iteration_normalizer, random_state)
#     327
#     328     # project M to the (k + p) dimensional space using the basis vectors
#
# /scratch/jouven/anaconda3/lib/python3.6/site-packages/sklearn/utils/extmath.py in randomized_range_finder(A, size, n_iter, power_iteration_normalizer, random_state)
#     222     # Sample the range of A using by linear projection of Q
#     223     # Extract an orthonormal basis
# --> 224     Q, _ = linalg.qr(safe_sparse_dot(A, Q), mode='economic')
#     225     return Q
#     226
#
# /scratch/jouven/anaconda3/lib/python3.6/site-packages/scipy/linalg/decomp_qr.py in qr(a, overwrite_a, lwork, mode, pivoting, check_finite)
#     163     elif mode == 'economic':
#     164         Q, = safecall(gor_un_gqr, "gorgqr/gungqr", qr, tau, lwork=lwork,
# --> 165             overwrite_a=1)
#     166     else:
#     167         t = qr.dtype.char
#
# /scratch/jouven/anaconda3/lib/python3.6/site-packages/scipy/linalg/decomp_qr.py in safecall(f, name, *args, **kwargs)
#      19         ret = f(*args, **kwargs)
#      20         kwargs['lwork'] = ret[-2][0].real.astype(numpy.int)
# ---> 21     ret = f(*args, **kwargs)
#      22     if ret[-1] < 0:
#      23         raise ValueError("illegal value in %d-th argument of internal %s"
#
# error: (lwork>=n||lwork==-1) failed for 1st keyword lwork: dorgqr:lwork=-1606122640

# %% [markdown]
# ### Facebook library

# %%
from fbpca import pca

# %%
dir_1 = '/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/'
check_directory(dir_1)
#for n_comp in n_components:
(graph_reduced, s, Va) = pca(graph_sparse_matrix, raw = True, k=10, n_iter = 1)
# Save the array into npz format
np.savez_compressed('/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/bipartite_matrix_reduced_pca_'+ str(10) +'.npz', graph_reduced)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-6-43604271cae3> in <module>
#       2 check_directory(dir_1)
#       3 #for n_comp in n_components:
# ----> 4 (graph_reduced, s, Va) = pca(graph_sparse_matrix, raw = True, k=10, n_iter = 1)
#       5 # Save the array into npz format
#       6 np.savez_compressed('/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/bipartite_matrix_reduced_pca_'+ str(10) +'.npz', graph_reduced)
#
# ~/.local/lib/python3.7/site-packages/fbpca.py in pca(A, k, raw, n_iter, l)
#    1598                 (Q, _) = qr(Q, mode='economic')
#    1599             if n_iter > 0:
# -> 1600                 (Q, _) = lu(Q, permute_l=True)
#    1601
#    1602             #
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/linalg/decomp_lu.py in lu(a, permute_l, overwrite_a, check_finite)
#     215     overwrite_a = overwrite_a or (_datacopied(a1, a))
#     216     flu, = get_flinalg_funcs(('lu',), (a1,))
# --> 217     p, l, u, info = flu(a1, permute_l=permute_l, overwrite_a=overwrite_a)
#     218     if info < 0:
#     219         raise ValueError('illegal value in %d-th argument of '
#
# MemoryError: Unable to allocate 39.0 GiB for an array with shape (436488207, 12) and data type float64

# %%
graph_reduced = 0
s = 0
Va = 0

# %%
dir_1 = '/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/'
check_directory(dir_1)
#for n_comp in n_components:
(graph_reduced, s, Va) = pca(graph_sparse_matrix, raw = True, k=50, n_iter = 1)
# Save the array into npz format
np.savez_compressed('/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/bipartite_matrix_reduced_pca_'+ str(40) +'.npz', graph_reduced)

# %%
graph_reduced = 0
s = 0
Va = 0

# %%
dir_1 = '/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/'
check_directory(dir_1)
#for n_comp in n_components:
(graph_reduced, s, Va) = pca(graph_sparse_matrix, raw = False, k=50, n_iter = 1)
# Save the array into npz format
np.savez_compressed('/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/bipartite_matrix_reduced_pca_center_'+ str(50) +'.npz', graph_reduced)

# %%
graph_reduced = 0
s = 0
Va = 0

# %%
dir_1 = '/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/'
check_directory(dir_1)
#for n_comp in n_components:
(graph_reduced, s, Va) = pca(graph_sparse_matrix, raw = False, k=60)
# Save the array into npz format
np.savez_compressed('/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/bipartite_matrix_reduced_pca_center_'+ str(60) +'.npz', graph_reduced)

# %%
graph_reduced = 0
s = 0
Va = 0

# %%
dir_1 = '/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/'
check_directory(dir_1)
#for n_comp in n_components:
(graph_reduced, s, Va) = pca(graph_sparse_matrix, raw = True, k=60)
# Save the array into npz format
np.savez_compressed('/dlabdata1/youtube_large/jouven/channel_embedding/sparse_matrix_bipartite/bipartite_matrix_reduced_pca_'+ str(60) +'.npz', graph_reduced)

# %% [markdown]
# ### Incremental PCA

# %%
#for n_comp in n_components:
ipca = IncrementalPCA(n_components=10, batch_size = 10)
graph_reduced = ipca.fit_transform(graph_sparse_matrix)
dir_1 = '/dlabdata1/youtube_large/jouven/channel_embedding/bipartite_graph/'
check_directory(dir_1)
np.savez_compressed('/dlabdata1/youtube_large/jouven/channel_embedding/bipartite_graph/bipartite_matrix_reduced_'+ str(10) +'.npz', graph_reduced)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-4-bdc272e33f93> in <module>
#       1 #for n_comp in n_components:
#       2 ipca = IncrementalPCA(n_components=10, batch_size = 10)
# ----> 3 graph_reduced = ipca.fit_transform(graph_sparse_matrix)
#       4 dir_1 = '/dlabdata1/youtube_large/jouven/channel_embedding/bipartite_graph/'
#       5 check_directory(dir_1)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_incremental_pca.py in fit(self, X, y)
#     209             if sparse.issparse(X_batch):
#     210                 X_batch = X_batch.toarray()
# --> 211             self.partial_fit(X_batch, check_input=False)
#     212
#     213         return self
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_incremental_pca.py in partial_fit(self, X, y, check_input)
#     275             _incremental_mean_and_var(
#     276                 X, last_mean=self.mean_, last_variance=self.var_,
# --> 277                 last_sample_count=np.repeat(self.n_samples_seen_, X.shape[1]))
#     278         n_total_samples = n_total_samples[0]
#     279
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/extmath.py in _incremental_mean_and_var(X, last_mean, last_variance, last_sample_count)
#     769     else:
#     770         new_unnormalized_variance = (
# --> 771             _safe_accumulator_op(np.nanvar, X, axis=0) * new_sample_count)
#     772         last_unnormalized_variance = last_variance * last_sample_count
#     773
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/extmath.py in _safe_accumulator_op(op, x, *args, **kwargs)
#     704         result = op(x, *args, **kwargs, dtype=np.float64)
#     705     else:
# --> 706         result = op(x, *args, **kwargs)
#     707     return result
#     708
#
# <__array_function__ internals> in nanvar(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py in nanvar(a, axis, dtype, out, ddof, keepdims)
#    1534     # the reason that it drops the keepdims kwarg is to force keepdims=True
#    1535     # so this used to work by serendipity.
# -> 1536     cnt = np.sum(~mask, axis=axis, dtype=np.intp, keepdims=_keepdims)
#    1537     avg = np.sum(arr, axis=axis, dtype=dtype, keepdims=_keepdims)
#    1538     avg = _divide_by_count(avg, cnt)
#
# MemoryError: Unable to allocate 4.07 GiB for an array with shape (10, 436488207) and data type bool
